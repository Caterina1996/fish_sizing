# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from termcolor import cprint
import results_analysis_utils as rutils
from IPython.display import display


# %load_ext autoreload
# %autoreload 2

# ===================================================================
# 1. CONFIGURATION
# ===================================================================
day_code = "2024_11_28" 
dataset_name = "DATASET_1" # O DATASET_2

ASPECT_RATIO_THR = 3.0
ANGLE_THR = 30.0

# Ruta al CSV crudo de este día concreto
csv_path = Path(f"/home/slimbook/fish_sizing/ARTICLE/{dataset_name}/{day_code}/{day_code}_ALL_raw_aggregated.csv")

cprint(f"👉 WORKING ON: {day_code}", "white", "on_blue", attrs=["bold"])
cprint(f"Reading csv from {csv_path}", "yellow")

# ===================================================================
# 2. FILTERING & AGGREGATION (Usando la misma lógica global)
# ===================================================================
# Le pasamos el nombre del día como 'dataset_name' para que la función imprima bonito

df_final, df_raw = rutils.load_and_filter_dataset(csv_path, 
                                                  dataset_name=day_code,
                                                  recalculate_failure_reason=True, 
                                                  aspect_ratio_thr=ASPECT_RATIO_THR, 
                                                  angle_thr=ANGLE_THR, 
                                                  save=False)

if df_raw.empty:
    raise ValueError("No data found for this day!")

# ===================================================================
# 3. DAILY SUMMARY TABLE (Single vs Multiple)
# ===================================================================
print("\n" + "="*85)
print(f"DAILY SUMMARY: {day_code}")
print("="*85)
print(f"{'SCENARIO':<15} | {'Total Tracks':<12} | {'Measured':<10} | {'Success (%)':<12} | {'MAE (cm)':<10} | {'STD (cm)':<10} | {'MAPE (%)':<10}")
print("-" * 85)

scenarios = ['All']
if 'scenario' in df_raw.columns:
    scenarios.extend(df_raw['scenario'].dropna().unique().tolist())

for sc in scenarios:
    # 1. Contar totales desde el RAW
    if sc == 'All':
        total_tracks = df_raw['track_uid'].nunique()
        sub_final = df_final
    else:
        total_tracks = df_raw[df_raw['scenario'] == sc]['track_uid'].nunique()
        sub_final = df_final[df_final['scenario'] == sc] if not df_final.empty else pd.DataFrame()
            
    # 2. Contar medidos desde el FINAL
    measured_tracks = len(sub_final)
    
    # 3. Calcular métricas
    if measured_tracks > 0:
        mae = sub_final['abs_error_cm'].mean()
        std = sub_final['abs_error_cm'].std()
        mape = sub_final['rel_error_perc'].mean()
    else:
        mae = std = mape = 0.0
        
    success_perc = (measured_tracks / total_tracks * 100) if total_tracks > 0 else 0
    
    label = f"GLOBAL DAY" if sc == 'All' else sc
    print(f"{label:<15} | {total_tracks:<12} | {measured_tracks:<10} | {success_perc:<12.1f} | {mae:<10.2f} | {std:<10.2f} | {mape:<10.2f}")

print("="*85 + "\n")


for sc in scenarios:
    cprint(f"\n\n{'='*70}", "white", "on_magenta", attrs=["bold"])
    cprint(f"📊 PLOTS FOR SCENARIO: {sc.upper()}", "white", "on_magenta", attrs=["bold"])
    cprint(f"{'='*70}", "white", "on_magenta", attrs=["bold"])
    
    # 1. Filtrar el dataframe dependiendo del escenario
    if sc == 'All':
        df_sc_raw = df_raw.copy()
        context_label = f"{day_code} - GLOBAL"
    else:
        df_sc_raw = df_raw[df_raw['scenario'] == sc].copy()
        context_label = f"{day_code} - {sc.upper()}"
        
    if df_sc_raw.empty:
        print(f"⚠️ No data available for {sc.upper()}, skipping plots.")
        continue
    
    # 2. Generar gráficos
    stacked_frames = rutils.plot_frame_failures(
        df_sc_raw, 
        aspect_ratio_thr=ASPECT_RATIO_THR, 
        angle_thr=ANGLE_THR,
        figsize_video=(12,6), 
        figsize_global=(5,5), 
        show_global=True,
        context_label=context_label
    )

    track_failures = rutils.plot_tracks_failure_distribution(
        df_sc_raw, 
        aspect_ratio_thr=ASPECT_RATIO_THR, 
        angle_thr=ANGLE_THR,
        show_global=True, 
        figsize_video=(12,6), 
        figsize_global=(5,5),
        context_label=context_label
    )

    rutils.plot_aspect_ratio_vs_length(
        df_sc_raw, 
        ASPECT_RATIO_THR=ASPECT_RATIO_THR, 
        figsize=(10, 8),
        context_label=context_label
    ) 
    
    # 1. Gráfica de Cascada (Ablation)
    print("\n📈 Generating Pipeline Ablation Plots...")
    stages_dict, agg_stages_dict = rutils.plot_ablation_pipeline(
        df_sc_raw, 
        ASPECT_RATIO_THR=ASPECT_RATIO_THR, 
        ANGLE_THR=ANGLE_THR,
        context_label=context_label  
    )
    
    # 2. Interacción de umbrales
    print("\n📈 Generating Thresholds Interaction Plot...")
    rutils.plot_thresholds_interaction(
        df_sc_raw, 
        optimal_ar=ASPECT_RATIO_THR, 
        context=context_label
    )
    
    # # 3. Relación de Error vs Geometría (Raw y Aislado)
    # print("\n📈 Generating Error vs Geometry Analysis Plots...")
    # rutils.plot_error_vs_geometry(
    #     df_sc_raw, 
    #     ar_thr=ASPECT_RATIO_THR, 
    #     angle_thr=ANGLE_THR, 
    #     context_label=context_label
    # )
    
    # print("\n📈 Generating Track Error vs Length Plot...")
    # rutils.plot_error_vs_track_length(
    #     df_raw=df_sc_raw, 
    #     df_final=sub_final,  # <--- ¡AQUÍ LE PASAMOS TU CÁLCULO INTELIGENTE!
    #     context_label=context_label,
    #     min_frames_thr=5
    # )
    
    print("\n📈 Generating Track Length Histogram...")
    rutils.plot_track_length_histogram(
        df_sc_raw, 
        min_frames_thr=5, # O el número que uses en el smart_aggregator
        context_label=context_label
    )
# Out:
# 👉 WORKING ON: 2024_11_28
# Reading csv from /home/slimbook/fish_sizing/ARTICLE/DATASET_1/2024_11_28/2024_11_28_ALL_raw_aggregated.csv
#
# --- Processing 2024_11_28 ---
# Total raw frames with valid GT: 11550
# Total initial tracks: 318
# Frames belonging to 'measured' tracks: 6476
# 📉 Tracks descartados por 'track_failure_from_frames': 162
# 📉 Tracks descartados por 'smart_aggregator': 0
# ✅ FINAL RESULT: 156 independent FISH (tracks) successfully aggregated.
# 📊 Success Rate: 49.06% (156/318 tracks medidos con éxito)
#
# =====================================================================================
# DAILY SUMMARY: 2024_11_28
# =====================================================================================
# SCENARIO        | Total Tracks | Measured   | Success (%)  | MAE (cm)   | STD (cm)   | MAPE (%)
# -------------------------------------------------------------------------------------
# GLOBAL DAY      | 318          | 156        | 49.1         | 1.21       | 1.71       | 4.74
# single_fish     | 100          | 37         | 37.0         | 1.10       | 1.51       | 3.79
# multiple_fish   | 218          | 119        | 54.6         | 1.25       | 1.78       | 5.03
# =====================================================================================
#
#
#
# ======================================================================
# 📊 PLOTS FOR SCENARIO: ALL
# ======================================================================
# ============================================================
# 📊 TABLA 1: Distribución Global de Frames
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured      6696           66.55
# 1        short_track         0            0.00
# 2      incomplete_3D       255            2.53
# 3            borders       879            8.74
# 4            overlap        21            0.21
# 5  aspect_ratio_fail       270            2.68
# 6         angle_fail      1940           19.28
# 7              other         0            0.00
# ============================================================
# 📊 TABLA 1: Distribución Global de Tracks
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured       156           49.06
# 1        short_track        90           28.30
# 2         not_a_fish         0            0.00
# 3      incomplete_3D        10            3.14
# 4     bad_pointcloud         9            2.83
# 5            borders        17            5.35
# 6            overlap         0            0.00
# 7  aspect_ratio_fail         6            1.89
# 8         angle_fail        30            9.43
# 9              other         0            0.00
# ============================================================
# 📊 TABLA 2: Desglose por Vídeo
# ============================================================
# track_failure_reason  measured  short_track  not_a_fish  incomplete_3D  \
# source_folder
# 12-52-36_0                   3            3           0              0
# 12-54-48_0                   6            8           0              0
# 12-57-00_0                   1            2           0              0
# 12-57-51_0                   1            2           0              0
# 12-58-48_0                   2            1           0              0
# 13-01-16_0                   3            1           0              0
# 13-02-27_0                   6            9           0              2
# 13-04-39_0                   2            0           0              0
# 13-05-27_0                   4            5           0              1
# 13-07-39_0                   2            1           0              0
# 13-08-34_0                   1            1           0              0
# 13-09-20_0                   1            0           0              0
# 13-12-31_0                   1            2           0              0
# 13-14-43_0                   9            4           0              1
# 13-16-54_0                   9            7           0              1
# 13-19-06_0                   9            2           0              0
# 13-21-17_0                   6            4           0              1
# 13-23-29_0                  19            2           0              1
# 13-25-41_0                  16            8           0              0
# 13-27-52_0                   8            2           0              0
# 13-32-16_0                   8            7           0              0
# 13-34-27_0                   8            2           0              0
# 13-36-49_0                   8            0           0              1
# 13-39-00_0                   4            1           0              0
# 13-41-12_0                   2            2           0              1
# 13-42-45_0                   5            1           0              0
# 13-44-57_0                   4            3           0              1
# 13-47-08_0                   4            6           0              0
# 13-48-24_0                   4            4           0              0
#
# track_failure_reason  bad_pointcloud  borders  overlap  aspect_ratio_fail  \
# source_folder
# 12-52-36_0                         0        1        0                  0
# 12-54-48_0                         0        1        0                  0
# 12-57-00_0                         0        1        0                  0
# 12-57-51_0                         0        0        0                  0
# 12-58-48_0                         0        1        0                  0
# 13-01-16_0                         0        1        0                  0
# 13-02-27_0                         0        3        0                  0
# 13-04-39_0                         0        0        0                  0
# 13-05-27_0                         0        2        0                  0
# 13-07-39_0                         0        0        0                  0
# 13-08-34_0                         0        0        0                  0
# 13-09-20_0                         0        1        0                  0
# 13-12-31_0                         0        0        0                  0
# 13-14-43_0                         1        1        0                  0
# 13-16-54_0                         0        2        0                  2
# 13-19-06_0                         1        0        0                  0
# 13-21-17_0                         0        1        0                  2
# 13-23-29_0                         2        0        0                  0
# 13-25-41_0                         4        1        0                  1
# 13-27-52_0                         0        0        0                  0
# 13-32-16_0                         1        0        0                  1
# 13-34-27_0                         0        0        0                  0
# 13-36-49_0                         0        0        0                  0
# 13-39-00_0                         0        0        0                  0
# 13-41-12_0                         0        0        0                  0
# 13-42-45_0                         0        0        0                  0
# 13-44-57_0                         0        1        0                  0
# 13-47-08_0                         0        0        0                  0
# 13-48-24_0                         0        0        0                  0
#
# track_failure_reason  angle_fail  other
# source_folder
# 12-52-36_0                     1      0
# 12-54-48_0                     1      0
# 12-57-00_0                     0      0
# 12-57-51_0                     2      0
# 12-58-48_0                     0      0
# 13-01-16_0                     0      0
# 13-02-27_0                     2      0
# 13-04-39_0                     0      0
# 13-05-27_0                     2      0
# 13-07-39_0                     0      0
# 13-08-34_0                     0      0
# 13-09-20_0                     1      0
# 13-12-31_0                     0      0
# 13-14-43_0                     2      0
# 13-16-54_0                     2      0
# 13-19-06_0                     1      0
# 13-21-17_0                     5      0
# 13-23-29_0                     0      0
# 13-25-41_0                     1      0
# 13-27-52_0                     3      0
# 13-32-16_0                     2      0
# 13-34-27_0                     0      0
# 13-36-49_0                     3      0
# 13-39-00_0                     0      0
# 13-41-12_0                     1      0
# 13-42-45_0                     0      0
# 13-44-57_0                     0      0
# 13-47-08_0                     1      0
# 13-48-24_0                     0      0
# 📈 Generating Pipeline Ablation Plots...
# ETAPA DEL PIPELINE (CASCADA)                  | ERROR MEDIO     | FRAMES VIVOS    | PECES (TRACKS)
# ----------------------------------------------------------------------------------------------------
# 0. Base (HDBSCAN without filters)             |  3.63 ± 12.63 cm |   10187 frames |   206 tracks
# 1. + Filter: No Borders                       |  3.63 ± 12.63 cm |   10187 frames |   206 tracks
# 2. + Filter: No Overlap                       |  3.64 ± 12.66 cm |   10145 frames |   205 tracks
# 3. + Filter: is_3D_complete                   |  2.73 ± 6.54 cm |    9945 frames |   197 tracks
# 4. + Filter: Aspect Ratio >= 3.0              |  2.73 ± 6.66 cm |    9661 frames |   189 tracks
# 5. + Filter: Z-Angle <= 30.0º                 |  1.18 ± 1.66 cm |    7699 frames |   164 tracks
# 📈 Generating Thresholds Interaction Plot...
# Evaluating Angles: 100%|██████████| 9/9 [00:16<00:00,  1.84s/it]
# 📈 Generating Track Length Histogram...
# ======================================================================
# 📊 PLOTS FOR SCENARIO: SINGLE_FISH
# ======================================================================
# ============================================================
# 📊 TABLA 1: Distribución Global de Frames
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured      1908           68.31
# 1        short_track         0            0.00
# 2      incomplete_3D        82            2.94
# 3            borders       289           10.35
# 4            overlap         0            0.00
# 5  aspect_ratio_fail        84            3.01
# 6         angle_fail       430           15.40
# 7              other         0            0.00
# ============================================================
# 📊 TABLA 1: Distribución Global de Tracks
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured        37            37.0
# 1        short_track        38            38.0
# 2         not_a_fish         0             0.0
# 3      incomplete_3D         4             4.0
# 4     bad_pointcloud         0             0.0
# 5            borders        12            12.0
# 6            overlap         0             0.0
# 7  aspect_ratio_fail         0             0.0
# 8         angle_fail         9             9.0
# 9              other         0             0.0
# ============================================================
# 📊 TABLA 2: Desglose por Vídeo
# ============================================================
# track_failure_reason  measured  short_track  not_a_fish  incomplete_3D  \
# source_folder
# 12-52-36_0                   3            3           0              0
# 12-54-48_0                   6            8           0              0
# 12-57-00_0                   1            2           0              0
# 12-57-51_0                   1            2           0              0
# 12-58-48_0                   2            1           0              0
# 13-01-16_0                   3            1           0              0
# 13-02-27_0                   6            9           0              2
# 13-04-39_0                   2            0           0              0
# 13-05-27_0                   4            5           0              1
# 13-07-39_0                   2            1           0              0
# 13-08-34_0                   1            1           0              0
# 13-09-20_0                   1            0           0              0
# 13-12-31_0                   1            2           0              0
# 13-44-57_0                   4            3           0              1
#
# track_failure_reason  bad_pointcloud  borders  overlap  aspect_ratio_fail  \
# source_folder
# 12-52-36_0                         0        1        0                  0
# 12-54-48_0                         0        1        0                  0
# 12-57-00_0                         0        1        0                  0
# 12-57-51_0                         0        0        0                  0
# 12-58-48_0                         0        1        0                  0
# 13-01-16_0                         0        1        0                  0
# 13-02-27_0                         0        3        0                  0
# 13-04-39_0                         0        0        0                  0
# 13-05-27_0                         0        2        0                  0
# 13-07-39_0                         0        0        0                  0
# 13-08-34_0                         0        0        0                  0
# 13-09-20_0                         0        1        0                  0
# 13-12-31_0                         0        0        0                  0
# 13-44-57_0                         0        1        0                  0
#
# track_failure_reason  angle_fail  other
# source_folder
# 12-52-36_0                     1      0
# 12-54-48_0                     1      0
# 12-57-00_0                     0      0
# 12-57-51_0                     2      0
# 12-58-48_0                     0      0
# 13-01-16_0                     0      0
# 13-02-27_0                     2      0
# 13-04-39_0                     0      0
# 13-05-27_0                     2      0
# 13-07-39_0                     0      0
# 13-08-34_0                     0      0
# 13-09-20_0                     1      0
# 13-12-31_0                     0      0
# 13-44-57_0                     0      0
# 📈 Generating Pipeline Ablation Plots...
# ETAPA DEL PIPELINE (CASCADA)                  | ERROR MEDIO     | FRAMES VIVOS    | PECES (TRACKS)
# ----------------------------------------------------------------------------------------------------
# 0. Base (HDBSCAN without filters)             |  2.77 ± 8.22 cm |    3127 frames |    50 tracks
# 1. + Filter: No Borders                       |  2.77 ± 8.22 cm |    3127 frames |    50 tracks
# 2. + Filter: No Overlap                       |  2.77 ± 8.22 cm |    3127 frames |    50 tracks
# 3. + Filter: is_3D_complete                   |  2.47 ± 8.11 cm |    3070 frames |    47 tracks
# 4. + Filter: Aspect Ratio >= 3.0              |  2.47 ± 8.37 cm |    2985 frames |    44 tracks
# 5. + Filter: Z-Angle <= 30.0º                 |  1.01 ± 1.37 cm |    2542 frames |    38 tracks
# 📈 Generating Thresholds Interaction Plot...
# Evaluating Angles: 100%|██████████| 9/9 [00:03<00:00,  2.37it/s]
# 📈 Generating Track Length Histogram...
# ======================================================================
# 📊 PLOTS FOR SCENARIO: MULTIPLE_FISH
# ======================================================================
# ============================================================
# 📊 TABLA 1: Distribución Global de Frames
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured      4788           65.88
# 1        short_track         0            0.00
# 2      incomplete_3D       173            2.38
# 3            borders       590            8.12
# 4            overlap        21            0.29
# 5  aspect_ratio_fail       186            2.56
# 6         angle_fail      1510           20.78
# 7              other         0            0.00
# ============================================================
# 📊 TABLA 1: Distribución Global de Tracks
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured       119           54.59
# 1        short_track        52           23.85
# 2         not_a_fish         0            0.00
# 3      incomplete_3D         6            2.75
# 4     bad_pointcloud         9            4.13
# 5            borders         5            2.29
# 6            overlap         0            0.00
# 7  aspect_ratio_fail         6            2.75
# 8         angle_fail        21            9.63
# 9              other         0            0.00
# ============================================================
# 📊 TABLA 2: Desglose por Vídeo
# ============================================================
# track_failure_reason  measured  short_track  not_a_fish  incomplete_3D  \
# source_folder
# 13-14-43_0                   9            4           0              1
# 13-16-54_0                   9            7           0              1
# 13-19-06_0                   9            2           0              0
# 13-21-17_0                   6            4           0              1
# 13-23-29_0                  19            2           0              1
# 13-25-41_0                  16            8           0              0
# 13-27-52_0                   8            2           0              0
# 13-32-16_0                   8            7           0              0
# 13-34-27_0                   8            2           0              0
# 13-36-49_0                   8            0           0              1
# 13-39-00_0                   4            1           0              0
# 13-41-12_0                   2            2           0              1
# 13-42-45_0                   5            1           0              0
# 13-47-08_0                   4            6           0              0
# 13-48-24_0                   4            4           0              0
#
# track_failure_reason  bad_pointcloud  borders  overlap  aspect_ratio_fail  \
# source_folder
# 13-14-43_0                         1        1        0                  0
# 13-16-54_0                         0        2        0                  2
# 13-19-06_0                         1        0        0                  0
# 13-21-17_0                         0        1        0                  2
# 13-23-29_0                         2        0        0                  0
# 13-25-41_0                         4        1        0                  1
# 13-27-52_0                         0        0        0                  0
# 13-32-16_0                         1        0        0                  1
# 13-34-27_0                         0        0        0                  0
# 13-36-49_0                         0        0        0                  0
# 13-39-00_0                         0        0        0                  0
# 13-41-12_0                         0        0        0                  0
# 13-42-45_0                         0        0        0                  0
# 13-47-08_0                         0        0        0                  0
# 13-48-24_0                         0        0        0                  0
#
# track_failure_reason  angle_fail  other
# source_folder
# 13-14-43_0                     2      0
# 13-16-54_0                     2      0
# 13-19-06_0                     1      0
# 13-21-17_0                     5      0
# 13-23-29_0                     0      0
# 13-25-41_0                     1      0
# 13-27-52_0                     3      0
# 13-32-16_0                     2      0
# 13-34-27_0                     0      0
# 13-36-49_0                     3      0
# 13-39-00_0                     0      0
# 13-41-12_0                     1      0
# 13-42-45_0                     0      0
# 13-47-08_0                     1      0
# 13-48-24_0                     0      0
# 📈 Generating Pipeline Ablation Plots...
# ETAPA DEL PIPELINE (CASCADA)                  | ERROR MEDIO     | FRAMES VIVOS    | PECES (TRACKS)
# ----------------------------------------------------------------------------------------------------
# 0. Base (HDBSCAN without filters)             |  3.91 ± 13.75 cm |    7060 frames |   156 tracks
# 1. + Filter: No Borders                       |  3.91 ± 13.75 cm |    7060 frames |   156 tracks
# 2. + Filter: No Overlap                       |  3.92 ± 13.80 cm |    7018 frames |   155 tracks
# 3. + Filter: is_3D_complete                   |  2.81 ± 5.99 cm |    6875 frames |   150 tracks
# 4. + Filter: Aspect Ratio >= 3.0              |  2.81 ± 6.08 cm |    6676 frames |   145 tracks
# 5. + Filter: Z-Angle <= 30.0º                 |  1.23 ± 1.73 cm |    5157 frames |   126 tracks
# 📈 Generating Thresholds Interaction Plot...
# Evaluating Angles: 100%|██████████| 9/9 [00:10<00:00,  1.22s/it]
# 📈 Generating Track Length Histogram...
