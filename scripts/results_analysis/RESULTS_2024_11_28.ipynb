# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from termcolor import cprint
import results_analysis_utils as rutils
from IPython.display import display


# %load_ext autoreload
# %autoreload 2

# ===================================================================
# 1. CONFIGURATION
# ===================================================================
day_code = "2024_11_28" 
dataset_name = "DATASET_1" # O DATASET_2

ASPECT_RATIO_THR = 3.0
ANGLE_THR = 30.0

# Ruta al CSV crudo de este día concreto
csv_path = Path(f"/home/slimbook/fish_sizing/ARTICLE/{dataset_name}/{day_code}/{day_code}_ALL_raw_aggregated.csv")

cprint(f"👉 WORKING ON: {day_code}", "white", "on_blue", attrs=["bold"])
cprint(f"Reading csv from {csv_path}", "yellow")

# ===================================================================
# 2. FILTERING & AGGREGATION (Usando la misma lógica global)
# ===================================================================
# Le pasamos el nombre del día como 'dataset_name' para que la función imprima bonito

df_final, df_raw = rutils.load_and_filter_dataset(csv_path, 
                                                  dataset_name=day_code,
                                                  recalculate_failure_reason=True, 
                                                  aspect_ratio_thr=ASPECT_RATIO_THR, 
                                                  angle_thr=ANGLE_THR, 
                                                  save=False)

if df_raw.empty:
    raise ValueError("No data found for this day!")

# ===================================================================
# 3. DAILY SUMMARY TABLE (Single vs Multiple)
# ===================================================================
print("\n" + "="*85)
print(f"DAILY SUMMARY: {day_code}")
print("="*85)
print(f"{'SCENARIO':<15} | {'Total Tracks':<12} | {'Measured':<10} | {'Success (%)':<12} | {'MAE (cm)':<10} | {'STD (cm)':<10} | {'MAPE (%)':<10}")
print("-" * 85)

scenarios = ['All']
if 'scenario' in df_raw.columns:
    scenarios.extend(df_raw['scenario'].dropna().unique().tolist())

for sc in scenarios:
    # 1. Contar totales desde el RAW
    if sc == 'All':
        total_tracks = df_raw['track_uid'].nunique()
        sub_final = df_final
    else:
        total_tracks = df_raw[df_raw['scenario'] == sc]['track_uid'].nunique()
        sub_final = df_final[df_final['scenario'] == sc] if not df_final.empty else pd.DataFrame()
            
    # 2. Contar medidos desde el FINAL
    measured_tracks = len(sub_final)
    
    # 3. Calcular métricas
    if measured_tracks > 0:
        mae = sub_final['abs_error_cm'].mean()
        std = sub_final['abs_error_cm'].std()
        mape = sub_final['rel_error_perc'].mean()
    else:
        mae = std = mape = 0.0
        
    success_perc = (measured_tracks / total_tracks * 100) if total_tracks > 0 else 0
    
    label = f"GLOBAL DAY" if sc == 'All' else sc
    print(f"{label:<15} | {total_tracks:<12} | {measured_tracks:<10} | {success_perc:<12.1f} | {mae:<10.2f} | {std:<10.2f} | {mape:<10.2f}")

print("="*85 + "\n")


for sc in scenarios:
    cprint(f"\n\n{'='*70}", "white", "on_magenta", attrs=["bold"])
    cprint(f"📊 PLOTS FOR SCENARIO: {sc.upper()}", "white", "on_magenta", attrs=["bold"])
    cprint(f"{'='*70}", "white", "on_magenta", attrs=["bold"])
    
    # 1. Filtrar el dataframe dependiendo del escenario
    if sc == 'All':
        df_sc_raw = df_raw.copy()
        context_label = f"{day_code} - GLOBAL"
    else:
        df_sc_raw = df_raw[df_raw['scenario'] == sc].copy()
        context_label = f"{day_code} - {sc.upper()}"
        
    if df_sc_raw.empty:
        print(f"⚠️ No data available for {sc.upper()}, skipping plots.")
        continue
    
    # 2. Generar gráficos
    stacked_frames = rutils.plot_frame_failures(
        df_sc_raw, 
        aspect_ratio_thr=ASPECT_RATIO_THR, 
        angle_thr=ANGLE_THR,
        figsize_video=(12,6), 
        figsize_global=(5,5), 
        show_global=True,
        context_label=context_label
    )

    track_failures = rutils.plot_tracks_failure_distribution(
        df_sc_raw, 
        aspect_ratio_thr=ASPECT_RATIO_THR, 
        angle_thr=ANGLE_THR,
        show_global=True, 
        figsize_video=(12,6), 
        figsize_global=(5,5),
        context_label=context_label
    )

    rutils.plot_aspect_ratio_vs_length(
        df_sc_raw, 
        ASPECT_RATIO_THR=ASPECT_RATIO_THR, 
        figsize=(10, 8),
        context_label=context_label
    ) 
    
    # 1. Gráfica de Cascada (Ablation)
    print("\n📈 Generating Pipeline Ablation Plots...")
    stages_dict, agg_stages_dict = rutils.plot_ablation_pipeline(
        df_sc_raw, 
        ASPECT_RATIO_THR=ASPECT_RATIO_THR, 
        ANGLE_THR=ANGLE_THR,
        context_label=context_label  
    )
    
    # 2. Interacción de umbrales
    print("\n📈 Generating Thresholds Interaction Plot...")
    rutils.plot_thresholds_interaction(
        df_sc_raw, 
        optimal_ar=ASPECT_RATIO_THR, 
        context=context_label
    )
    
    # 3. Relación de Error vs Geometría (Raw y Aislado)
    print("\n📈 Generating Error vs Geometry Analysis Plots...")
    rutils.plot_error_vs_geometry(
        df_sc_raw, 
        ar_thr=ASPECT_RATIO_THR, 
        angle_thr=ANGLE_THR, 
        context_label=context_label
    )
    
    print("\n📈 Generating Track Error vs Length Plot...")
    rutils.plot_error_vs_track_length(
        df_raw=df_sc_raw, 
        df_final=sub_final,  # <--- ¡AQUÍ LE PASAMOS TU CÁLCULO INTELIGENTE!
        context_label=context_label,
        min_frames_thr=5
    )
    
    print("\n📈 Generating Track Length Histogram...")
    rutils.plot_track_length_histogram(
        df_sc_raw, 
        min_frames_thr=5, # O el número que uses en el smart_aggregator
        context_label=context_label
    )
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 👉 WORKING ON: 2024_11_28
# Reading csv from /home/slimbook/fish_sizing/ARTICLE/DATASET_1/2024_11_28/2024_11_28_ALL_raw_aggregated.csv
#
# --- Processing 2024_11_28 ---
# Total raw frames with valid GT: 11404
# Total initial tracks: 266
# Frames belonging to 'measured' tracks: 5311
# 📉 Tracks descartados por 'track_failure_from_frames': 130
# 📉 Tracks descartados por 'smart_aggregator': 0
# ✅ FINAL RESULT: 136 independent FISH (tracks) successfully aggregated.
# 📊 Success Rate: 51.13% (136/266 tracks medidos con éxito)
#
# =====================================================================================
# DAILY SUMMARY: 2024_11_28
# =====================================================================================
# SCENARIO        | Total Tracks | Measured   | Success (%)  | MAE (cm)   | STD (cm)   | MAPE (%)
# -------------------------------------------------------------------------------------
# GLOBAL DAY      | 266          | 136        | 51.1         | 1.20       | 1.68       | 4.65
# single_fish     | 100          | 38         | 38.0         | 1.01       | 1.37       | 3.49
# multiple_fish   | 166          | 98         | 59.0         | 1.27       | 1.78       | 5.09
# =====================================================================================
#
#
#
# ======================================================================
# 📊 PLOTS FOR SCENARIO: ALL
# ======================================================================
# ============================================================
# 📊 TABLA 1: Distribución Global de Frames
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured      5467           47.94
# 1      incomplete_3D       102            0.89
# 2            borders       872            7.65
# 3            overlap        41            0.36
# 4  aspect_ratio_fail      3443           30.19
# 5         angle_fail      1169           10.25
# 6        short_track         0            0.00
# 7              other       310            2.72
# ============================================================
# 📊 TABLA 1: Distribución Global de Tracks
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured       136           51.13
# 1      incomplete_3D         1            0.38
# 2            borders        35           13.16
# 3            overlap         0            0.00
# 4  aspect_ratio_fail        57           21.43
# 5         angle_fail        29           10.90
# 6        short_track         7            2.63
# 7              other         1            0.38
# ============================================================
# 📊 TABLA 2: Desglose por Vídeo
# ============================================================
# track_failure_reason  measured  incomplete_3D  borders  overlap  \
# source_folder
# 12-52-36_0                   3              0        4        0
# 12-54-48_0                   6              0        2        0
# 12-57-00_0                   1              0        1        0
# 12-57-51_0                   1              0        0        0
# 12-58-48_0                   2              0        2        0
# 13-01-16_0                   3              0        1        0
# 13-02-27_0                   6              0        9        0
# 13-04-39_0                   2              0        0        0
# 13-05-27_0                   5              0        4        0
# 13-07-39_0                   2              0        1        0
# 13-08-34_0                   1              0        1        0
# 13-09-20_0                   1              0        1        0
# 13-12-31_0                   1              0        2        0
# 13-14-43_0                   6              0        0        0
# 13-16-54_0                   5              0        2        0
# 13-19-06_0                  10              0        0        0
# 13-21-17_0                   7              0        1        0
# 13-23-29_0                  20              0        0        0
# 13-25-41_0                  20              0        1        0
# 13-27-52_0                   6              0        0        0
# 13-32-16_0                   3              0        0        0
# 13-34-27_0                   4              0        0        0
# 13-36-49_0                   4              0        0        0
# 13-39-00_0                   2              0        0        0
# 13-41-12_0                   1              1        0        0
# 13-42-45_0                   3              0        0        0
# 13-44-57_0                   4              0        3        0
# 13-47-08_0                   4              0        0        0
# 13-48-24_0                   3              0        0        0
#
# track_failure_reason  aspect_ratio_fail  angle_fail  short_track  other
# source_folder
# 12-52-36_0                            0           1            0      0
# 12-54-48_0                            1           4            3      0
# 12-57-00_0                            1           0            1      0
# 12-57-51_0                            1           2            1      0
# 12-58-48_0                            0           0            0      0
# 13-01-16_0                            0           0            1      0
# 13-02-27_0                            2           4            1      0
# 13-04-39_0                            0           0            0      0
# 13-05-27_0                            2           3            0      0
# 13-07-39_0                            0           0            0      0
# 13-08-34_0                            0           0            0      0
# 13-09-20_0                            0           1            0      0
# 13-12-31_0                            0           0            0      0
# 13-14-43_0                            8           0            0      0
# 13-16-54_0                            9           0            0      0
# 13-19-06_0                            0           1            0      0
# 13-21-17_0                            2           5            0      0
# 13-23-29_0                            1           1            0      0
# 13-25-41_0                            0           2            0      0
# 13-27-52_0                            5           0            0      0
# 13-32-16_0                            8           0            0      1
# 13-34-27_0                            4           0            0      0
# 13-36-49_0                            6           2            0      0
# 13-39-00_0                            2           0            0      0
# 13-41-12_0                            2           0            0      0
# 13-42-45_0                            2           0            0      0
# 13-44-57_0                            0           2            0      0
# 13-47-08_0                            0           1            0      0
# 13-48-24_0                            1           0            0      0
# 📈 Generating Pipeline Ablation Plots...
# ETAPA DEL PIPELINE (CASCADA)                  | ERROR MEDIO     | FRAMES VIVOS    | PECES (TRACKS)
# ----------------------------------------------------------------------------------------------------
# 0. Base (HDBSCAN without filters)             |  3.09 ± 11.92 cm |   10067 frames |   206 tracks
# 1. + Filter: No Borders                       |  3.09 ± 11.92 cm |   10067 frames |   206 tracks
# 2. + Filter: No Overlap                       |  3.10 ± 11.95 cm |   10027 frames |   205 tracks
# 3. + Filter: is_3D_complete                   |  2.49 ± 6.20 cm |    9832 frames |   197 tracks
# 4. + Filter: Aspect Ratio >= 3.0              |  2.16 ± 5.53 cm |    6593 frames |   156 tracks
# 5. + Filter: Z-Angle <= 30.0º                 |  1.20 ± 1.68 cm |    5467 frames |   136 tracks
# 📈 Generating Thresholds Interaction Plot...
# Evaluating Angles: 100%|██████████| 9/9 [00:16<00:00,  1.79s/it]
# 📈 Generating Error vs Geometry Analysis Plots...
# 📈 Generating Track Error vs Length Plot...
# 📈 Generating Track Length Histogram...
# ======================================================================
# 📊 PLOTS FOR SCENARIO: SINGLE_FISH
# ======================================================================
# ============================================================
# 📊 TABLA 1: Distribución Global de Frames
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured      2542           71.83
# 1      incomplete_3D        48            1.36
# 2            borders       289            8.17
# 3            overlap         0            0.00
# 4  aspect_ratio_fail       111            3.14
# 5         angle_fail       456           12.88
# 6        short_track         0            0.00
# 7              other        93            2.63
# ============================================================
# 📊 TABLA 1: Distribución Global de Tracks
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured        38            38.0
# 1      incomplete_3D         0             0.0
# 2            borders        31            31.0
# 3            overlap         0             0.0
# 4  aspect_ratio_fail         7             7.0
# 5         angle_fail        17            17.0
# 6        short_track         7             7.0
# 7              other         0             0.0
# ============================================================
# 📊 TABLA 2: Desglose por Vídeo
# ============================================================
# track_failure_reason  measured  incomplete_3D  borders  overlap  \
# source_folder
# 12-52-36_0                   3              0        4        0
# 12-54-48_0                   6              0        2        0
# 12-57-00_0                   1              0        1        0
# 12-57-51_0                   1              0        0        0
# 12-58-48_0                   2              0        2        0
# 13-01-16_0                   3              0        1        0
# 13-02-27_0                   6              0        9        0
# 13-04-39_0                   2              0        0        0
# 13-05-27_0                   5              0        4        0
# 13-07-39_0                   2              0        1        0
# 13-08-34_0                   1              0        1        0
# 13-09-20_0                   1              0        1        0
# 13-12-31_0                   1              0        2        0
# 13-44-57_0                   4              0        3        0
#
# track_failure_reason  aspect_ratio_fail  angle_fail  short_track  other
# source_folder
# 12-52-36_0                            0           1            0      0
# 12-54-48_0                            1           4            3      0
# 12-57-00_0                            1           0            1      0
# 12-57-51_0                            1           2            1      0
# 12-58-48_0                            0           0            0      0
# 13-01-16_0                            0           0            1      0
# 13-02-27_0                            2           4            1      0
# 13-04-39_0                            0           0            0      0
# 13-05-27_0                            2           3            0      0
# 13-07-39_0                            0           0            0      0
# 13-08-34_0                            0           0            0      0
# 13-09-20_0                            0           1            0      0
# 13-12-31_0                            0           0            0      0
# 13-44-57_0                            0           2            0      0
# 📈 Generating Pipeline Ablation Plots...
# ETAPA DEL PIPELINE (CASCADA)                  | ERROR MEDIO     | FRAMES VIVOS    | PECES (TRACKS)
# ----------------------------------------------------------------------------------------------------
# 0. Base (HDBSCAN without filters)             |  1.66 ± 2.96 cm |    3127 frames |    50 tracks
# 1. + Filter: No Borders                       |  1.66 ± 2.96 cm |    3127 frames |    50 tracks
# 2. + Filter: No Overlap                       |  1.66 ± 2.96 cm |    3127 frames |    50 tracks
# 3. + Filter: is_3D_complete                   |  2.46 ± 8.11 cm |    3070 frames |    47 tracks
# 4. + Filter: Aspect Ratio >= 3.0              |  2.46 ± 8.37 cm |    2985 frames |    44 tracks
# 5. + Filter: Z-Angle <= 30.0º                 |  1.01 ± 1.37 cm |    2542 frames |    38 tracks
# 📈 Generating Thresholds Interaction Plot...
# Evaluating Angles: 100%|██████████| 9/9 [00:05<00:00,  1.51it/s]
# 📈 Generating Error vs Geometry Analysis Plots...
# 📈 Generating Track Error vs Length Plot...
# 📈 Generating Track Length Histogram...
# ======================================================================
# 📊 PLOTS FOR SCENARIO: MULTIPLE_FISH
# ======================================================================
# ============================================================
# 📊 TABLA 1: Distribución Global de Frames
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured      2925           37.19
# 1      incomplete_3D        54            0.69
# 2            borders       583            7.41
# 3            overlap        41            0.52
# 4  aspect_ratio_fail      3332           42.36
# 5         angle_fail       713            9.07
# 6        short_track         0            0.00
# 7              other       217            2.76
# ============================================================
# 📊 TABLA 1: Distribución Global de Tracks
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured        98           59.04
# 1      incomplete_3D         1            0.60
# 2            borders         4            2.41
# 3            overlap         0            0.00
# 4  aspect_ratio_fail        50           30.12
# 5         angle_fail        12            7.23
# 6        short_track         0            0.00
# 7              other         1            0.60
# ============================================================
# 📊 TABLA 2: Desglose por Vídeo
# ============================================================
# track_failure_reason  measured  incomplete_3D  borders  overlap  \
# source_folder
# 13-14-43_0                   6              0        0        0
# 13-16-54_0                   5              0        2        0
# 13-19-06_0                  10              0        0        0
# 13-21-17_0                   7              0        1        0
# 13-23-29_0                  20              0        0        0
# 13-25-41_0                  20              0        1        0
# 13-27-52_0                   6              0        0        0
# 13-32-16_0                   3              0        0        0
# 13-34-27_0                   4              0        0        0
# 13-36-49_0                   4              0        0        0
# 13-39-00_0                   2              0        0        0
# 13-41-12_0                   1              1        0        0
# 13-42-45_0                   3              0        0        0
# 13-47-08_0                   4              0        0        0
# 13-48-24_0                   3              0        0        0
#
# track_failure_reason  aspect_ratio_fail  angle_fail  short_track  other
# source_folder
# 13-14-43_0                            8           0            0      0
# 13-16-54_0                            9           0            0      0
# 13-19-06_0                            0           1            0      0
# 13-21-17_0                            2           5            0      0
# 13-23-29_0                            1           1            0      0
# 13-25-41_0                            0           2            0      0
# 13-27-52_0                            5           0            0      0
# 13-32-16_0                            8           0            0      1
# 13-34-27_0                            4           0            0      0
# 13-36-49_0                            6           2            0      0
# 13-39-00_0                            2           0            0      0
# 13-41-12_0                            2           0            0      0
# 13-42-45_0                            2           0            0      0
# 13-47-08_0                            0           1            0      0
# 13-48-24_0                            1           0            0      0
# 📈 Generating Pipeline Ablation Plots...
# ETAPA DEL PIPELINE (CASCADA)                  | ERROR MEDIO     | FRAMES VIVOS    | PECES (TRACKS)
# ----------------------------------------------------------------------------------------------------
# 0. Base (HDBSCAN without filters)             |  3.55 ± 13.57 cm |    6940 frames |   156 tracks
# 1. + Filter: No Borders                       |  3.55 ± 13.57 cm |    6940 frames |   156 tracks
# 2. + Filter: No Overlap                       |  3.57 ± 13.62 cm |    6900 frames |   155 tracks
# 3. + Filter: is_3D_complete                   |  2.49 ± 5.51 cm |    6762 frames |   150 tracks
# 4. + Filter: Aspect Ratio >= 3.0              |  2.04 ± 3.93 cm |    3608 frames |   112 tracks
# 5. + Filter: Z-Angle <= 30.0º                 |  1.27 ± 1.78 cm |    2925 frames |    98 tracks
# 📈 Generating Thresholds Interaction Plot...
# Evaluating Angles: 100%|██████████| 9/9 [00:13<00:00,  1.45s/it]
# 📈 Generating Error vs Geometry Analysis Plots...
# 📈 Generating Track Error vs Length Plot...
# 📈 Generating Track Length Histogram...
