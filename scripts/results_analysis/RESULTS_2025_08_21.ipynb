# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from termcolor import cprint
import results_analysis_utils as rutils
from IPython.display import display


# %load_ext autoreload
# %autoreload 2

# ===================================================================
# 1. CONFIGURATION
# ===================================================================
day_code = "2025_08_21" 
dataset_name = "DATASET_2" # O DATASET_2

ASPECT_RATIO_THR = 3.0
ANGLE_THR = 30.0

# Ruta al CSV crudo de este día concreto
csv_path = Path(f"/home/slimbook/fish_sizing/ARTICLE/{dataset_name}/{day_code}/{day_code}_ALL_raw_aggregated.csv")

cprint(f"👉 WORKING ON: {day_code}", "white", "on_blue", attrs=["bold"])
cprint(f"Reading csv from {csv_path}", "yellow")

# ===================================================================
# 2. FILTERING & AGGREGATION (Usando la misma lógica global)
# ===================================================================
# Le pasamos el nombre del día como 'dataset_name' para que la función imprima bonito

df_final, df_raw = rutils.load_and_filter_dataset(csv_path, 
                                                  dataset_name=day_code,
                                                  recalculate_failure_reason=True, 
                                                  aspect_ratio_thr=ASPECT_RATIO_THR, 
                                                  angle_thr=ANGLE_THR, 
                                                  save=False)

if df_raw.empty:
    raise ValueError("No data found for this day!")

# ===================================================================
# 3. DAILY SUMMARY TABLE (Single vs Multiple)
# ===================================================================
print("\n" + "="*85)
print(f"DAILY SUMMARY: {day_code}")
print("="*85)
print(f"{'SCENARIO':<15} | {'Total Tracks':<12} | {'Measured':<10} | {'Success (%)':<12} | {'MAE (cm)':<10} | {'STD (cm)':<10} | {'MAPE (%)':<10}")
print("-" * 85)

scenarios = ['All']
if 'scenario' in df_raw.columns:
    scenarios.extend(df_raw['scenario'].dropna().unique().tolist())

for sc in scenarios:
    # 1. Contar totales desde el RAW
    if sc == 'All':
        total_tracks = df_raw['track_uid'].nunique()
        sub_final = df_final
    else:
        total_tracks = df_raw[df_raw['scenario'] == sc]['track_uid'].nunique()
        sub_final = df_final[df_final['scenario'] == sc] if not df_final.empty else pd.DataFrame()
            
    # 2. Contar medidos desde el FINAL
    measured_tracks = len(sub_final)
    
    # 3. Calcular métricas
    if measured_tracks > 0:
        mae = sub_final['abs_error_cm'].mean()
        std = sub_final['abs_error_cm'].std()
        mape = sub_final['rel_error_perc'].mean()
    else:
        mae = std = mape = 0.0
        
    success_perc = (measured_tracks / total_tracks * 100) if total_tracks > 0 else 0
    
    label = f"GLOBAL DAY" if sc == 'All' else sc
    print(f"{label:<15} | {total_tracks:<12} | {measured_tracks:<10} | {success_perc:<12.1f} | {mae:<10.2f} | {std:<10.2f} | {mape:<10.2f}")

print("="*85 + "\n")


for sc in scenarios:
    cprint(f"\n\n{'='*70}", "white", "on_magenta", attrs=["bold"])
    cprint(f"📊 PLOTS FOR SCENARIO: {sc.upper()}", "white", "on_magenta", attrs=["bold"])
    cprint(f"{'='*70}", "white", "on_magenta", attrs=["bold"])
    
    # 1. Filtrar el dataframe dependiendo del escenario
    if sc == 'All':
        df_sc_raw = df_raw.copy()
        context_label = f"{day_code} - GLOBAL"
    else:
        df_sc_raw = df_raw[df_raw['scenario'] == sc].copy()
        context_label = f"{day_code} - {sc.upper()}"
        
    if df_sc_raw.empty:
        print(f"⚠️ No data available for {sc.upper()}, skipping plots.")
        continue
    
    # 2. Generar gráficos
    stacked_frames = rutils.plot_frame_failures(
        df_sc_raw, 
        aspect_ratio_thr=ASPECT_RATIO_THR, 
        angle_thr=ANGLE_THR,
        figsize_video=(12,6), 
        figsize_global=(5,5), 
        show_global=True,
        context_label=context_label
    )

    track_failures = rutils.plot_tracks_failure_distribution(
        df_sc_raw, 
        aspect_ratio_thr=ASPECT_RATIO_THR, 
        angle_thr=ANGLE_THR,
        show_global=True, 
        figsize_video=(12,6), 
        figsize_global=(5,5),
        context_label=context_label
    )

    rutils.plot_aspect_ratio_vs_length(
        df_sc_raw, 
        ASPECT_RATIO_THR=ASPECT_RATIO_THR, 
        figsize=(10, 8),
        context_label=context_label
    ) 
    
    # 1. Gráfica de Cascada (Ablation)
    print("\n📈 Generating Pipeline Ablation Plots...")
    stages_dict, agg_stages_dict = rutils.plot_ablation_pipeline(
        df_sc_raw, 
        ASPECT_RATIO_THR=ASPECT_RATIO_THR, 
        ANGLE_THR=ANGLE_THR,
        context_label=context_label  
    )
    
    # 2. Interacción de umbrales
    print("\n📈 Generating Thresholds Interaction Plot...")
    rutils.plot_thresholds_interaction(
        df_sc_raw, 
        optimal_ar=ASPECT_RATIO_THR, 
        context=context_label
    )
    
    # 3. Relación de Error vs Geometría (Raw y Aislado)
    print("\n📈 Generating Error vs Geometry Analysis Plots...")
    rutils.plot_error_vs_geometry(
        df_sc_raw, 
        ar_thr=ASPECT_RATIO_THR, 
        angle_thr=ANGLE_THR, 
        context_label=context_label
    )
    
    print("\n📈 Generating Track Error vs Length Plot...")
    rutils.plot_error_vs_track_length(
        df_raw=df_sc_raw, 
        df_final=sub_final,  # <--- ¡AQUÍ LE PASAMOS TU CÁLCULO INTELIGENTE!
        context_label=context_label,
        min_frames_thr=6
    )
    
    print("\n📈 Generating Track Length Histogram...")
    rutils.plot_track_length_histogram(
        df_sc_raw, 
        min_frames_thr=5, # O el número que uses en el smart_aggregator
        context_label=context_label
    )
# Out:
# 👉 WORKING ON: 2025_08_21
# Reading csv from /home/slimbook/fish_sizing/ARTICLE/DATASET_2/2025_08_21/2025_08_21_ALL_raw_aggregated.csv
#
# --- Processing 2025_08_21 ---
# Total raw frames with valid GT: 26016
# Total initial tracks: 189
# Frames belonging to 'measured' tracks: 4001
# 📉 Tracks descartados por 'track_failure_from_frames': 90
# 📉 Tracks descartados por 'smart_aggregator': 0
# ✅ FINAL RESULT: 99 independent FISH (tracks) successfully aggregated.
# 📊 Success Rate: 52.38% (99/189 tracks medidos con éxito)
#
# =====================================================================================
# DAILY SUMMARY: 2025_08_21
# =====================================================================================
# SCENARIO        | Total Tracks | Measured   | Success (%)  | MAE (cm)   | STD (cm)   | MAPE (%)
# -------------------------------------------------------------------------------------
# GLOBAL DAY      | 189          | 99         | 52.4         | 1.36       | 1.83       | 4.58
# single_fish     | 57           | 27         | 47.4         | 1.63       | 2.58       | 5.59
# multiple_fish   | 132          | 72         | 54.5         | 1.26       | 1.47       | 4.21
# =====================================================================================
#
#
#
# ======================================================================
# 📊 PLOTS FOR SCENARIO: ALL
# ======================================================================
# ============================================================
# 📊 TABLA 1: Distribución Global de Frames
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured
# 13-54-05_0_compressed                  1            0           0
# 13-55-37_0_compressed                  1            0           0
# 13-57-08_0_compressed                  1            0           0
# 13-58-40_0_compressed                  1            0           0
#
# track_failure_reason            incomplete_3D  bad_pointcloud  borders  \
# source_folder
# 10-01-53_0_compressed-r201-end              0               0        1
# 10-07-59_0-r50-end                          0               0        0
# 10-09-31_0-r0-344                           0               0        0
# 10-09-31_0-r398-end                         0               0        0
# 10-11-02_0-r0-244                           0               0        0
# 10-11-02_0-r295-end                         0               0        2
# 10-12-34_0-r215-end                         0               0        0
# 10-14-05_0-r0-528                           0               0        0
# 10-15-37_0-r496-end                         0               0        0
# 10-18-24_0_compressed-r47-end               0               0        0
# 10-19-44_0_compressed-r383-534              0               0        0
# 10-19-44_0_compressed-r588-end              0               0        0
# 10-20-29_1_compressed-r0-78                 0               0        0
# 10-22-00_1_compressed                       0               0        0
# 10-37-15_1-r                                0               0        1
# 12-07-32_0                                  0               0        0
# 12-08-05_1                                  1               0        0
# 12-09-03_0_compressed                       0               0        0
# 12-09-37_1_compressed                       0               0        0
# 12-10-35_0_compressed                       0               0        0
# 12-11-09_1_compressed                       0               0        0
# 12-12-06_0_compressed                       0               0        0
# 12-12-40_1_compressed                       0               0        0
# 12-13-38_0_compressed                       0               0        0
# 12-14-12_1_compressed                       0               0        0
# 12-15-10_0_compressed                       0               0        0
# 12-15-43_1_compressed                       0               0        0
# 13-05-55_0-r                                0               0        0
# 13-22-22_0_compressed-r378-463              0               0        0
# 13-22-22_0_compressed-r60-297               0               0        0
# 13-23-54_0_compressed-r0-304                0               0        0
# 13-23-54_0_compressed-r450-524              0               0        0
# 13-23-54_0_compressed-r602-end              0               0        0
# 13-33-04_0                                  0               0        0
# 13-33-43_1                                  0               0        0
# 13-34-25_0_compressed                       0               0        0
# 13-35-09_1_compressed                       0               0        0
# 13-35-56_0_compressed                       0               0        0
# 13-36-41_1_compressed                       0               0        0
# 13-37-28_0_compressed                       0               0        0
# 13-38-13_1_compressed                       0               0        0
# 13-38-54_0_compressed                       0               0        0
# 13-40-21_0_compressed                       0               0        0
# 13-41-52_0_compressed                       0               0        0
# 13-43-24_0_compressed                       0               0        0
# 13-44-56_0_compressed                       0               0        0
# 13-46-27_0_compressed                       0               0        0
# 13-47-59_0_compressed                       0               0        0
# 13-49-30_0_compressed                       0               0        0
# 13-51-02_0_compressed                       0               0        0
# 13-52-34_0_compressed                       0               0        0
# 13-54-05_0_compressed                       0               0        0
# 13-55-37_0_compressed                       0               0        0
# 13-57-08_0_compressed                       0               0        0
# 13-58-40_0_compressed                       0               0        0
#
# track_failure_reason            overlap  aspect_ratio_fail  angle_fail  other
# source_folder
# 10-01-53_0_compressed-r201-end        1                  3           0      0
# 10-07-59_0-r50-end                    4                  3           0      0
# 10-09-31_0-r0-344                     1                  4           0      0
# 10-09-31_0-r398-end                   0                  0           1      0
# 10-11-02_0-r0-244                     2                  1           0      0
# 10-11-02_0-r295-end                   1                  0           0      0
# 10-12-34_0-r215-end                   1                  0           0      0
# 10-14-05_0-r0-528                     0                  3           0      0
# 10-15-37_0-r496-end                   0                  2           0      0
# 10-18-24_0_compressed-r47-end         0                  3           0      0
# 10-19-44_0_compressed-r383-534        0                  0           0      0
# 10-19-44_0_compressed-r588-end        0                  0           0      0
# 10-20-29_1_compressed-r0-78           0                  3           0      0
# 10-22-00_1_compressed                 0                  1           0      0
# 10-37-15_1-r                          0                  0           0      0
# 12-07-32_0                            0                  0           0      0
# 12-08-05_1                            0                  0           1      0
# 12-09-03_0_compressed                 0                  0           0      0
# 12-09-37_1_compressed                 0                  0           0      0
# 12-10-35_0_compressed                 0                  4           0      0
# 12-11-09_1_compressed                 0                  2           0      0
# 12-12-06_0_compressed                 0                  1           0      0
# 12-12-40_1_compressed                 0                  1           0      0
# 12-13-38_0_compressed                 0                  0           0      0
# 12-14-12_1_compressed                 0                  1           0      0
# 12-15-10_0_compressed                 0                  2           0      0
# 12-15-43_1_compressed                 0                  2           0      0
# 13-05-55_0-r                          4                  2           0      0
# 13-22-22_0_compressed-r378-463        0                  2           0      0
# 13-22-22_0_compressed-r60-297         1                  1           1      0
# 13-23-54_0_compressed-r0-304          3                  0           0      0
# 13-23-54_0_compressed-r450-524        0                  0           0      0
# 13-23-54_0_compressed-r602-end        0                  1           0      0
# 13-33-04_0                            0                  0           0      0
# 13-33-43_1                            0                  0           0      0
# 13-34-25_0_compressed                 0                  0           0      0
# 13-35-09_1_compressed                 0                  0           1      0
# 13-35-56_0_compressed                 0                  1           0      0
# 13-36-41_1_compressed                 0                  0           0      0
# 13-37-28_0_compressed                 0                  0           0      0
# 13-38-13_1_compressed                 0                  0           0      0
# 13-38-54_0_compressed                 0                  0           0      0
# 13-40-21_0_compressed                 0                  0           0      0
# 13-41-52_0_compressed                 0                  1           0      0
# 13-43-24_0_compressed                 0                  0           0      0
# 13-44-56_0_compressed                 0                  1           0      0
# 13-46-27_0_compressed                 0                  1           0      0
# 13-47-59_0_compressed                 0                  1           0      0
# 13-49-30_0_compressed                 0                  1           0      0
# 13-51-02_0_compressed                 0                  2           0      0
# 13-52-34_0_compressed                 0                  0           0      0
# 13-54-05_0_compressed                 0                  0           0      0
# 13-55-37_0_compressed                 0                  0           0      0
# 13-57-08_0_compressed                 0                  0           0      0
# 13-58-40_0_compressed                 0                  0           0      0
# 📈 Generating Pipeline Ablation Plots...
# ETAPA DEL PIPELINE (CASCADA)                  | ERROR MEDIO     | FRAMES VIVOS    | PECES (TRACKS)
# ----------------------------------------------------------------------------------------------------
# 0. Base (HDBSCAN without filters)             |  2.54 ± 3.12 cm |   24416 frames |   173 tracks
# 1. + Filter: No Borders                       |  2.54 ± 3.12 cm |   24416 frames |   173 tracks
# 2. + Filter: No Overlap                       |  2.45 ± 3.06 cm |   21778 frames |   164 tracks
# 3. + Filter: is_3D_complete                   |  2.48 ± 3.09 cm |   21497 frames |   164 tracks
# 4. + Filter: Aspect Ratio >= 3.0              |  1.55 ± 1.90 cm |    9281 frames |   120 tracks
# 5. + Filter: Z-Angle <= 30.0º                 |  1.38 ± 1.74 cm |    4504 frames |   102 tracks
# 📈 Generating Thresholds Interaction Plot...
# Evaluating Angles: 100%|██████████| 9/9 [00:08<00:00,  1.02it/s]
# 📈 Generating Error vs Geometry Analysis Plots...
# 📈 Generating Track Error vs Length Plot...
# 📈 Generating Track Length Histogram...
# ======================================================================
# 📊 PLOTS FOR SCENARIO: SINGLE_FISH
# ======================================================================
# ============================================================
# 📊 TABLA 1: Distribución Global de Frames
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured
# 13-37-28_0_compressed               0        0        0                  0
# 13-38-13_1_compressed               0        0        0                  0
# 13-38-54_0_compressed               0        0        0                  0
# 13-40-21_0_compressed               0        0        0                  0
# 13-41-52_0_compressed               0        0        0                  1
# 13-43-24_0_compressed               0        0        0                  0
# 13-44-56_0_compressed               0        0        0                  1
# 13-46-27_0_compressed               0        0        0                  1
# 13-47-59_0_compressed               0        0        0                  1
# 13-49-30_0_compressed               0        0        0                  1
# 13-51-02_0_compressed               0        0        0                  2
# 13-52-34_0_compressed               0        0        0                  0
# 13-54-05_0_compressed               0        0        0                  0
# 13-55-37_0_compressed               0        0        0                  0
# 13-57-08_0_compressed               0        0        0                  0
# 13-58-40_0_compressed               0        0        0                  0
#
# track_failure_reason   angle_fail  other
# source_folder
# 12-07-32_0                      0      0
# 12-08-05_1                      1      0
# 12-09-03_0_compressed           0      0
# 12-09-37_1_compressed           0      0
# 12-10-35_0_compressed           0      0
# 12-11-09_1_compressed           0      0
# 12-12-06_0_compressed           0      0
# 12-12-40_1_compressed           0      0
# 12-13-38_0_compressed           0      0
# 12-14-12_1_compressed           0      0
# 12-15-10_0_compressed           0      0
# 12-15-43_1_compressed           0      0
# 13-33-04_0                      0      0
# 13-33-43_1                      0      0
# 13-34-25_0_compressed           0      0
# 13-35-09_1_compressed           1      0
# 13-35-56_0_compressed           0      0
# 13-36-41_1_compressed           0      0
# 13-37-28_0_compressed           0      0
# 13-38-13_1_compressed           0      0
# 13-38-54_0_compressed           0      0
# 13-40-21_0_compressed           0      0
# 13-41-52_0_compressed           0      0
# 13-43-24_0_compressed           0      0
# 13-44-56_0_compressed           0      0
# 13-46-27_0_compressed           0      0
# 13-47-59_0_compressed           0      0
# 13-49-30_0_compressed           0      0
# 13-51-02_0_compressed           0      0
# 13-52-34_0_compressed           0      0
# 13-54-05_0_compressed           0      0
# 13-55-37_0_compressed           0      0
# 13-57-08_0_compressed           0      0
# 13-58-40_0_compressed           0      0
# 📈 Generating Pipeline Ablation Plots...
# ETAPA DEL PIPELINE (CASCADA)                  | ERROR MEDIO     | FRAMES VIVOS    | PECES (TRACKS)
# ----------------------------------------------------------------------------------------------------
# 0. Base (HDBSCAN without filters)             |  3.59 ± 3.34 cm |   15356 frames |    51 tracks
# 1. + Filter: No Borders                       |  3.59 ± 3.34 cm |   15356 frames |    51 tracks
# 2. + Filter: No Overlap                       |  3.60 ± 3.35 cm |   15340 frames |    51 tracks
# 3. + Filter: is_3D_complete                   |  3.66 ± 3.38 cm |   15150 frames |    51 tracks
# 4. + Filter: Aspect Ratio >= 3.0              |  2.30 ± 2.74 cm |    6432 frames |    34 tracks
# 5. + Filter: Z-Angle <= 30.0º                 |  1.67 ± 2.49 cm |    2641 frames |    28 tracks
# 📈 Generating Thresholds Interaction Plot...
# Evaluating Angles: 100%|██████████| 9/9 [00:03<00:00,  2.63it/s]
# 📈 Generating Error vs Geometry Analysis Plots...
# 📈 Generating Track Error vs Length Plot...
# 📈 Generating Track Length Histogram...
# ======================================================================
# 📊 PLOTS FOR SCENARIO: MULTIPLE_FISH
# ======================================================================
# ============================================================
# 📊 TABLA 1: Distribución Global de Frames
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured      1625           18.51
# 1        short_track         0            0.00
# 2      incomplete_3D       155            1.77
# 3            borders       352            4.01
# 4            overlap      2370           27.00
# 5  aspect_ratio_fail      3386           38.57
# 6         angle_fail       890           10.14
# 7              other         0            0.00
# ============================================================
# 📊 TABLA 1: Distribución Global de Tracks
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured        72           54.55
# 1        short_track         7            5.30
# 2         not_a_fish         0            0.00
# 3      incomplete_3D         0            0.00
# 4     bad_pointcloud         0            0.00
# 5            borders         4            3.03
# 6            overlap        18           13.64
# 7  aspect_ratio_fail        29           21.97
# 8         angle_fail         2            1.52
# 9              other         0            0.00
# ============================================================
# 📊 TABLA 2: Desglose por Vídeo
# ============================================================
# track_failure_reason            measured  short_track  not_a_fish  \
# source_folder
# 10-01-53_0_compressed-r201-end         3            2           0
# 10-07-59_0-r50-end                     8            1           0
# 10-09-31_0-r0-344                      4            0           0
# 10-09-31_0-r398-end                    7            2           0
# 10-11-02_0-r0-244                      2            0           0
# 10-11-02_0-r295-end                    2            0           0
# 10-12-34_0-r215-end                    6            0           0
# 10-14-05_0-r0-528                      5            0           0
# 10-15-37_0-r496-end                    2            0           0
# 10-18-24_0_compressed-r47-end          3            1           0
# 10-19-44_0_compressed-r383-534         2            0           0
# 10-19-44_0_compressed-r588-end         2            0           0
# 10-20-29_1_compressed-r0-78            1            0           0
# 10-22-00_1_compressed                  2            0           0
# 10-37-15_1-r                           4            0           0
# 13-05-55_0-r                          11            0           0
# 13-22-22_0_compressed-r378-463         1            0           0
# 13-22-22_0_compressed-r60-297          2            1           0
# 13-23-54_0_compressed-r0-304           0            0           0
# 13-23-54_0_compressed-r450-524         3            0           0
# 13-23-54_0_compressed-r602-end         2            0           0
#
# track_failure_reason            incomplete_3D  bad_pointcloud  borders  \
# source_folder
# 10-01-53_0_compressed-r201-end              0               0        1
# 10-07-59_0-r50-end                          0               0        0
# 10-09-31_0-r0-344                           0               0        0
# 10-09-31_0-r398-end                         0               0        0
# 10-11-02_0-r0-244                           0               0        0
# 10-11-02_0-r295-end                         0               0        2
# 10-12-34_0-r215-end                         0               0        0
# 10-14-05_0-r0-528                           0               0        0
# 10-15-37_0-r496-end                         0               0        0
# 10-18-24_0_compressed-r47-end               0               0        0
# 10-19-44_0_compressed-r383-534              0               0        0
# 10-19-44_0_compressed-r588-end              0               0        0
# 10-20-29_1_compressed-r0-78                 0               0        0
# 10-22-00_1_compressed                       0               0        0
# 10-37-15_1-r                                0               0        1
# 13-05-55_0-r                                0               0        0
# 13-22-22_0_compressed-r378-463              0               0        0
# 13-22-22_0_compressed-r60-297               0               0        0
# 13-23-54_0_compressed-r0-304                0               0        0
# 13-23-54_0_compressed-r450-524              0               0        0
# 13-23-54_0_compressed-r602-end              0               0        0
#
# track_failure_reason            overlap  aspect_ratio_fail  angle_fail  other
# source_folder
# 10-01-53_0_compressed-r201-end        1                  3           0      0
# 10-07-59_0-r50-end                    4                  3           0      0
# 10-09-31_0-r0-344                     1                  4           0      0
# 10-09-31_0-r398-end                   0                  0           1      0
# 10-11-02_0-r0-244                     2                  1           0      0
# 10-11-02_0-r295-end                   1                  0           0      0
# 10-12-34_0-r215-end                   1                  0           0      0
# 10-14-05_0-r0-528                     0                  3           0      0
# 10-15-37_0-r496-end                   0                  2           0      0
# 10-18-24_0_compressed-r47-end         0                  3           0      0
# 10-19-44_0_compressed-r383-534        0                  0           0      0
# 10-19-44_0_compressed-r588-end        0                  0           0      0
# 10-20-29_1_compressed-r0-78           0                  3           0      0
# 10-22-00_1_compressed                 0                  1           0      0
# 10-37-15_1-r                          0                  0           0      0
# 13-05-55_0-r                          4                  2           0      0
# 13-22-22_0_compressed-r378-463        0                  2           0      0
# 13-22-22_0_compressed-r60-297         1                  1           1      0
# 13-23-54_0_compressed-r0-304          3                  0           0      0
# 13-23-54_0_compressed-r450-524        0                  0           0      0
# 13-23-54_0_compressed-r602-end        0                  1           0      0
# 📈 Generating Pipeline Ablation Plots...
# ETAPA DEL PIPELINE (CASCADA)                  | ERROR MEDIO     | FRAMES VIVOS    | PECES (TRACKS)
# ----------------------------------------------------------------------------------------------------
# 0. Base (HDBSCAN without filters)             |  2.10 ± 2.92 cm |    9060 frames |   122 tracks
# 1. + Filter: No Borders                       |  2.10 ± 2.92 cm |    9060 frames |   122 tracks
# 2. + Filter: No Overlap                       |  1.93 ± 2.79 cm |    6438 frames |   113 tracks
# 3. + Filter: is_3D_complete                   |  1.95 ± 2.80 cm |    6347 frames |   113 tracks
# 4. + Filter: Aspect Ratio >= 3.0              |  1.25 ± 1.36 cm |    2849 frames |    86 tracks
# 5. + Filter: Z-Angle <= 30.0º                 |  1.27 ± 1.36 cm |    1863 frames |    74 tracks
# 📈 Generating Thresholds Interaction Plot...
# Evaluating Angles: 100%|██████████| 9/9 [00:06<00:00,  1.41it/s]
# 📈 Generating Error vs Geometry Analysis Plots...
# 📈 Generating Track Error vs Length Plot...
# 📈 Generating Track Length Histogram...

# %%
display(df_final.describe())

display(df_final.head())

single = df_final[df_final["scenario"]=="single_fish"]

single_sorted = single.sort_values(by="abs_error_cm", ascending=False)
# Out:
#        n_frames_validos  calculated_length_cm      gt_cm  abs_error_cm  \
# count         99.000000             99.000000  99.000000     99.000000
# mean          40.414141             29.709447  29.821212      1.361366
# std           64.258567              2.789545   1.636589      1.831549
# min            6.000000             17.287883  26.600000      0.020557
# 25%           12.000000             28.522179  29.100000      0.380483
# 50%           21.000000             29.377891  29.100000      0.779429
# 75%           40.500000             31.457569  32.300000      1.442551
# max          528.000000             37.147720  32.300000     11.812117
#
#        rel_error_perc  mean_elevation_deg
# count       99.000000           99.000000
# mean         4.584959            0.514920
# std          6.253980           11.528358
# min          0.070642          -25.784033
# 25%          1.307501           -7.790539
# 50%          2.678450            2.933712
# 75%          4.872204            9.325281
# max         40.591467           20.329322
#                                            track_uid  n_frames_validos  \
# 0  2025_08_21_2025_08_21_10-01-53_0_compressed-r2...              58.0
# 1  2025_08_21_2025_08_21_10-01-53_0_compressed-r2...              27.0
# 2  2025_08_21_2025_08_21_10-01-53_0_compressed-r2...              12.0
# 3        2025_08_21_2025_08_21_10-07-59_0-r50-end_12              36.0
# 4        2025_08_21_2025_08_21_10-07-59_0-r50-end_16              11.0
#
#    calculated_length_cm  gt_cm  abs_error_cm  rel_error_perc  \
# 0             31.208944   29.1      2.108944        7.247231
# 1             28.487170   29.1      0.612830        2.105947
# 2             36.844358   32.3      4.544358       14.069219
# 3             31.633936   32.3      0.666064        2.062116
# 4             28.766386   29.1      0.333614        1.146440
#
#    mean_elevation_deg     dataset       scenario   video_day  \
# 0            3.507113  2025_08_21  multiple_fish  2025_08_21
# 1           -7.784807  2025_08_21  multiple_fish  2025_08_21
# 2            4.428089  2025_08_21  multiple_fish  2025_08_21
# 3            1.037775  2025_08_21  multiple_fish  2025_08_21
# 4           10.841321  2025_08_21  multiple_fish  2025_08_21
#
#                        video_name especie_gt
# 0  10-01-53_0_compressed-r201-end        red
