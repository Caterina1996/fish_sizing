# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from termcolor import cprint
import results_analysis_utils as rutils
from IPython.display import display


# %load_ext autoreload
# %autoreload 2

# ===================================================================
# 1. CONFIGURATION
# ===================================================================
day_code = "2025_08_21" 
dataset_name = "DATASET_2" # O DATASET_2

ASPECT_RATIO_THR = 3.0
ANGLE_THR = 30.0

# Ruta al CSV crudo de este día concreto
csv_path = Path(f"/home/slimbook/fish_sizing/ARTICLE/{dataset_name}/{day_code}/{day_code}_ALL_raw_aggregated.csv")

cprint(f"👉 WORKING ON: {day_code}", "white", "on_blue", attrs=["bold"])
cprint(f"Reading csv from {csv_path}", "yellow")

# ===================================================================
# 2. FILTERING & AGGREGATION (Usando la misma lógica global)
# ===================================================================
# Le pasamos el nombre del día como 'dataset_name' para que la función imprima bonito

df_final, df_raw = rutils.load_and_filter_dataset(csv_path, 
                                                  dataset_name=day_code,
                                                  recalculate_failure_reason=True, 
                                                  aspect_ratio_thr=ASPECT_RATIO_THR, 
                                                  angle_thr=ANGLE_THR, 
                                                  save=False)

if df_raw.empty:
    raise ValueError("No data found for this day!")

# ===================================================================
# 3. DAILY SUMMARY TABLE (Single vs Multiple)
# ===================================================================
print("\n" + "="*85)
print(f"DAILY SUMMARY: {day_code}")
print("="*85)
print(f"{'SCENARIO':<15} | {'Total Tracks':<12} | {'Measured':<10} | {'Success (%)':<12} | {'MAE (cm)':<10} | {'STD (cm)':<10} | {'MAPE (%)':<10}")
print("-" * 85)

scenarios = ['All']
if 'scenario' in df_raw.columns:
    scenarios.extend(df_raw['scenario'].dropna().unique().tolist())

for sc in scenarios:
    # 1. Contar totales desde el RAW
    if sc == 'All':
        total_tracks = df_raw['track_uid'].nunique()
        sub_final = df_final
    else:
        total_tracks = df_raw[df_raw['scenario'] == sc]['track_uid'].nunique()
        sub_final = df_final[df_final['scenario'] == sc] if not df_final.empty else pd.DataFrame()
            
    # 2. Contar medidos desde el FINAL
    measured_tracks = len(sub_final)
    
    # 3. Calcular métricas
    if measured_tracks > 0:
        mae = sub_final['abs_error_cm'].mean()
        std = sub_final['abs_error_cm'].std()
        mape = sub_final['rel_error_perc'].mean()
    else:
        mae = std = mape = 0.0
        
    success_perc = (measured_tracks / total_tracks * 100) if total_tracks > 0 else 0
    
    label = f"GLOBAL DAY" if sc == 'All' else sc
    print(f"{label:<15} | {total_tracks:<12} | {measured_tracks:<10} | {success_perc:<12.1f} | {mae:<10.2f} | {std:<10.2f} | {mape:<10.2f}")

print("="*85 + "\n")


for sc in scenarios:
    cprint(f"\n\n{'='*70}", "white", "on_magenta", attrs=["bold"])
    cprint(f"📊 PLOTS FOR SCENARIO: {sc.upper()}", "white", "on_magenta", attrs=["bold"])
    cprint(f"{'='*70}", "white", "on_magenta", attrs=["bold"])
    
    # 1. Filtrar el dataframe dependiendo del escenario
    if sc == 'All':
        df_sc_raw = df_raw.copy()
        context_label = f"{day_code} - GLOBAL"
    else:
        df_sc_raw = df_raw[df_raw['scenario'] == sc].copy()
        context_label = f"{day_code} - {sc.upper()}"
        
    if df_sc_raw.empty:
        print(f"⚠️ No data available for {sc.upper()}, skipping plots.")
        continue
    
    # 2. Generar gráficos
    stacked_frames = rutils.plot_frame_failures(
        df_sc_raw, 
        aspect_ratio_thr=ASPECT_RATIO_THR, 
        angle_thr=ANGLE_THR,
        figsize_video=(12,6), 
        figsize_global=(5,5), 
        show_global=True,
        context_label=context_label
    )

    track_failures = rutils.plot_tracks_failure_distribution(
        df_sc_raw, 
        aspect_ratio_thr=ASPECT_RATIO_THR, 
        angle_thr=ANGLE_THR,
        show_global=True, 
        figsize_video=(12,6), 
        figsize_global=(5,5),
        context_label=context_label
    )

    rutils.plot_aspect_ratio_vs_length(
        df_sc_raw, 
        ASPECT_RATIO_THR=ASPECT_RATIO_THR, 
        figsize=(10, 8),
        context_label=context_label
    ) 
    
    # 1. Gráfica de Cascada (Ablation)
    print("\n📈 Generating Pipeline Ablation Plots...")
    stages_dict, agg_stages_dict = rutils.plot_ablation_pipeline(
        df_sc_raw, 
        ASPECT_RATIO_THR=ASPECT_RATIO_THR, 
        ANGLE_THR=ANGLE_THR,
        context_label=context_label  
    )
    
    # 2. Interacción de umbrales
    print("\n📈 Generating Thresholds Interaction Plot...")
    rutils.plot_thresholds_interaction(
        df_sc_raw, 
        optimal_ar=ASPECT_RATIO_THR, 
        context=context_label
    )
    
    # 3. Relación de Error vs Geometría (Raw y Aislado)
    print("\n📈 Generating Error vs Geometry Analysis Plots...")
    rutils.plot_error_vs_geometry(
        df_sc_raw, 
        ar_thr=ASPECT_RATIO_THR, 
        angle_thr=ANGLE_THR, 
        context_label=context_label
    )
    
    print("\n📈 Generating Track Error vs Length Plot...")
    rutils.plot_error_vs_track_length(
        df_raw=df_sc_raw, 
        df_final=sub_final,  # <--- ¡AQUÍ LE PASAMOS TU CÁLCULO INTELIGENTE!
        context_label=context_label,
        min_frames_thr=6
    )
    
    print("\n📈 Generating Track Length Histogram...")
    rutils.plot_track_length_histogram(
        df_sc_raw, 
        min_frames_thr=5, # O el número que uses en el smart_aggregator
        context_label=context_label
    )
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 👉 WORKING ON: 2025_08_21
# Reading csv from /home/slimbook/fish_sizing/ARTICLE/DATASET_2/2025_08_21/2025_08_21_ALL_raw_aggregated.csv
#
# --- Processing 2025_08_21 ---
# Total raw frames with valid GT: 26016
# Total initial tracks: 189
# Frames belonging to 'measured' tracks: 4453
# 📉 Tracks descartados por 'track_failure_from_frames': 87
# 📉 Tracks descartados por 'smart_aggregator': 0
# ✅ FINAL RESULT: 102 independent FISH (tracks) successfully aggregated.
# 📊 Success Rate: 53.97% (102/189 tracks medidos con éxito)
#
# =====================================================================================
# DAILY SUMMARY: 2025_08_21
# =====================================================================================
# SCENARIO        | Total Tracks | Measured   | Success (%)  | MAE (cm)   | STD (cm)   | MAPE (%)
# -------------------------------------------------------------------------------------
# GLOBAL DAY      | 189          | 102        | 54.0         | 1.35       | 1.74       | 4.57
# single_fish     | 57           | 28         | 49.1         | 1.67       | 2.49       | 5.74
# multiple_fish   | 132          | 74         | 56.1         | 1.23       | 1.35       | 4.13
# =====================================================================================
#
#
#
# ======================================================================
# 📊 PLOTS FOR SCENARIO: ALL
# ======================================================================
# ============================================================
# 📊 TABLA 1: Distribución Global de Frames
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured      4504           17.31
# 1      incomplete_3D        69            0.27
# 2            borders       468            1.80
# 3            overlap      2739           10.53
# 4  aspect_ratio_fail     13308           51.15
# 5         angle_fail      4836           18.59
# 6        short_track         0            0.00
# 7              other        92            0.35
# ============================================================
# 📊 TABLA 1: Distribución Global de Tracks
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured       102           53.97
# 1      incomplete_3D         0            0.00
# 2            borders         4            2.12
# 3            overlap        20           10.58
# 4  aspect_ratio_fail        58           30.69
# 5         angle_fail         5            2.65
# 6        short_track         0            0.00
# 7              other         0            0.00
# ============================================================
# 📊 TABLA 2: Desglose por Vídeo
# ============================================================
# track_failure_reason            measured  incomplete_3D  borders  overlap  \
# source_folder
# 10-01-53_0_compressed-r201-end         3              0        0        2
# 10-07-59_0-r50-end                     8              0        0        5
# 10-09-31_0-r0-344                      4              0        0        1
# 10-09-31_0-r398-end                    7              0        0        0
# 10-11-02_0-r0-244                      2              0        0        2
# 10-11-02_0-r295-end                    2              0        2        1
# 10-12-34_0-r215-end                    6              0        0        1
# 10-14-05_0-r0-528                      5              0        0        0
# 10-15-37_0-r496-end                    2              0        0        0
# 10-18-24_0_compressed-r47-end          3              0        0        0
# 10-19-44_0_compressed-r383-534         2              0        0        0
# 10-19-44_0_compressed-r588-end         2              0        0        0
# 10-20-29_1_compressed-r0-78            1              0        0        0
# 10-22-00_1_compressed                  2              0        0        0
# 10-37-15_1-r                           4              0        1        0
# 12-07-32_0                             1              0        0        0
# 12-08-05_1                             2              0        0        0
# 12-09-03_0_compressed                  2              0        0        0
# 12-09-37_1_compressed                  1              0        0        1
# 12-10-35_0_compressed                  0              0        0        0
# 12-11-09_1_compressed                  1              0        0        0
# 12-12-06_0_compressed                  1              0        0        0
# 12-12-40_1_compressed                  0              0        0        0
# 12-13-38_0_compressed                  1              0        0        0
# 12-14-12_1_compressed                  1              0        0        0
# 12-15-10_0_compressed                  0              0        0        0
# 12-15-43_1_compressed                  0              0        0        0
# 13-05-55_0-r                          12              0        0        3
# 13-22-22_0_compressed-r378-463         2              0        0        0
# 13-22-22_0_compressed-r60-297          2              0        1        1
# 13-23-54_0_compressed-r0-304           0              0        0        3
# 13-23-54_0_compressed-r450-524         3              0        0        0
# 13-23-54_0_compressed-r602-end         2              0        0        0
# 13-33-04_0                             2              0        0        0
# 13-33-43_1                             1              0        0        0
# 13-34-25_0_compressed                  1              0        0        0
# 13-35-09_1_compressed                  0              0        0        0
# 13-35-56_0_compressed                  1              0        0        0
# 13-36-41_1_compressed                  1              0        0        0
# 13-37-28_0_compressed                  2              0        0        0
# 13-38-13_1_compressed                  1              0        0        0
# 13-38-54_0_compressed                  1              0        0        0
# 13-40-21_0_compressed                  1              0        0        0
# 13-41-52_0_compressed                  0              0        0        0
# 13-43-24_0_compressed                  1              0        0        0
# 13-44-56_0_compressed                  0              0        0        0
# 13-46-27_0_compressed                  0              0        0        0
# 13-47-59_0_compressed                  0              0        0        0
# 13-49-30_0_compressed                  0              0        0        0
# 13-51-02_0_compressed                  0              0        0        0
# 13-52-34_0_compressed                  2              0        0        0
# 13-54-05_0_compressed                  1              0        0        0
# 13-55-37_0_compressed                  1              0        0        0
# 13-57-08_0_compressed                  1              0        0        0
# 13-58-40_0_compressed                  1              0        0        0
#
# track_failure_reason            aspect_ratio_fail  angle_fail  short_track  \
# source_folder
# 10-01-53_0_compressed-r201-end                  5           0            0
# 10-07-59_0-r50-end                              3           0            0
# 10-09-31_0-r0-344                               4           0            0
# 10-09-31_0-r398-end                             2           1            0
# 10-11-02_0-r0-244                               1           0            0
# 10-11-02_0-r295-end                             0           0            0
# 10-12-34_0-r215-end                             0           0            0
# 10-14-05_0-r0-528                               3           0            0
# 10-15-37_0-r496-end                             2           0            0
# 10-18-24_0_compressed-r47-end                   4           0            0
# 10-19-44_0_compressed-r383-534                  0           0            0
# 10-19-44_0_compressed-r588-end                  0           0            0
# 10-20-29_1_compressed-r0-78                     3           0            0
# 10-22-00_1_compressed                           1           0            0
# 10-37-15_1-r                                    0           0            0
# 12-07-32_0                                      2           0            0
# 12-08-05_1                                      1           1            0
# 12-09-03_0_compressed                           0           0            0
# 12-09-37_1_compressed                           0           0            0
# 12-10-35_0_compressed                           4           0            0
# 12-11-09_1_compressed                           2           0            0
# 12-12-06_0_compressed                           1           0            0
# 12-12-40_1_compressed                           1           0            0
# 12-13-38_0_compressed                           1           0            0
# 12-14-12_1_compressed                           1           0            0
# 12-15-10_0_compressed                           2           0            0
# 12-15-43_1_compressed                           3           0            0
# 13-05-55_0-r                                    2           0            0
# 13-22-22_0_compressed-r378-463                  1           0            0
# 13-22-22_0_compressed-r60-297                   1           1            0
# 13-23-54_0_compressed-r0-304                    0           0            0
# 13-23-54_0_compressed-r450-524                  0           0            0
# 13-23-54_0_compressed-r602-end                  1           0            0
# 13-33-04_0                                      0           0            0
# 13-33-43_1                                      0           0            0
# 13-34-25_0_compressed                           0           0            0
# 13-35-09_1_compressed                           0           1            0
# 13-35-56_0_compressed                           0           0            0
# 13-36-41_1_compressed                           0           0            0
# 13-37-28_0_compressed                           0           0            0
# 13-38-13_1_compressed                           0           0            0
# 13-38-54_0_compressed                           0           1            0
# 13-40-21_0_compressed                           0           0            0
# 13-41-52_0_compressed                           1           0            0
# 13-43-24_0_compressed                           0           0            0
# 13-44-56_0_compressed                           1           0            0
# 13-46-27_0_compressed                           1           0            0
# 13-47-59_0_compressed                           1           0            0
# 13-49-30_0_compressed                           1           0            0
# 13-51-02_0_compressed                           2           0            0
# 13-52-34_0_compressed                           0           0            0
# 13-54-05_0_compressed                           0           0            0
# 13-55-37_0_compressed                           0           0            0
# 13-57-08_0_compressed                           0           0            0
# 13-58-40_0_compressed                           0           0            0
#
# track_failure_reason            other
# source_folder
# 10-01-53_0_compressed-r201-end      0
# 10-07-59_0-r50-end                  0
# 10-09-31_0-r0-344                   0
# 10-09-31_0-r398-end                 0
# 10-11-02_0-r0-244                   0
# 10-11-02_0-r295-end                 0
# 10-12-34_0-r215-end                 0
# 10-14-05_0-r0-528                   0
# 10-15-37_0-r496-end                 0
# 10-18-24_0_compressed-r47-end       0
# 10-19-44_0_compressed-r383-534      0
# 10-19-44_0_compressed-r588-end      0
# 10-20-29_1_compressed-r0-78         0
# 10-22-00_1_compressed               0
# 10-37-15_1-r                        0
# 12-07-32_0                          0
# 12-08-05_1                          0
# 12-09-03_0_compressed               0
# 12-09-37_1_compressed               0
# 12-10-35_0_compressed               0
# 12-11-09_1_compressed               0
# 12-12-06_0_compressed               0
# 12-12-40_1_compressed               0
# 12-13-38_0_compressed               0
# 12-14-12_1_compressed               0
# 12-15-10_0_compressed               0
# 12-15-43_1_compressed               0
# 13-05-55_0-r                        0
# 13-22-22_0_compressed-r378-463      0
# 13-22-22_0_compressed-r60-297       0
# 13-23-54_0_compressed-r0-304        0
# 13-23-54_0_compressed-r450-524      0
# 13-23-54_0_compressed-r602-end      0
# 13-33-04_0                          0
# 13-33-43_1                          0
# 13-34-25_0_compressed               0
# 13-35-09_1_compressed               0
# 13-35-56_0_compressed               0
# 13-36-41_1_compressed               0
# 13-37-28_0_compressed               0
# 13-38-13_1_compressed               0
# 13-38-54_0_compressed               0
# 13-40-21_0_compressed               0
# 13-41-52_0_compressed               0
# 13-43-24_0_compressed               0
# 13-44-56_0_compressed               0
# 13-46-27_0_compressed               0
# 13-47-59_0_compressed               0
# 13-49-30_0_compressed               0
# 13-51-02_0_compressed               0
# 13-52-34_0_compressed               0
# 13-54-05_0_compressed               0
# 13-55-37_0_compressed               0
# 13-57-08_0_compressed               0
# 13-58-40_0_compressed               0
# 📈 Generating Pipeline Ablation Plots...
# ETAPA DEL PIPELINE (CASCADA)                  | ERROR MEDIO     | FRAMES VIVOS    | PECES (TRACKS)
# ----------------------------------------------------------------------------------------------------
# 0. Base (HDBSCAN without filters)             |  2.43 ± 3.08 cm |   24416 frames |   173 tracks
# 1. + Filter: No Borders                       |  2.43 ± 3.08 cm |   24416 frames |   173 tracks
# 2. + Filter: No Overlap                       |  2.30 ± 3.01 cm |   21778 frames |   164 tracks
# 3. + Filter: is_3D_complete                   |  2.32 ± 3.03 cm |   21497 frames |   164 tracks
# 4. + Filter: Aspect Ratio >= 3.0              |  1.46 ± 1.79 cm |    9281 frames |   120 tracks
# 5. + Filter: Z-Angle <= 30.0º                 |  1.35 ± 1.74 cm |    4504 frames |   102 tracks
# 📈 Generating Thresholds Interaction Plot...
# Evaluating Angles: 100%|██████████| 9/9 [00:11<00:00,  1.33s/it]
# 📈 Generating Error vs Geometry Analysis Plots...
# 📈 Generating Track Error vs Length Plot...
# 📈 Generating Track Length Histogram...
# ======================================================================
# 📊 PLOTS FOR SCENARIO: SINGLE_FISH
# ======================================================================
# ============================================================
# 📊 TABLA 1: Distribución Global de Frames
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured      2641           16.19
# 1      incomplete_3D        26            0.16
# 2            borders       116            0.71
# 3            overlap        16            0.10
# 4  aspect_ratio_fail      9641           59.11
# 5         angle_fail      3818           23.41
# 6        short_track         0            0.00
# 7              other        51            0.31
# ============================================================
# 📊 TABLA 1: Distribución Global de Tracks
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured        28           49.12
# 1      incomplete_3D         0            0.00
# 2            borders         0            0.00
# 3            overlap         1            1.75
# 4  aspect_ratio_fail        25           43.86
# 5         angle_fail         3            5.26
# 6        short_track         0            0.00
# 7              other         0            0.00
# ============================================================
# 📊 TABLA 2: Desglose por Vídeo
# ============================================================
# track_failure_reason   measured  incomplete_3D  borders  overlap  \
# source_folder
# 12-07-32_0                    1              0        0        0
# 12-08-05_1                    2              0        0        0
# 12-09-03_0_compressed         2              0        0        0
# 12-09-37_1_compressed         1              0        0        1
# 12-10-35_0_compressed         0              0        0        0
# 12-11-09_1_compressed         1              0        0        0
# 12-12-06_0_compressed         1              0        0        0
# 12-12-40_1_compressed         0              0        0        0
# 12-13-38_0_compressed         1              0        0        0
# 12-14-12_1_compressed         1              0        0        0
# 12-15-10_0_compressed         0              0        0        0
# 12-15-43_1_compressed         0              0        0        0
# 13-33-04_0                    2              0        0        0
# 13-33-43_1                    1              0        0        0
# 13-34-25_0_compressed         1              0        0        0
# 13-35-09_1_compressed         0              0        0        0
# 13-35-56_0_compressed         1              0        0        0
# 13-36-41_1_compressed         1              0        0        0
# 13-37-28_0_compressed         2              0        0        0
# 13-38-13_1_compressed         1              0        0        0
# 13-38-54_0_compressed         1              0        0        0
# 13-40-21_0_compressed         1              0        0        0
# 13-41-52_0_compressed         0              0        0        0
# 13-43-24_0_compressed         1              0        0        0
# 13-44-56_0_compressed         0              0        0        0
# 13-46-27_0_compressed         0              0        0        0
# 13-47-59_0_compressed         0              0        0        0
# 13-49-30_0_compressed         0              0        0        0
# 13-51-02_0_compressed         0              0        0        0
# 13-52-34_0_compressed         2              0        0        0
# 13-54-05_0_compressed         1              0        0        0
# 13-55-37_0_compressed         1              0        0        0
# 13-57-08_0_compressed         1              0        0        0
# 13-58-40_0_compressed         1              0        0        0
#
# track_failure_reason   aspect_ratio_fail  angle_fail  short_track  other
# source_folder
# 12-07-32_0                             2           0            0      0
# 12-08-05_1                             1           1            0      0
# 12-09-03_0_compressed                  0           0            0      0
# 12-09-37_1_compressed                  0           0            0      0
# 12-10-35_0_compressed                  4           0            0      0
# 12-11-09_1_compressed                  2           0            0      0
# 12-12-06_0_compressed                  1           0            0      0
# 12-12-40_1_compressed                  1           0            0      0
# 12-13-38_0_compressed                  1           0            0      0
# 12-14-12_1_compressed                  1           0            0      0
# 12-15-10_0_compressed                  2           0            0      0
# 12-15-43_1_compressed                  3           0            0      0
# 13-33-04_0                             0           0            0      0
# 13-33-43_1                             0           0            0      0
# 13-34-25_0_compressed                  0           0            0      0
# 13-35-09_1_compressed                  0           1            0      0
# 13-35-56_0_compressed                  0           0            0      0
# 13-36-41_1_compressed                  0           0            0      0
# 13-37-28_0_compressed                  0           0            0      0
# 13-38-13_1_compressed                  0           0            0      0
# 13-38-54_0_compressed                  0           1            0      0
# 13-40-21_0_compressed                  0           0            0      0
# 13-41-52_0_compressed                  1           0            0      0
# 13-43-24_0_compressed                  0           0            0      0
# 13-44-56_0_compressed                  1           0            0      0
# 13-46-27_0_compressed                  1           0            0      0
# 13-47-59_0_compressed                  1           0            0      0
# 13-49-30_0_compressed                  1           0            0      0
# 13-51-02_0_compressed                  2           0            0      0
# 13-52-34_0_compressed                  0           0            0      0
# 13-54-05_0_compressed                  0           0            0      0
# 13-55-37_0_compressed                  0           0            0      0
# 13-57-08_0_compressed                  0           0            0      0
# 13-58-40_0_compressed                  0           0            0      0
# 📈 Generating Pipeline Ablation Plots...
# ETAPA DEL PIPELINE (CASCADA)                  | ERROR MEDIO     | FRAMES VIVOS    | PECES (TRACKS)
# ----------------------------------------------------------------------------------------------------
# 0. Base (HDBSCAN without filters)             |  3.19 ± 3.20 cm |   15356 frames |    51 tracks
# 1. + Filter: No Borders                       |  3.19 ± 3.20 cm |   15356 frames |    51 tracks
# 2. + Filter: No Overlap                       |  3.19 ± 3.21 cm |   15340 frames |    51 tracks
# 3. + Filter: is_3D_complete                   |  3.26 ± 3.24 cm |   15150 frames |    51 tracks
# 4. + Filter: Aspect Ratio >= 3.0              |  2.05 ± 2.51 cm |    6432 frames |    34 tracks
# 5. + Filter: Z-Angle <= 30.0º                 |  1.67 ± 2.49 cm |    2641 frames |    28 tracks
# 📈 Generating Thresholds Interaction Plot...
# Evaluating Angles: 100%|██████████| 9/9 [00:05<00:00,  1.76it/s]
# 📈 Generating Error vs Geometry Analysis Plots...
# 📈 Generating Track Error vs Length Plot...
# 📈 Generating Track Length Histogram...
# ======================================================================
# 📊 PLOTS FOR SCENARIO: MULTIPLE_FISH
# ======================================================================
# ============================================================
# 📊 TABLA 1: Distribución Global de Frames
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured      1863           19.19
# 1      incomplete_3D        43            0.44
# 2            borders       352            3.63
# 3            overlap      2723           28.05
# 4  aspect_ratio_fail      3667           37.78
# 5         angle_fail      1018           10.49
# 6        short_track         0            0.00
# 7              other        41            0.42
# ============================================================
# 📊 TABLA 1: Distribución Global de Tracks
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured        74           56.06
# 1      incomplete_3D         0            0.00
# 2            borders         4            3.03
# 3            overlap        19           14.39
# 4  aspect_ratio_fail        33           25.00
# 5         angle_fail         2            1.52
# 6        short_track         0            0.00
# 7              other         0            0.00
# ============================================================
# 📊 TABLA 2: Desglose por Vídeo
# ============================================================
# track_failure_reason            measured  incomplete_3D  borders  overlap  \
# source_folder
# 10-01-53_0_compressed-r201-end         3              0        0        2
# 10-07-59_0-r50-end                     8              0        0        5
# 10-09-31_0-r0-344                      4              0        0        1
# 10-09-31_0-r398-end                    7              0        0        0
# 10-11-02_0-r0-244                      2              0        0        2
# 10-11-02_0-r295-end                    2              0        2        1
# 10-12-34_0-r215-end                    6              0        0        1
# 10-14-05_0-r0-528                      5              0        0        0
# 10-15-37_0-r496-end                    2              0        0        0
# 10-18-24_0_compressed-r47-end          3              0        0        0
# 10-19-44_0_compressed-r383-534         2              0        0        0
# 10-19-44_0_compressed-r588-end         2              0        0        0
# 10-20-29_1_compressed-r0-78            1              0        0        0
# 10-22-00_1_compressed                  2              0        0        0
# 10-37-15_1-r                           4              0        1        0
# 13-05-55_0-r                          12              0        0        3
# 13-22-22_0_compressed-r378-463         2              0        0        0
# 13-22-22_0_compressed-r60-297          2              0        1        1
# 13-23-54_0_compressed-r0-304           0              0        0        3
# 13-23-54_0_compressed-r450-524         3              0        0        0
# 13-23-54_0_compressed-r602-end         2              0        0        0
#
# track_failure_reason            aspect_ratio_fail  angle_fail  short_track  \
# source_folder
# 10-01-53_0_compressed-r201-end                  5           0            0
# 10-07-59_0-r50-end                              3           0            0
# 10-09-31_0-r0-344                               4           0            0
# 10-09-31_0-r398-end                             2           1            0
# 10-11-02_0-r0-244                               1           0            0
# 10-11-02_0-r295-end                             0           0            0
# 10-12-34_0-r215-end                             0           0            0
# 10-14-05_0-r0-528                               3           0            0
# 10-15-37_0-r496-end                             2           0            0
# 10-18-24_0_compressed-r47-end                   4           0            0
# 10-19-44_0_compressed-r383-534                  0           0            0
# 10-19-44_0_compressed-r588-end                  0           0            0
# 10-20-29_1_compressed-r0-78                     3           0            0
# 10-22-00_1_compressed                           1           0            0
# 10-37-15_1-r                                    0           0            0
# 13-05-55_0-r                                    2           0            0
# 13-22-22_0_compressed-r378-463                  1           0            0
# 13-22-22_0_compressed-r60-297                   1           1            0
# 13-23-54_0_compressed-r0-304                    0           0            0
# 13-23-54_0_compressed-r450-524                  0           0            0
# 13-23-54_0_compressed-r602-end                  1           0            0
#
# track_failure_reason            other
# source_folder
# 10-01-53_0_compressed-r201-end      0
# 10-07-59_0-r50-end                  0
# 10-09-31_0-r0-344                   0
# 10-09-31_0-r398-end                 0
# 10-11-02_0-r0-244                   0
# 10-11-02_0-r295-end                 0
# 10-12-34_0-r215-end                 0
# 10-14-05_0-r0-528                   0
# 10-15-37_0-r496-end                 0
# 10-18-24_0_compressed-r47-end       0
# 10-19-44_0_compressed-r383-534      0
# 10-19-44_0_compressed-r588-end      0
# 10-20-29_1_compressed-r0-78         0
# 10-22-00_1_compressed               0
# 10-37-15_1-r                        0
# 13-05-55_0-r                        0
# 13-22-22_0_compressed-r378-463      0
# 13-22-22_0_compressed-r60-297       0
# 13-23-54_0_compressed-r0-304        0
# 13-23-54_0_compressed-r450-524      0
# 13-23-54_0_compressed-r602-end      0
# 📈 Generating Pipeline Ablation Plots...
# ETAPA DEL PIPELINE (CASCADA)                  | ERROR MEDIO     | FRAMES VIVOS    | PECES (TRACKS)
# ----------------------------------------------------------------------------------------------------
# 0. Base (HDBSCAN without filters)             |  2.11 ± 2.98 cm |    9060 frames |   122 tracks
# 1. + Filter: No Borders                       |  2.11 ± 2.98 cm |    9060 frames |   122 tracks
# 2. + Filter: No Overlap                       |  1.89 ± 2.84 cm |    6438 frames |   113 tracks
# 3. + Filter: is_3D_complete                   |  1.89 ± 2.84 cm |    6347 frames |   113 tracks
# 4. + Filter: Aspect Ratio >= 3.0              |  1.22 ± 1.35 cm |    2849 frames |    86 tracks
# 5. + Filter: Z-Angle <= 30.0º                 |  1.23 ± 1.35 cm |    1863 frames |    74 tracks
# 📈 Generating Thresholds Interaction Plot...
# Evaluating Angles: 100%|██████████| 9/9 [00:10<00:00,  1.13s/it]
# 📈 Generating Error vs Geometry Analysis Plots...
# 📈 Generating Track Error vs Length Plot...
# 📈 Generating Track Length Histogram...

# %%
display(df_final.describe())

display(df_final.head())

single = df_final[df_final["scenario"]=="single_fish"]

single_sorted = single.sort_values(by="abs_error_cm", ascending=False)
# Out:
#        n_frames_validos  calculated_length_cm       gt_cm  abs_error_cm  \
# count        102.000000            102.000000  102.000000    102.000000
# mean          43.656863             29.634503   29.775490      1.350745
# std           64.694636              2.677358    1.646144      1.735965
# min            6.000000             17.287883   26.600000      0.020557
# 25%           14.000000             28.411424   29.100000      0.439788
# 50%           24.500000             29.510628   29.100000      0.774419
# 75%           46.000000             31.266657   32.300000      1.441284
# max          529.000000             36.844358   32.300000     11.812117
#
#        mean_elevation_deg  rel_error_perc
# count          102.000000      102.000000
# mean             0.132708        4.569659
# std             11.319136        5.943608
# min            -25.783270        0.070642
# 25%             -8.083044        1.463355
# 50%              2.213340        2.681075
# 75%              8.854890        4.912915
# max             19.095454       40.591467
#                                            track_uid  n_frames_validos  \
# 0  2025_08_21_2025_08_21_10-01-53_0_compressed-r2...              59.0
# 1  2025_08_21_2025_08_21_10-01-53_0_compressed-r2...              31.0
# 2  2025_08_21_2025_08_21_10-01-53_0_compressed-r2...              14.0
# 3        2025_08_21_2025_08_21_10-07-59_0-r50-end_12              42.0
# 4        2025_08_21_2025_08_21_10-07-59_0-r50-end_16              17.0
#
#    calculated_length_cm  gt_cm  abs_error_cm  mean_elevation_deg     dataset  \
# 0             31.208944   29.1      2.108944            3.402430  2025_08_21
# 1             28.425580   29.1      0.674420           -7.608901  2025_08_21
# 2             36.844358   32.3      4.544358            3.907754  2025_08_21
# 3             31.582839   32.3      0.717161            1.588804  2025_08_21
# 4             28.766386   29.1      0.333614            7.392670  2025_08_21
#
#         scenario   video_day                      video_name especie_gt  \
# 0  multiple_fish  2025_08_21  10-01-53_0_compressed-r201-end        red
# 1  multiple_fish  2025_08_21  10-01-53_0_compressed-r201-end        red
# 2  multiple_fish  2025_08_21  10-01-53_0_compressed-r201-end    no_mark
# 3  multiple_fish  2025_08_21              10-07-59_0-r50-end    no_mark
# 4  multiple_fish  2025_08_21              10-07-59_0-r50-end        red
#
#    rel_error_perc
# 0        7.247231
# 1        2.317593
# 2       14.069219
# 3        2.220313
# 4        1.146440

# %%
single_sorted
# Out:
#                                          track_uid  n_frames_validos  \
# 56   2025_08_21_2025_08_21_12-09-03_0_compressed_1              11.0
# 94   2025_08_21_2025_08_21_13-40-21_0_compressed_1              11.0
# 61   2025_08_21_2025_08_21_12-13-38_0_compressed_9              15.0
# 60   2025_08_21_2025_08_21_12-12-06_0_compressed_1              73.0
# 89   2025_08_21_2025_08_21_13-36-41_1_compressed_1             102.0
# 101  2025_08_21_2025_08_21_13-58-40_0_compressed_1              99.0
# 96   2025_08_21_2025_08_21_13-52-34_0_compressed_1              46.0
# 58   2025_08_21_2025_08_21_12-09-37_1_compressed_1             112.0
# 95   2025_08_21_2025_08_21_13-43-24_0_compressed_1              12.0
# 88   2025_08_21_2025_08_21_13-35-56_0_compressed_1              13.0
# 91   2025_08_21_2025_08_21_13-37-28_0_compressed_3              72.0
# 92   2025_08_21_2025_08_21_13-38-13_1_compressed_1              93.0
# 59   2025_08_21_2025_08_21_12-11-09_1_compressed_1              66.0
# 84              2025_08_21_2025_08_21_13-33-04_0_1              21.0
# 93   2025_08_21_2025_08_21_13-38-54_0_compressed_1             104.0
# 90   2025_08_21_2025_08_21_13-37-28_0_compressed_1              92.0
# 97   2025_08_21_2025_08_21_13-52-34_0_compressed_2             230.0
# 100  2025_08_21_2025_08_21_13-57-08_0_compressed_1             227.0
# 86              2025_08_21_2025_08_21_13-33-43_1_1             107.0
# 99   2025_08_21_2025_08_21_13-55-37_0_compressed_1             179.0
# 98   2025_08_21_2025_08_21_13-54-05_0_compressed_1             529.0
# 87   2025_08_21_2025_08_21_13-34-25_0_compressed_1              41.0
# 53              2025_08_21_2025_08_21_12-07-32_0_1             196.0
# 62   2025_08_21_2025_08_21_12-14-12_1_compressed_1              36.0
# 85              2025_08_21_2025_08_21_13-33-04_0_3              71.0
# 57   2025_08_21_2025_08_21_12-09-03_0_compressed_3              16.0
# 54              2025_08_21_2025_08_21_12-08-05_1_2              27.0
# 55              2025_08_21_2025_08_21_12-08-05_1_8              26.0
#
#      calculated_length_cm  gt_cm  abs_error_cm  mean_elevation_deg  \
# 56              17.287883   29.1     11.812117           -9.405450
# 94              21.248788   29.1      7.851212          -19.625152
# 61              25.925889   29.1      3.174111           -3.912328
# 60              31.576477   29.1      2.476477           -9.503630
# 89              31.204269   29.1      2.104269           13.392335
# 101             31.150985   29.1      2.050985           -8.131899
# 96              31.118722   29.1      2.018722          -10.358975
# 58              30.971489   29.1      1.871489           -3.574030
# 95              30.691948   29.1      1.591948          -23.580820
# 88              30.540404   29.1      1.440404          -14.650624
# 91              30.497422   29.1      1.397422          -13.648827
# 92              29.998858   29.1      0.898858            3.273812
# 59              29.918011   29.1      0.818011           -8.523906
# 84              28.303970   29.1      0.796030           -3.116097
# 93              29.867586   29.1      0.767586           -3.738017
# 90              28.366577   29.1      0.733423            5.632675
# 97              29.833224   29.1      0.733224          -24.527327
# 100             28.394917   29.1      0.705083          -25.750361
# 86              29.712277   29.1      0.612277            5.844288
# 99              28.557188   29.1      0.542812          -25.565623
# 98              28.612778   29.1      0.487222          -25.783270
# 87              28.674844   29.1      0.425156          -20.527932
# 53              29.523561   29.1      0.423561            5.018009
# 62              29.497696   29.1      0.397696           -4.720585
# 85              29.472203   29.1      0.372203            1.492582
# 57              29.283695   29.1      0.183695           10.556101
# 54              29.063507   29.1      0.036493           11.447987
# 55              29.079443   29.1      0.020557           -0.402084
#
#         dataset     scenario   video_day             video_name especie_gt  \
# 56   2025_08_21  single_fish  2025_08_21  12-09-03_0_compressed        red
# 94   2025_08_21  single_fish  2025_08_21  13-40-21_0_compressed        red
# 61   2025_08_21  single_fish  2025_08_21  12-13-38_0_compressed        red
# 60   2025_08_21  single_fish  2025_08_21  12-12-06_0_compressed        red
# 89   2025_08_21  single_fish  2025_08_21  13-36-41_1_compressed        red
# 101  2025_08_21  single_fish  2025_08_21  13-58-40_0_compressed        red
# 96   2025_08_21  single_fish  2025_08_21  13-52-34_0_compressed        red
# 58   2025_08_21  single_fish  2025_08_21  12-09-37_1_compressed        red
# 95   2025_08_21  single_fish  2025_08_21  13-43-24_0_compressed        red
# 88   2025_08_21  single_fish  2025_08_21  13-35-56_0_compressed        red
# 91   2025_08_21  single_fish  2025_08_21  13-37-28_0_compressed        red
# 92   2025_08_21  single_fish  2025_08_21  13-38-13_1_compressed        red
# 59   2025_08_21  single_fish  2025_08_21  12-11-09_1_compressed        red
# 84   2025_08_21  single_fish  2025_08_21             13-33-04_0        red
# 93   2025_08_21  single_fish  2025_08_21  13-38-54_0_compressed        red
# 90   2025_08_21  single_fish  2025_08_21  13-37-28_0_compressed        red
# 97   2025_08_21  single_fish  2025_08_21  13-52-34_0_compressed        red
# 100  2025_08_21  single_fish  2025_08_21  13-57-08_0_compressed        red
# 86   2025_08_21  single_fish  2025_08_21             13-33-43_1        red
# 99   2025_08_21  single_fish  2025_08_21  13-55-37_0_compressed        red
# 98   2025_08_21  single_fish  2025_08_21  13-54-05_0_compressed        red
# 87   2025_08_21  single_fish  2025_08_21  13-34-25_0_compressed        red
# 53   2025_08_21  single_fish  2025_08_21             12-07-32_0        red
# 62   2025_08_21  single_fish  2025_08_21  12-14-12_1_compressed        red
# 85   2025_08_21  single_fish  2025_08_21             13-33-04_0        red
# 57   2025_08_21  single_fish  2025_08_21  12-09-03_0_compressed        red
# 54   2025_08_21  single_fish  2025_08_21             12-08-05_1        red
# 55   2025_08_21  single_fish  2025_08_21             12-08-05_1        red
#
#      rel_error_perc
# 56        40.591467
# 94        26.980110
# 61        10.907599
# 60         8.510230
# 89         7.231166
# 101        7.048059
# 96         6.937190
# 58         6.431232
# 95         5.470612
# 88         4.949840
# 91         4.802139
# 92         3.088860
# 59         2.811033
# 84         2.735497
# 93         2.637752
# 90         2.520355
# 97         2.519671
# 100        2.422967
# 86         2.104045
# 99         1.865334
# 98         1.674302
# 87         1.461016
# 53         1.455536
# 62         1.366652
# 85         1.279050
# 57         0.631254
# 54         0.125405
# 55         0.070642
