# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from termcolor import cprint
import results_analysis_utils as rutils
from IPython.display import display


# %load_ext autoreload
# %autoreload 2

# ===================================================================
# 1. CONFIGURATION
# ===================================================================
day_code = "2025_05_08" 
dataset_name = "DATASET_1" # O DATASET_2

ASPECT_RATIO_THR = 3.0
ANGLE_THR = 30.0

# Ruta al CSV crudo de este día concreto
csv_path = Path(f"/home/slimbook/fish_sizing/ARTICLE/{dataset_name}/{day_code}/{day_code}_ALL_raw_aggregated.csv")

cprint(f"👉 WORKING ON: {day_code}", "white", "on_blue", attrs=["bold"])
cprint(f"Reading csv from {csv_path}", "yellow")

# ===================================================================
# 2. FILTERING & AGGREGATION (Usando la misma lógica global)
# ===================================================================
# Le pasamos el nombre del día como 'dataset_name' para que la función imprima bonito

df_final, df_raw = rutils.load_and_filter_dataset(csv_path, 
                                                  dataset_name=day_code,
                                                  recalculate_failure_reason=True, 
                                                  aspect_ratio_thr=ASPECT_RATIO_THR, 
                                                  angle_thr=ANGLE_THR, 
                                                  save=False)

if df_raw.empty:
    raise ValueError("No data found for this day!")

# ===================================================================
# 3. DAILY SUMMARY TABLE (Single vs Multiple)
# ===================================================================
print("\n" + "="*85)
print(f"DAILY SUMMARY: {day_code}")
print("="*85)
print(f"{'SCENARIO':<15} | {'Total Tracks':<12} | {'Measured':<10} | {'Success (%)':<12} | {'MAE (cm)':<10} | {'STD (cm)':<10} | {'MAPE (%)':<10}")
print("-" * 85)

scenarios = ['All']
if 'scenario' in df_raw.columns:
    scenarios.extend(df_raw['scenario'].dropna().unique().tolist())

for sc in scenarios:
    # 1. Contar totales desde el RAW
    if sc == 'All':
        total_tracks = df_raw['track_uid'].nunique()
        sub_final = df_final
    else:
        total_tracks = df_raw[df_raw['scenario'] == sc]['track_uid'].nunique()
        sub_final = df_final[df_final['scenario'] == sc] if not df_final.empty else pd.DataFrame()
            
    # 2. Contar medidos desde el FINAL
    measured_tracks = len(sub_final)
    
    # 3. Calcular métricas
    if measured_tracks > 0:
        mae = sub_final['abs_error_cm'].mean()
        std = sub_final['abs_error_cm'].std()
        mape = sub_final['rel_error_perc'].mean()
    else:
        mae = std = mape = 0.0
        
    success_perc = (measured_tracks / total_tracks * 100) if total_tracks > 0 else 0
    
    label = f"GLOBAL DAY" if sc == 'All' else sc
    print(f"{label:<15} | {total_tracks:<12} | {measured_tracks:<10} | {success_perc:<12.1f} | {mae:<10.2f} | {std:<10.2f} | {mape:<10.2f}")

print("="*85 + "\n")


for sc in scenarios:
    cprint(f"\n\n{'='*70}", "white", "on_magenta", attrs=["bold"])
    cprint(f"📊 PLOTS FOR SCENARIO: {sc.upper()}", "white", "on_magenta", attrs=["bold"])
    cprint(f"{'='*70}", "white", "on_magenta", attrs=["bold"])
    
    # 1. Filtrar el dataframe dependiendo del escenario
    if sc == 'All':
        df_sc_raw = df_raw.copy()
        context_label = f"{day_code} - GLOBAL"
    else:
        df_sc_raw = df_raw[df_raw['scenario'] == sc].copy()
        context_label = f"{day_code} - {sc.upper()}"
        
    if df_sc_raw.empty:
        print(f"⚠️ No data available for {sc.upper()}, skipping plots.")
        continue
    
    # 2. Generar gráficos
    stacked_frames = rutils.plot_frame_failures(
        df_sc_raw, 
        aspect_ratio_thr=ASPECT_RATIO_THR, 
        angle_thr=ANGLE_THR,
        figsize_video=(12,6), 
        figsize_global=(5,5), 
        show_global=True,
        context_label=context_label
    )

    track_failures = rutils.plot_tracks_failure_distribution(
        df_sc_raw, 
        aspect_ratio_thr=ASPECT_RATIO_THR, 
        angle_thr=ANGLE_THR,
        show_global=True, 
        figsize_video=(12,6), 
        figsize_global=(5,5),
        context_label=context_label
    )

    rutils.plot_aspect_ratio_vs_length(
        df_sc_raw, 
        ASPECT_RATIO_THR=ASPECT_RATIO_THR, 
        figsize=(10, 8),
        context_label=context_label
    ) 
    
    # 1. Gráfica de Cascada (Ablation)
    print("\n📈 Generating Pipeline Ablation Plots...")
    stages_dict, agg_stages_dict = rutils.plot_ablation_pipeline(
        df_sc_raw, 
        ASPECT_RATIO_THR=ASPECT_RATIO_THR, 
        ANGLE_THR=ANGLE_THR,
        context_label=context_label  
    )
    
    # 2. Interacción de umbrales
    print("\n📈 Generating Thresholds Interaction Plot...")
    rutils.plot_thresholds_interaction(
        df_sc_raw, 
        optimal_ar=ASPECT_RATIO_THR, 
        context=context_label
    )
    
    # 3. Relación de Error vs Geometría (Raw y Aislado)
    print("\n📈 Generating Error vs Geometry Analysis Plots...")
    rutils.plot_error_vs_geometry(
        df_sc_raw, 
        ar_thr=ASPECT_RATIO_THR, 
        angle_thr=ANGLE_THR, 
        context_label=context_label
    )
    
    print("\n📈 Generating Track Error vs Length Plot...")
    rutils.plot_error_vs_track_length(
        df_raw=df_sc_raw, 
        df_final=sub_final,  # <--- ¡AQUÍ LE PASAMOS TU CÁLCULO INTELIGENTE!
        context_label=context_label,
        min_frames_thr=6
    )
    
    print("\n📈 Generating Track Length Histogram...")
    rutils.plot_track_length_histogram(
        df_sc_raw, 
        min_frames_thr=5, # O el número que uses en el smart_aggregator
        context_label=context_label
    )
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 👉 WORKING ON: 2025_05_08
# Reading csv from /home/slimbook/fish_sizing/ARTICLE/DATASET_1/2025_05_08/2025_05_08_ALL_raw_aggregated.csv
#
# --- Processing 2025_05_08 ---
# Total raw frames with valid GT: 23256
# Total initial tracks: 126
# Frames belonging to 'measured' tracks: 12204
# 📉 Tracks descartados por 'track_failure_from_frames': 17
# 📉 Tracks descartados por 'smart_aggregator': 10
# ✅ FINAL RESULT: 99 independent FISH (tracks) successfully aggregated.
# 📊 Success Rate: 78.57% (99/126 tracks medidos con éxito)
#
# =====================================================================================
# DAILY SUMMARY: 2025_05_08
# =====================================================================================
# SCENARIO        | Total Tracks | Measured   | Success (%)  | MAE (cm)   | STD (cm)   | MAPE (%)
# -------------------------------------------------------------------------------------
# GLOBAL DAY      | 126          | 99         | 78.6         | 1.44       | 1.44       | 4.51
# single_fish     | 14           | 8          | 57.1         | 1.16       | 0.94       | 3.48
# multiple_fish   | 112          | 91         | 81.2         | 1.47       | 1.48       | 4.60
# =====================================================================================
#
#
#
# ======================================================================
# 📊 PLOTS FOR SCENARIO: ALL
# ======================================================================
# ============================================================
# 📊 TABLA 1: Distribución Global de Frames
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured     12204           52.48
# 1      incomplete_3D       298            1.28
# 2            borders      1844            7.93
# 3            overlap       810            3.48
# 4  aspect_ratio_fail      4658           20.03
# 5         angle_fail      3383           14.55
# 6        short_track         0            0.00
# 7              other        59            0.25
# ============================================================
# 📊 TABLA 1: Distribución Global de Tracks
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured       109           86.51
# 1      incomplete_3D         0            0.00
# 2            borders         3            2.38
# 3            overlap         3            2.38
# 4  aspect_ratio_fail         8            6.35
# 5         angle_fail         3            2.38
# 6        short_track         0            0.00
# 7              other         0            0.00
# ============================================================
# 📊 TABLA 2: Desglose por Vídeo
# ============================================================
# track_failure_reason  measured  incomplete_3D  borders  overlap  \
# source_folder
# 11-14-53_0                   1              0        0        0
# 11-17-18_0                   1              0        0        0
# 11-18-25_1                   1              0        0        0
# 11-19-32_2                   2              0        0        0
# 11-20-39_3                   1              0        0        0
# 11-20-56_0                   1              0        1        0
# 11-22-03_1                   2              0        0        0
# 11-23-09_2                   1              0        2        0
# 11-28-42_0                   3              0        0        0
# 11-29-16_1                   3              0        0        0
# 11-29-49_2                   3              0        0        0
# 11-30-34_0                   2              0        0        0
# 11-31-08_1                   4              0        0        0
# 11-33-23_0                   6              0        0        0
# 11-33-52_1                   1              0        0        0
# 11-36-36_0                   6              0        0        0
# 11-37-20_1                   6              0        0        0
# 11-41-45_0                   2              0        0        0
# 11-42-15_1                   1              0        0        0
# 11-44-48_0                   4              0        0        0
# 11-48-15_0                   8              0        0        1
# 11-49-52_0                   7              0        0        0
# 11-57-17_0                   3              0        0        0
# 11-57-59_0                   6              0        0        1
# 11-59-57_0                   5              0        0        0
# 12-00-39_0                   8              0        0        0
# 12-01-20_0                   9              0        0        1
# 12-02-02_0                   7              0        0        0
# 12-02-44_0                   5              0        0        0
#
# track_failure_reason  aspect_ratio_fail  angle_fail  short_track  other
# source_folder
# 11-14-53_0                            0           0            0      0
# 11-17-18_0                            0           1            0      0
# 11-18-25_1                            0           0            0      0
# 11-19-32_2                            0           0            0      0
# 11-20-39_3                            0           0            0      0
# 11-20-56_0                            0           0            0      0
# 11-22-03_1                            0           0            0      0
# 11-23-09_2                            0           0            0      0
# 11-28-42_0                            0           0            0      0
# 11-29-16_1                            0           1            0      0
# 11-29-49_2                            0           1            0      0
# 11-30-34_0                            0           0            0      0
# 11-31-08_1                            0           0            0      0
# 11-33-23_0                            0           0            0      0
# 11-33-52_1                            2           0            0      0
# 11-36-36_0                            1           0            0      0
# 11-37-20_1                            1           0            0      0
# 11-41-45_0                            0           0            0      0
# 11-42-15_1                            0           0            0      0
# 11-44-48_0                            0           0            0      0
# 11-48-15_0                            1           0            0      0
# 11-49-52_0                            0           0            0      0
# 11-57-17_0                            0           0            0      0
# 11-57-59_0                            1           0            0      0
# 11-59-57_0                            1           0            0      0
# 12-00-39_0                            1           0            0      0
# 12-01-20_0                            0           0            0      0
# 12-02-02_0                            0           0            0      0
# 12-02-44_0                            0           0            0      0
# 📈 Generating Pipeline Ablation Plots...
# ETAPA DEL PIPELINE (CASCADA)                  | ERROR MEDIO     | FRAMES VIVOS    | PECES (TRACKS)
# ----------------------------------------------------------------------------------------------------
# 0. Base (HDBSCAN without filters)             |  2.10 ± 2.41 cm |   21260 frames |   122 tracks
# 1. + Filter: No Borders                       |  2.10 ± 2.41 cm |   21260 frames |   122 tracks
# 2. + Filter: No Overlap                       |  1.97 ± 2.26 cm |   20459 frames |   119 tracks
# 3. + Filter: is_3D_complete                   |  1.81 ± 1.96 cm |   20124 frames |   117 tracks
# 4. + Filter: Aspect Ratio >= 3.0              |  1.46 ± 1.45 cm |   15566 frames |   105 tracks
# 5. + Filter: Z-Angle <= 30.0º                 |  1.44 ± 1.44 cm |   12204 frames |    99 tracks
# 📈 Generating Thresholds Interaction Plot...
# Evaluating Angles: 100%|██████████| 9/9 [00:07<00:00,  1.22it/s]
# 📈 Generating Error vs Geometry Analysis Plots...
# 📈 Generating Track Error vs Length Plot...
# 📈 Generating Track Length Histogram...
# ======================================================================
# 📊 PLOTS FOR SCENARIO: SINGLE_FISH
# ======================================================================
# ============================================================
# 📊 TABLA 1: Distribución Global de Frames
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured      2338           56.75
# 1      incomplete_3D        26            0.63
# 2            borders       209            5.07
# 3            overlap         0            0.00
# 4  aspect_ratio_fail      1397           33.91
# 5         angle_fail       144            3.50
# 6        short_track         0            0.00
# 7              other         6            0.15
# ============================================================
# 📊 TABLA 1: Distribución Global de Tracks
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured        10           71.43
# 1      incomplete_3D         0            0.00
# 2            borders         3           21.43
# 3            overlap         0            0.00
# 4  aspect_ratio_fail         0            0.00
# 5         angle_fail         1            7.14
# 6        short_track         0            0.00
# 7              other         0            0.00
# ============================================================
# 📊 TABLA 2: Desglose por Vídeo
# ============================================================
# track_failure_reason  measured  incomplete_3D  borders  overlap  \
# source_folder
# 11-14-53_0                   1              0        0        0
# 11-17-18_0                   1              0        0        0
# 11-18-25_1                   1              0        0        0
# 11-19-32_2                   2              0        0        0
# 11-20-39_3                   1              0        0        0
# 11-20-56_0                   1              0        1        0
# 11-22-03_1                   2              0        0        0
# 11-23-09_2                   1              0        2        0
#
# track_failure_reason  aspect_ratio_fail  angle_fail  short_track  other
# source_folder
# 11-14-53_0                            0           0            0      0
# 11-17-18_0                            0           1            0      0
# 11-18-25_1                            0           0            0      0
# 11-19-32_2                            0           0            0      0
# 11-20-39_3                            0           0            0      0
# 11-20-56_0                            0           0            0      0
# 11-22-03_1                            0           0            0      0
# 11-23-09_2                            0           0            0      0
# 📈 Generating Pipeline Ablation Plots...
# ETAPA DEL PIPELINE (CASCADA)                  | ERROR MEDIO     | FRAMES VIVOS    | PECES (TRACKS)
# ----------------------------------------------------------------------------------------------------
# 0. Base (HDBSCAN without filters)             |  2.61 ± 3.83 cm |    3902 frames |    10 tracks
# 1. + Filter: No Borders                       |  2.61 ± 3.83 cm |    3902 frames |    10 tracks
# 2. + Filter: No Overlap                       |  2.61 ± 3.83 cm |    3902 frames |    10 tracks
# 3. + Filter: is_3D_complete                   |  1.41 ± 0.99 cm |    3866 frames |     9 tracks
# 4. + Filter: Aspect Ratio >= 3.0              |  1.17 ± 0.93 cm |    2478 frames |     8 tracks
# 5. + Filter: Z-Angle <= 30.0º                 |  1.16 ± 0.94 cm |    2338 frames |     8 tracks
# 📈 Generating Thresholds Interaction Plot...
# Evaluating Angles: 100%|██████████| 9/9 [00:01<00:00,  6.66it/s]
# 📈 Generating Error vs Geometry Analysis Plots...
# 📈 Generating Track Error vs Length Plot...
# 📈 Generating Track Length Histogram...
# ======================================================================
# 📊 PLOTS FOR SCENARIO: MULTIPLE_FISH
# ======================================================================
# ============================================================
# 📊 TABLA 1: Distribución Global de Frames
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured      9866           51.56
# 1      incomplete_3D       272            1.42
# 2            borders      1635            8.54
# 3            overlap       810            4.23
# 4  aspect_ratio_fail      3261           17.04
# 5         angle_fail      3239           16.93
# 6        short_track         0            0.00
# 7              other        53            0.28
# ============================================================
# 📊 TABLA 1: Distribución Global de Tracks
# ============================================================
#       Causa de Fallo  Cantidad  Porcentaje (%)
# 0           measured        99           88.39
# 1      incomplete_3D         0            0.00
# 2            borders         0            0.00
# 3            overlap         3            2.68
# 4  aspect_ratio_fail         8            7.14
# 5         angle_fail         2            1.79
# 6        short_track         0            0.00
# 7              other         0            0.00
# ============================================================
# 📊 TABLA 2: Desglose por Vídeo
# ============================================================
# track_failure_reason  measured  incomplete_3D  borders  overlap  \
# source_folder
# 11-28-42_0                   3              0        0        0
# 11-29-16_1                   3              0        0        0
# 11-29-49_2                   3              0        0        0
# 11-30-34_0                   2              0        0        0
# 11-31-08_1                   4              0        0        0
# 11-33-23_0                   6              0        0        0
# 11-33-52_1                   1              0        0        0
# 11-36-36_0                   6              0        0        0
# 11-37-20_1                   6              0        0        0
# 11-41-45_0                   2              0        0        0
# 11-42-15_1                   1              0        0        0
# 11-44-48_0                   4              0        0        0
# 11-48-15_0                   8              0        0        1
# 11-49-52_0                   7              0        0        0
# 11-57-17_0                   3              0        0        0
# 11-57-59_0                   6              0        0        1
# 11-59-57_0                   5              0        0        0
# 12-00-39_0                   8              0        0        0
# 12-01-20_0                   9              0        0        1
# 12-02-02_0                   7              0        0        0
# 12-02-44_0                   5              0        0        0
#
# track_failure_reason  aspect_ratio_fail  angle_fail  short_track  other
# source_folder
# 11-28-42_0                            0           0            0      0
# 11-29-16_1                            0           1            0      0
# 11-29-49_2                            0           1            0      0
# 11-30-34_0                            0           0            0      0
# 11-31-08_1                            0           0            0      0
# 11-33-23_0                            0           0            0      0
# 11-33-52_1                            2           0            0      0
# 11-36-36_0                            1           0            0      0
# 11-37-20_1                            1           0            0      0
# 11-41-45_0                            0           0            0      0
# 11-42-15_1                            0           0            0      0
# 11-44-48_0                            0           0            0      0
# 11-48-15_0                            1           0            0      0
# 11-49-52_0                            0           0            0      0
# 11-57-17_0                            0           0            0      0
# 11-57-59_0                            1           0            0      0
# 11-59-57_0                            1           0            0      0
# 12-00-39_0                            1           0            0      0
# 12-01-20_0                            0           0            0      0
# 12-02-02_0                            0           0            0      0
# 12-02-44_0                            0           0            0      0
# 📈 Generating Pipeline Ablation Plots...
# ETAPA DEL PIPELINE (CASCADA)                  | ERROR MEDIO     | FRAMES VIVOS    | PECES (TRACKS)
# ----------------------------------------------------------------------------------------------------
# 0. Base (HDBSCAN without filters)             |  2.05 ± 2.26 cm |   17358 frames |   112 tracks
# 1. + Filter: No Borders                       |  2.05 ± 2.26 cm |   17358 frames |   112 tracks
# 2. + Filter: No Overlap                       |  1.92 ± 2.08 cm |   16557 frames |   109 tracks
# 3. + Filter: is_3D_complete                   |  1.85 ± 2.02 cm |   16258 frames |   108 tracks
# 4. + Filter: Aspect Ratio >= 3.0              |  1.49 ± 1.49 cm |   13088 frames |    97 tracks
# 5. + Filter: Z-Angle <= 30.0º                 |  1.47 ± 1.48 cm |    9866 frames |    91 tracks
# 📈 Generating Thresholds Interaction Plot...
# Evaluating Angles: 100%|██████████| 9/9 [00:08<00:00,  1.11it/s]
# 📈 Generating Error vs Geometry Analysis Plots...
# 📈 Generating Track Error vs Length Plot...
# 📈 Generating Track Length Histogram...
