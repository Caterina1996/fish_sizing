# %% [markdown]
# ## 🧪 Experiment 1 - 2024_11_12
#
# Un únic peix i la piscina sense mosaic, objectes o textura.
#
# ### 🐟 Peix 0
# - Llargària màxima: **31.5 cm**
# - Fins a la coa: **26.5 cm**
# - Punt mig de la coa: **29.5 cm**
#
# <img src="Peix0.jpeg" alt="Peix 0" width="200" style="transform: rotate(-180deg);"/>
#
# ---
#
# ## 🧪 Experiment 2 - 2024_11_28
#
# 3 peixos diferents i la piscina amb textura (mosaic) i una àmfora.
#
# ### 🐟 Peix 1
# - Llargària màxima: **19.4 cm**
# - Punt mig de la coa: **17.4 cm**
#
# <img src="Peix1.jpeg" alt="Peix 1" width="300" style="transform: rotate(-90deg);"/>
#
# ### 🐟 Peix 2
# - Llargària màxima: **28.9 cm**
# - Punt mig de la coa: **27.0 cm**
#
# <img src="Peix2.jpeg" alt="Peix 2" width="300" style="transform: rotate(-90deg);"/>
#
# ### 🐟 Peix 3
# - Llargària màxima: **21.6 cm**
# - Punt mig de la coa: **19.4 cm**
#
# <img src="Peix3.jpeg" alt="Peix 3" width="300" style="transform: rotate(-90deg);"/>
#
# ---
#
# ## 🧪 Experiment 3 - 2025_05_08
#
# 3 peixos (2 de la mateixa classe), la piscina amb textura (mosaic) i una àmfora.
# Tests a **major frame rate**.
# Els bagfiles a **30fps no s'han gravat bé**.
#
# ### 🐟 Peix 4 — *Espècie: Lubina*
# - Llargària màxima: **33.5 cm** (amb cua)
# - Sense cua: **30.0 cm**
#
# <img src="Peix4.jpeg" alt="Peix 4" width="300" style="transform: rotate(-90deg);"/>
#
# ### 🐟 Peix 5 — *Espècie: Ocha1*
# - Llargària màxima: **30.0? cm** (amb cua)
# - Sense cua: **28.0 cm**
# - Clip
#
# <img src="Peix5.jpeg" alt="Peix 5" width="300"/>
#
# ### 🐟 Peix 6 — *Espècie: Ocha2*
# - Llargària màxima: **33.5 cm** (amb cua)
# - Sense cua: **25.0 cm**
# - Cinta americana
#
# <img src="Peix6.jpeg" alt="Peix 6" width="300" style="transform: rotate(-90deg);"/>

# %%
a=[1,2,3]

for b in a:
    print(b)

# %%
# !pip install openpyxl

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from openpyxl import load_workbook
from pandas import ExcelWriter



# 1) Lubina -> 33,5 cm (tail included) // 30,0 cm (without tail)
# 2) Ocha1 -> 33,5 cm (tail included) // 28,0 cm (without tail) // clip ->>>> Corregit!! cinta americana
# 3) Ocha2 -> 30,0 cm (tail included) // 25,0 cm (without tail) // 

# Notes whatsap:
# Lubina 
# 33.75-8 total 
# Fins enmig de la cia 32cm
# Fins a la cosa 28.5

# Peix cinta americana :
# 33.8
# Sense la mini coa 31.9 
# Fins a la coa 28.4

# Peix 2 sense cinta americana:
# 30.8-9
# 26 sense la coa
# Out:
# Requirement already satisfied: openpyxl in /home/uib/miniconda3/envs/jupyterlab/lib/python3.13/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /home/uib/miniconda3/envs/jupyterlab/lib/python3.13/site-packages (from openpyxl) (2.0.0)

# %%
# INIT

# %%
# Pool test fishes Caterina 08_05_2025

# Fish species:

# 1) Lubina -> 33,5 cm (tail included) // 30,0 cm (without tail)
# 2) Ocha1 -> 33,5 cm (tail included) // 28,0 cm (without tail) // clip
# 3) Ocha2 -> 30,0 cm (tail included) // 25,0 cm (without tail) // cinta americana
# 11_30 (lubina + ocha petita)

"2025_05_08/11_30_34": {1:30, 4:33.5, 9:30, 18:33.5, 23:-100}
# Out:
#   Cell In[4], line 10
#     "2025_05_08/11_30_34": {1:30, 4:33.5, 9:30, 18:33.5, 23:-100}
#     ^
# SyntaxError: illegal target for annotation

# %%
### 🐟 Peix 0
# - Llargària màxima: **31.5 cm**
# - Fins a la coa: **26.5 cm**
# - Punt mig de la coa: **29.5 cm**

# ---

# ## 🧪 Experiment 2 - 2024_11_28

# 3 peixos diferents i la piscina amb textura (mosaic) i una àmfora.

# ### 🐟 Peix 1
# - Llargària màxima: **19.4 cm**
# - Punt mig de la coa: **17.4 cm**


# ### 🐟 Peix 2 (caballa)
# - Llargària màxima: **28.9 cm**
# - Punt mig de la coa: **27.0 cm**

# <img src="Peix2.jpeg" alt="Peix 2" width="300" style="transform: rotate(-90deg);"/>
# ### 🐟 Peix 3
# - Llargària màxima: **21.6 cm**
# - Punt mig de la coa: **19.4 cm**

# · Experiment 3:
# 1) Lubina -> 33,5 cm (tail included) // 30,0 cm (without tail)
# 2) Ocha1 -> 33,5 cm (tail included) // 28,0 cm (without tail) // clip ->>>> Corregit!! cinta americana
# 3) Ocha2 -> 30,0 cm (tail included) // 25,0 cm (without tail) // 

# Notes whatsap:
# Lubina 
# 33.75-8 total 
# Fins enmig de la cia 32cm
# Fins a la cosa 28.5

# Peix cinta americana :
# 33.8
# Sense la mini coa 31.9 
# Fins a la coa 28.4

# Peix 2 sense cinta americana:
# 30.8-9
# 26 sense la coa)

# %%
gt_measure = bagfile_gts[base_path]
gt_measure

# %%
def clasificar_medidas(df, agg=False, verbose=True):
    df = df.copy()

    def clasificar_error(x, umbral_good, umbral_medium):
        return 'good' if x < umbral_good else ('medium' if x < umbral_medium else 'bad')

    if agg:
        columnas = {
            'measure_ok_abs_max': ('Abs_ERROR (maxl) [cm]', 1, 2),
            'measure_ok_abs_mean': ('Abs_ERROR (meanl) [cm]', 1, 2),
            'measure_ok_rel_max': ('relative_error(maxl) [%]', 1, 5),
            'measure_ok_rel_mean': ('relative_error(meanl) [%]', 1, 5),
        }
        for nueva_col, (col, umbral_good, umbral_medium) in columnas.items():
            df[nueva_col] = df[col].apply(lambda x: clasificar_error(x, umbral_good, umbral_medium))

        if verbose:
            print("Resumen de clasificaciones (agregadas):\n")
            for col in columnas.keys():
                counts = df[col].value_counts()
                percentages = df[col].value_counts(normalize=True) * 100
                print(f"{col}:")
                print(counts)
                print("%", percentages.round(2), "\n")
                print("-" * 80)

    else:
        columnas = {
            'measure_ok_abs': ('Abs_ERROR [cm]', 1, 2),
            'measure_ok_rel': ('Rel_ERROR[%]', 1, 5),
        }
        for nueva_col, (col, umbral_good, umbral_medium) in columnas.items():
            df[nueva_col] = df[col].apply(lambda x: clasificar_error(x, umbral_good, umbral_medium))

        if verbose:
            print(df.head(), "\n")
            print(df.describe(), "\n")

            for col in columnas.keys():
                counts = df[col].value_counts()
                percentages = df[col].value_counts(normalize=True) * 100
                print(f"{col}:")
                print(counts)
                print("%", percentages.round(2), "\n")
                print("-" * 80)

    return df
    
def generate_analysis_plots(df):
    # Preprocessing (if not already done)
    df["elevation_abs"] = df["elevation_deg"].abs()
    df["elevation_rad"] = np.radians(df["elevation_deg"])
    df["elevation_sin"] = np.abs(np.sin(df["elevation_rad"]))
    
    # Define error metric and label column
    error_col = "Abs_ERROR [cm]"
    label_col = "measure_ok_abs"  # Make sure this column is present in your df
    
    # Plot
    fig, axs = plt.subplots(1, 3, figsize=(16, 6))
    
    # Plot 1: "Error vs Absolute Elevation Angle
    sns.scatterplot(x="elevation_abs", y=error_col, hue=label_col, data=df, ax=axs[0], palette="Set2", s=70)
    axs[0].set_title("Error vs Absolute Elevation Angle")
    axs[0].set_xlabel("|Elevation| (degrees)")
    axs[0].set_ylabel(error_col)
    axs[0].grid(True)
    
    # Plot 2: Error vs sin(|Elevation|)
    sns.scatterplot(x="elevation_sin", y=error_col, hue=label_col, data=df, ax=axs[1], palette="Set2", s=70)
    axs[1].set_title("Error vs sin(|Elevation|)")
    axs[1].set_xlabel("sin(|elevation|) [0: side-view, 1: head/tail-view]")
    axs[1].set_ylabel(error_col)
    axs[1].grid(True)
    
    # Plot 3: Error vs fish_dist_from_camera
    sns.scatterplot(x="fish_dist_from_camera",y=error_col,hue=label_col,data=df, ax=axs[2],palette="Set2",s=70)
    axs[2].set_title("Error vs fish_dist_from_camera")
    axs[2].set_xlabel("fish_dist_from_camera")  # Fixed: removed extra parenthesis
    axs[2].set_ylabel(error_col)
    axs[2].grid(True)
    
    
    plt.tight_layout()
    plt.legend(title="Quality Label")
    plt.show()

    return df 
    
# Function to color rows according to measure classification
def highlight_rows(row,quality_column="measure_ok_abs_max"):

    if row[quality_column]=='good':
         color = '#d9f2d9'  # soft green
    elif row[quality_column]=='medium':
        color = '#fff3cd'  # soft orange/yellow
    elif row[quality_column]=='bad':
         color = '#f8d7da'  # soft red/pink
    else:
        print("PROBLEM!!")
        color ="white"
    return [f'background-color: {color}'] * len(row)


def visualizar_outliers(df, track_id, porcentaje_umbral=0.1):
    grupo = df[df['track_id'] == track_id]
    valores = grupo['filtered_length'].sort_values(ascending=False).reset_index(drop=True)
    print("num de medidas = ",len(valores))

    media = valores.mean()
    threshold = porcentaje_umbral * media
    
    outlier_indices = []
    for i in range(len(valores) - 1):
        diff = valores[i] - valores[i + 1]
        if not ((diff <= porcentaje_umbral * media) or diff <0.03):
            print("DIFF:",diff)
            print("THR:",threshold)
            
            outlier_indices.append(i)

    # Marcar valores como outliers o no
    colores = ['red' if i in outlier_indices else 'skyblue' for i in range(len(valores))]

    # Visualización detallada
    plt.figure(figsize=(12, 6))
    plot = plt.scatter(range(len(valores)), valores, color=colores, edgecolor='black')
    plt.title(f'Valores ordenados de filtered_length para track_id: {track_id}')
    plt.xlabel('Índice (ordenado descendente)')
    plt.ylabel('filtered_length')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
    
def filtrar_outliers(grupo,porcentaje_umbral=0.05):
    valores = grupo['filtered_length'].sort_values(ascending=False).reset_index(drop=True)
    if len(valores) <= 2:
        return pd.DataFrame({'filtered_length': [valores.iloc[0]], 'track_id': grupo.name})
    
    media = valores.mean()
    for i in range(len(valores) - 1):
        diff = valores.iloc[i] - valores.iloc[i + 1]
        if (diff <= porcentaje_umbral * media) or diff <0.03:
            return pd.DataFrame({'filtered_length': [valores.iloc[i]], 'track_id': grupo.name})
        else: 
            print("*****************************************")
            print("Maximo descartado",valores.iloc[i])
            print("*****************************************")
    return pd.DataFrame({'filtered_length': [valores.iloc[-1]], 'track_id': grupo.name})

def descartar_outliers_por_track(df, porcentaje_umbral=0.05):
    # Aplicar filtrado
    df_max_filtrados = (
    df.groupby('track_id', group_keys=False)
      .apply(filtrar_outliers)
      .reset_index(drop=True))

    # Asociar las medidas gt_measure a cada track_id
    gt_measure = bagfile_gts[base_path]
    print(gt_measure)
    
    # Asignar al dataframe filtrado
    # df_max_filtrados["gt_measure"] = df_max_filtrados["track_id"].map(gt_measure)
    print("peix_measures",peix_measures)
    df_max_filtrados["gt_measure"] = df_max_filtrados["track_id"].map(gt_measure).map(peix_measures)
    df_max_filtrados['codi_escenari'] = codi_escenari
    df_max_filtrados['day'] = day
    df_max_filtrados['hour'] = hour
    
    # # Calcular el error absoluto en cm
    df_max_filtrados["Abs_ERROR [cm]"] = abs(df_max_filtrados["filtered_length"] - (df_max_filtrados["gt_measure"] / 100)) * 100
    # # Calcular el error relativo en porcentaje
    df_max_filtrados['relative_error [%]'] = df_max_filtrados["Abs_ERROR [cm]"] / (df_max_filtrados['gt_measure'] / 100)
    # Clasificación en datos agregados (por track_id)
    
    df_max_filtrados['measure_ok_abs'] = df_max_filtrados['Abs_ERROR [cm]'].apply(
        lambda x: 'good' if x < 1 else ('medium' if x <= 2 else 'bad')

    )
    print("------------------------------------------------------------------")
    print(df_max_filtrados)
    print("------------------------------------------------------------------")
    
    
    # Calcular estadísticas por track_id
    df_statistics = df.groupby('track_id', as_index=False).agg(
        count=('filtered_length', 'size'),
        max_length=('filtered_length', 'max'),
        mean_length=('filtered_length', 'mean'),
        elevation_deg_mean=('elevation_deg', 'mean'),
        std_dev=('filtered_length', 'std')
    )
    
    # Combinar stats con datos filtrados
    df_resultado = df_max_filtrados.merge(df_statistics, on='track_id', how='left')
    print(df_resultado.columns)

    column_order = [
        "codi_escenari",
        "day",
        "hour",        
        "track_id",
        "count",
        "filtered_length",
        "gt_measure",
        "Abs_ERROR [cm]",
        "relative_error [%]",
        "measure_ok_abs",
        "max_length",
        "mean_length",
        "std_dev",
        "elevation_deg_mean"
    ]
    
    df_resultado = df_resultado[column_order]

    return df_resultado



def guardar_resultado_excel(df, filename, sheet_name="resultados"):
    if os.path.exists(filename):
        # Si el archivo existe, abre y añade nueva hoja
        with ExcelWriter(filename, engine='openpyxl', mode='a', if_sheet_exists='new') as writer:
            df.to_excel(writer, sheet_name=sheet_name, index=False)
    else:
        # Si no existe, lo crea desde cero
        df.to_excel(filename, sheet_name=sheet_name, index=False)

# %%
peix_measures={"lubina0":31.5,"peix1":19.4,"caballa":28.9,"peix3":21.6,"lubina2":33.5,"ochoa_no_cinta":30,"ochoa_cinta":33.5,"fake_fish":-100 }

# %%
# bagfile_gts = {"2025_05_08/11_30_34": {1:30, 4:33.5, 9:30, 18:33.5, 23:-100},
#                "2025_05_08/11_36_35":{1, 2, 5, 6, 12, 16, 18, 20, 24}
#                #Escenari 1:
#                "2025_05_08/11_17_18": {1: 33.5, 6: -100, 9: -100},
#                "2025_05_08/11_41_03":{1:33.5},
#                "2024_11_12/11_00_27":{-1:31.5, 1:31.5, 2:31.5, 3:31.5, 6:31.5, 8:31.5, 11:31.5},
#                "2024_11_28/13_07_38":{1:28.9 , -1:28.9 , 6:28.9},
#                "2024_11_28/13_09_20":{-1: 28.9 , 4: 28.9 , 5: 28.9}}


# bagfile_gts = {"2025_05_08/11_30_34": {1:"ochoa_no_cinta", 4:"lubina2", 9:"ochoa_no_cinta", 18:"lubina2", 23:"fake_fish"},
#                "2025_05_08/11_36_35":{1:"ochoa_no_cinta", 2:"lubina2", 5:"ochoa_no_cinta", 6:"lubina2", 12:"ochoa_no_cinta", 16:"ochoa_no_cinta", 18:"ochoa_no_cinta", 20:"ochoa_no_cinta", 24:"lubina2"}
#                #Escenari 1:
#                "2025_05_08/11_17_18": {1: "lubina2", 6: "fake_fish", 9: "fake_fish"},
#                "2025_05_08/11_41_03":{1:"lubina2"},
#                "2024_11_12/11_00_27":{-1:"lubina0", 1:"lubina0", 2:"lubina0", 3:"lubina0", 6:"lubina0", 8:"lubina0", 11:"lubina0"},
#                "2024_11_28/13_07_38":{1:"caballa" , -1:"caballa" , 6:"caballa"},
#                "2024_11_28/13_09_20":{-1: "caballa" , 4: "caballa" , 5: "caballa"}}

# %%
# # INICIALITZACIONS -----------------------------------------------------------
# Escenari="Escenari_3/"
# base_path="2024_11_18/13_52_03"

# column_order = [
#     "codi_escenari",
#     "day",
#     "hour",        
#     "track_id",
#     "count",
#     "filtered_length",
#     "gt_measure",
#     "Abs_ERROR [cm]",
#     "relative_error [%]",
#     "measure_ok_abs",
#     "max_length",
#     "mean_length",
#     "std_dev",
#     "elevation_deg_mean",
#     "comentaris"
# ]

# df_all_results = pd.DataFrame(columns=column_order)


# day = base_path.split("/")[0]
# hour = base_path.split("/")[-1]
# codi_escenari="E"+Escenari.split("_")[-1][0]

# temp_code = ("-").join(base_path.split("/"))
# experiment_code = codi_escenari+"_"+temp_code


# out_escenari_agg_csv=codi_escenari+"_results_resume.csv"
# out_csv_name =experiment_code+"_results_agg.csv"

# df = pd.read_csv(Escenari+base_path+"/pointclouds/results/all_complete_ok_fish.csv").iloc[:,1:]
# df_resume = pd.read_csv(Escenari+base_path+"/pointclouds/results/resume.csv")

# df['codi_escenari'] = codi_escenari
# df['day'] = day
# df['hour'] = hour

# # Paso 3: Reordenar columnas (poner las nuevas al principio)
# cols = ['codi_escenari', 'day', 'hour'] + [col for col in df.columns if col not in ['codi_escenari', 'day', 'hour']]
# df = df[cols]


# peix_measures={"lubina0":31.5,"peix1":19.4,"caballa":28.9,"peix3":21.6,"lubina2":33.5,"ochoa_no_cinta":30,"ochoa_cinta":33.5,"fake_fish":-100,"no_track_E2":25}

# bagfile_gts = { 
#                 "2024_11_18/13_52_03":{1:"caballa", 4:"caballa", 11:"peix1", 19:"peix1", 20:"peix1", 22:"caballa", 26:"peix1",\
#                                        27:"caballa", 28:"caballa", 33:"peix1", 39:"caballa", 41:"peix1", \
#                                        47:"peix1", 49:"peix3", 50:"peix1", 52:"caballa", 54:"peix1", 55:"peix3", 56:"peix1", 58:"peix1"},

#                 "2025_05_08/11_57_58":{1:"lubina2", 2:"ochoa_cinta", 34:"fake_fish", 37:"lubina2", 6:"ochoa_no_cinta", 10:"ochoa_no_cinta", 27:"ochoa_no_cinta",\
#                                        30:"ochoa_no_cinta", 31:"ochoa_cinta"},
#                 # 11_48_14 -> Aquest es un poc trambòlico xq el tracker es confon quan es creuen peixos.
#                 "2025_05_08/11_48_14":{32:"ochoa_cinta", 1:"lubina2", 2:"ochoa_no_cinta", 3:"ochoa_cinta", 6:"ochoa_cinta", 8:"ochoa_cinta", 16:"ochoa_cinta", \
#                                             19:"lubina2", 21:"ochoa_cinta", 22:"ochoa_no_cinta", 23:"lubina2", 28:"lubina2", 29:"ochoa_cinta", 30:"ochoa_cinta"},
#                 # Escenari_2
#                "2025_05_08/11_30_34": {1:"ochoa_no_cinta", 4:"lubina2", 9:"ochoa_no_cinta", 18:"lubina2", 23:"fake_fish"},
#                "2025_05_08/11_36_35":{1:"ochoa_no_cinta", 2:"lubina2", 5:"ochoa_no_cinta", 6:"lubina2", 12:"ochoa_no_cinta", 16:"ochoa_no_cinta", 18:"ochoa_no_cinta", 20:"ochoa_no_cinta", 24:"lubina2"},
#                "2025_05_08/11_44_47":{1:"lubina2", 4:"ochoa_no_cinta", 14:"ochoa_no_cinta"},
#                "2024_11_28/13_19_06":{1:"caballa", 2:"peix3", 8:"peix3", 9:"caballa", 10:"peix3", 11:"caballa", 15:"peix3", 19:"fake_fish"},
#                "2024_11_28/13_47_08":{1:"caballa", 3:"peix3", 6:"peix3", 10:"caballa", 11:"peix3", -1:"no_track_E2"},
#                #Escenari 1:
#                "2025_05_08/11_17_18": {1: "lubina2", 6: "fake_fish", 9: "fake_fish"},
#                "2025_05_08/11_41_03":{1:"lubina2"},
#                "2024_11_12/11_00_27":{-1:"lubina0", 1:"lubina0", 2:"lubina0", 3:"lubina0", 6:"lubina0", 8:"lubina0", 11:"lubina0"},
#                "2024_11_28/13_07_38":{1:"caballa" , -1:"caballa" , 6:"caballa"},
#                "2024_11_28/13_09_20":{-1: "caballa" , 4: "caballa" , 5: "caballa"}}


# # bagfile_gts = {"2025_05_08/11_30_34": {1:30, 4:33.5, 9:30, 18:33.5, 23:-100},
# #                "2025_05_08/11_36_35":{1, 2, 5, 6, 12, 16, 18, 20, 24},
# #                #Escenari 1:
# #                "2025_05_08/11_17_18": {1: 33.5, 6: -100, 9: -100},
# #                "2025_05_08/11_41_03":{1:33.5},
# #                "2024_11_12/11_00_27":{-1:31.5, 1:31.5, 2:31.5, 3:31.5, 6:31.5, 8:31.5, 11:31.5},
# #                "2024_11_28/13_07_38":{1:28.9 , -1:28.9 , 6:28.9},
# #                "2024_11_28/13_09_20":{-1: 28.9 , 4: 28.9 , 5: 28.9}}
              
# #----------------------------------------------------------------------------------

# print("Tracks ids present in this video:")
# print(set(df["track_id"]))

# # Ja he generat el gt
# if base_path in bagfile_gts.keys():

#     gt_measure = bagfile_gts[base_path]
#     print(gt_measure)
        
    
#     df["gt_measure"] = df["track_id"].map(gt_measure).map(peix_measures)
#     df_resume["gt_measure"] = df_resume["track_id"].map(gt_measure).map(peix_measures)
#     # df_resume["gt_measure"] = df["track_id"].map(gt_measure[peix_measures])
#     df.sort_values(by=['frame_id'])

#     df["Abs_ERROR [cm]"]=abs(df["filtered_length"]-(df["gt_measure"]/100))*100
#     df['Rel_ERROR[%]'] = df['Abs_ERROR [cm]'] / (df['gt_measure']/100)

#     print(df.head())
#     print("----------------------------------- \n \n")

#     df = clasificar_medidas(df, agg=False)
#     # print(df.head())
    
#     df = generate_analysis_plots(df)

#     # Descomentar para guardar todas las medidas sin agregar clasificadas:
#     # styled_df = df.style.apply(lambda row: highlight_rows(row, quality_column="measure_ok_abs"), axis=1)
#     # styled_df.to_excel(out_csv_name+'.xlsx', engine='openpyxl', index=False)

#     df_resultado=descartar_outliers_por_track(df, porcentaje_umbral=0.1)
#     print(df_resultado.head())
    

#     df_resultado["Comentaris"] = ("")
#     # df_resultado.loc[df_resultado["track_id"] != 1, "Comentaris"] = ("")

#     df_resultado_colored = df_resultado.style.apply(lambda row: highlight_rows(row, quality_column='measure_ok_abs'), axis=1)

# %%
# INICIALITZACIONS -----------------------------------------------------------

column_order = [
    "codi_escenari",
    "day",
    "hour",        
    "track_id",
    "count",
    "filtered_length",
    "gt_measure",
    "Abs_ERROR [cm]",
    "relative_error [%]",
    "measure_ok_abs",
    "max_length",
    "mean_length",
    "std_dev",
    "elevation_deg_mean",
    "comentaris"
]

df_all_results = pd.DataFrame(columns=column_order)

Escenari="Escenari_3/"
codi_escenari="E"+Escenari.split("_")[-1][0]
# base_path="2024_11_18/13_52_03"


peix_measures={"lubina0":31.5,"peix1":19.4,"caballa":28.9,"peix3":21.6,"lubina2":33.5,"ochoa_no_cinta":30,"ochoa_cinta":33.5,"fake_fish":-100,"no_track_E2":25}

bagfile_gts = { "2024_11_18/13_52_03":{1:"caballa", 4:"caballa", 11:"peix1", 19:"peix1", 20:"peix1", 22:"caballa", 26:"peix1",\
                                       27:"caballa", 28:"caballa", 33:"peix1", 39:"caballa", 41:"peix1", \
                                       47:"peix1", 49:"peix3", 50:"peix1", 52:"caballa", 54:"peix1", 55:"peix3", 56:"peix1", 58:"peix1"},

                "2025_05_08/11_57_58":{1:"lubina2", 2:"ochoa_cinta", 34:"fake_fish", 37:"lubina2", 6:"ochoa_no_cinta", 10:"ochoa_no_cinta", 27:"ochoa_no_cinta",\
                                       30:"ochoa_no_cinta", 31:"ochoa_cinta"}}
                # 11_48_14 -> Aquest es un poc trambòlico xq el tracker es confon quan es creuen peixos.
                # "2025_05_08/11_48_14":{32:"ochoa_cinta", 1:"lubina2", 2:"ochoa_no_cinta", 3:"ochoa_cinta", 6:"ochoa_cinta", 8:"ochoa_cinta", 16:"ochoa_cinta", \
                #                             19:"lubina2", 21:"ochoa_cinta", 22:"ochoa_no_cinta", 23:"lubina2", 28:"lubina2", 29:"ochoa_cinta", 30:"ochoa_cinta"},
                # }}

for base_path in bagfile_gts.keys():
    day = base_path.split("/")[0]
    hour = base_path.split("/")[-1]
    
    
    temp_code = ("-").join(base_path.split("/"))
    experiment_code = codi_escenari+"_"+temp_code
    
    
    out_escenari_agg_csv=codi_escenari+"_results_resume.csv"
    out_csv_name =experiment_code+"_results_agg.csv"
    
    df = pd.read_csv(Escenari+base_path+"/pointclouds/results/all_complete_ok_fish.csv").iloc[:,1:]
    df_resume = pd.read_csv(Escenari+base_path+"/pointclouds/results/resume.csv")
    
    df['codi_escenari'] = codi_escenari
    df['day'] = day
    df['hour'] = hour
    
    # Paso 3: Reordenar columnas (poner las nuevas al principio)
    cols = ['codi_escenari', 'day', 'hour'] + [col for col in df.columns if col not in ['codi_escenari', 'day', 'hour']]
    df = df[cols]
    
    
    
    
    # bagfile_gts = {"2025_05_08/11_30_34": {1:30, 4:33.5, 9:30, 18:33.5, 23:-100},
    #                "2025_05_08/11_36_35":{1, 2, 5, 6, 12, 16, 18, 20, 24},
    #                #Escenari 1:
    #                "2025_05_08/11_17_18": {1: 33.5, 6: -100, 9: -100},
    #                "2025_05_08/11_41_03":{1:33.5},
    #                "2024_11_12/11_00_27":{-1:31.5, 1:31.5, 2:31.5, 3:31.5, 6:31.5, 8:31.5, 11:31.5},
    #                "2024_11_28/13_07_38":{1:28.9 , -1:28.9 , 6:28.9},
    #                "2024_11_28/13_09_20":{-1: 28.9 , 4: 28.9 , 5: 28.9}}
                  
    #----------------------------------------------------------------------------------
    
    print("Tracks ids present in this video:")
    print(set(df["track_id"]))
    
    # Ja he generat el gt
    if base_path in bagfile_gts.keys():
    
        gt_measure = bagfile_gts[base_path]
        print(gt_measure)
            
        
        df["gt_measure"] = df["track_id"].map(gt_measure).map(peix_measures)
        df_resume["gt_measure"] = df_resume["track_id"].map(gt_measure).map(peix_measures)
        # df_resume["gt_measure"] = df["track_id"].map(gt_measure[peix_measures])
        df.sort_values(by=['frame_id'])
    
        df["Abs_ERROR [cm]"]=abs(df["filtered_length"]-(df["gt_measure"]/100))*100
        df['Rel_ERROR[%]'] = df['Abs_ERROR [cm]'] / (df['gt_measure']/100)
    
        print(df.head())
        print("----------------------------------- \n \n")
    
        df = clasificar_medidas(df, agg=False)
        # print(df.head())
        
        df = generate_analysis_plots(df)
    
        # Descomentar para guardar todas las medidas sin agregar clasificadas:
        # styled_df = df.style.apply(lambda row: highlight_rows(row, quality_column="measure_ok_abs"), axis=1)
        # styled_df.to_excel(out_csv_name+'.xlsx', engine='openpyxl', index=False)
    
        df_resultado=descartar_outliers_por_track(df, porcentaje_umbral=0.1)
        print(df_resultado.head())
        
    
        df_resultado["Comentaris"] = ("")
        # df_resultado.loc[df_resultado["track_id"] != 1, "Comentaris"] = ("")
    
        df_resultado_colored = df_resultado.style.apply(lambda row: highlight_rows(row, quality_column='measure_ok_abs'), axis=1)

        # Guardar con append o crear nuevo
        df_resultado.to_csv(experiment_code+".csv")
        df_resultado_colored.to_excel("results/E1/"+experiment_code+'.xlsx', engine='openpyxl', index=False)
        
        # Append df del escenario y guardar:
        df_all_results = pd.concat([df_all_results, df_resultado], ignore_index=True)
        print("++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
        print("++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
        print(df_all_results.describe())
        print("++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
        print("++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
        
        
csv_path ="results/E3/"+ codi_escenari + ".csv"
# Comprobar si el archivo ya existe
# file_exists = os.path.exists(csv_path)
# Guardar con append o crear nuevo
df_all_results.to_csv(
    csv_path,
    # mode='a' if file_exists else 'w',
    mode='w',
    header=not file_exists,  # Solo escribir encabezado si el archivo no existe
    index=False
)

# Apply styling and save
df_all_results_colored = df_all_results.style.apply(lambda row: highlight_rows(row, quality_column='measure_ok_abs'), axis=1)
df_all_results_colored.to_excel("results/E3/"+codi_escenari+'.xlsx', engine='openpyxl', index=False)

        
        
df_all_results_colored
# Out:
# Tracks ids present in this video:
# {1, 4, 11, 19, 20, 22, 26, 27, 28, 33, 39, 41, 47, 49, 50, 52, 54, 55, 56, 58}
# {1: 'caballa', 4: 'caballa', 11: 'peix1', 19: 'peix1', 20: 'peix1', 22: 'caballa', 26: 'peix1', 27: 'caballa', 28: 'caballa', 33: 'peix1', 39: 'caballa', 41: 'peix1', 47: 'peix1', 49: 'peix3', 50: 'peix1', 52: 'caballa', 54: 'peix1', 55: 'peix3', 56: 'peix1', 58: 'peix1'}
#   codi_escenari         day      hour frame_id  class_name  Object_id  \
# 0            E3  2024_11_18  13_52_03   frame1           9        127
# 1            E3  2024_11_18  13_52_03  frame30           9        255
# 2            E3  2024_11_18  13_52_03  frame31           9        255
# 3            E3  2024_11_18  13_52_03  frame37           9        255
# 4            E3  2024_11_18  13_52_03  frame49           9        127
#
#    track_id  is_3D_complete  in_image_borders  \
# 0         1               1             False
# 1         4               1             False
# 2         4               1             False
# 3         4               1             False
# 4         4               1             False
#
#                           fish_direction  elevation_deg  azimuth_deg  \
# 0  [-0.98625272  0.07695524  0.14623083]       8.408561   175.538370
# 1  [-0.92691681  0.2630677  -0.26762028]     -15.522709   164.155560
# 2  [-0.91071348  0.28540261 -0.29857378]     -17.371961   162.599868
# 3  [-0.97343883  0.22002786 -0.06328177]      -3.628202   167.263375
# 4  [ 0.55824035 -0.40280195  0.72534012]      46.497150   -35.812577
#
#    raw_length  filtered_length  fish_dist_from_camera  gt_measure  \
# 0    0.284927         0.284927               1.559434        28.9
# 1    0.281117         0.281117               1.587732        28.9
# 2    0.275128         0.275128               1.589821        28.9
# 3    0.285755         0.285755               1.645132        28.9
# 4    0.268150         0.268150               1.763914        28.9
#
#    Abs_ERROR [cm]  Rel_ERROR[%]
# 0        0.407262      1.409213
# 1        0.788285      2.727631
# 2        1.387241      4.800143
# 3        0.324461      1.122702
# 4        2.084957      7.214385
# -----------------------------------
#
#
#   codi_escenari         day      hour frame_id  class_name  Object_id  \
# 0            E3  2024_11_18  13_52_03   frame1           9        127
# 1            E3  2024_11_18  13_52_03  frame30           9        255
# 2            E3  2024_11_18  13_52_03  frame31           9        255
# 3            E3  2024_11_18  13_52_03  frame37           9        255
# 4            E3  2024_11_18  13_52_03  frame49           9        127
#
#    track_id  is_3D_complete  in_image_borders  \
# 0         1               1             False
# 1         4               1             False
# 2         4               1             False
# 3         4               1             False
# 4         4               1             False
#
#                           fish_direction  elevation_deg  azimuth_deg  \
# 0  [-0.98625272  0.07695524  0.14623083]       8.408561   175.538370
# 1  [-0.92691681  0.2630677  -0.26762028]     -15.522709   164.155560
# 2  [-0.91071348  0.28540261 -0.29857378]     -17.371961   162.599868
# 3  [-0.97343883  0.22002786 -0.06328177]      -3.628202   167.263375
# 4  [ 0.55824035 -0.40280195  0.72534012]      46.497150   -35.812577
#
#    raw_length  filtered_length  fish_dist_from_camera  gt_measure  \
# 0    0.284927         0.284927               1.559434        28.9
# 1    0.281117         0.281117               1.587732        28.9
# 2    0.275128         0.275128               1.589821        28.9
# 3    0.285755         0.285755               1.645132        28.9
# 4    0.268150         0.268150               1.763914        28.9
#
#    Abs_ERROR [cm]  Rel_ERROR[%] measure_ok_abs measure_ok_rel
# 0        0.407262      1.409213           good         medium
# 1        0.788285      2.727631           good         medium
# 2        1.387241      4.800143         medium         medium
# 3        0.324461      1.122702           good         medium
# 4        2.084957      7.214385            bad            bad
#
#        class_name   Object_id    track_id  is_3D_complete  elevation_deg  \
# count       375.0  375.000000  375.000000           375.0     375.000000
# mean          9.0  191.877333   37.314667             1.0      12.245047
# std           0.0   65.508834   17.526517             0.0      19.391984
# min           9.0   85.000000    1.000000             1.0     -27.955690
# 25%           9.0  127.000000   22.000000             1.0      -2.751569
# 50%           9.0  170.000000   47.000000             1.0      13.020194
# 75%           9.0  255.000000   52.000000             1.0      26.406793
# max           9.0  255.000000   58.000000             1.0      58.269948
#
#        azimuth_deg  raw_length  filtered_length  fish_dist_from_camera  \
# count   375.000000  375.000000       375.000000             375.000000
# mean    -40.013980    0.256101         0.222365               1.378172
# std      96.764002    0.177527         0.045806               0.365173
# min    -178.074918    0.152218         0.152218               0.779924
# 25%    -120.624626    0.186621         0.186575               1.018304
# 50%     -51.086885    0.195625         0.195493               1.454765
# 75%     -34.944734    0.283098         0.277146               1.678387
# max     175.538370    1.947335         0.366902               1.971042
#
#        gt_measure  Abs_ERROR [cm]  Rel_ERROR[%]
# count  375.000000      375.000000    375.000000
# mean    22.830933        0.926975      4.220187
# std      4.288082        1.091540      5.094855
# min     19.400000        0.009560      0.045596
# 25%     19.400000        0.336343      1.501597
# 50%     19.400000        0.637724      2.906165
# 75%     28.900000        1.168371      4.994523
# max     28.900000       15.090248     69.862261
#
# measure_ok_abs:
# measure_ok_abs
# good      263
# medium     76
# bad        36
# Name: count, dtype: int64
# % measure_ok_abs
# good      70.13
# medium    20.27
# bad        9.60
# Name: proportion, dtype: float64
#
# --------------------------------------------------------------------------------
# measure_ok_rel:
# measure_ok_rel
# medium    223
# bad        94
# good       58
# Name: count, dtype: int64
# % measure_ok_rel
# medium    59.47
# bad       25.07
# good      15.47
# Name: proportion, dtype: float64
#
# --------------------------------------------------------------------------------
# *****************************************
# Maximo descartado 0.3669024843324878
# *****************************************
# {1: 'caballa', 4: 'caballa', 11: 'peix1', 19: 'peix1', 20: 'peix1', 22: 'caballa', 26: 'peix1', 27: 'caballa', 28: 'caballa', 33: 'peix1', 39: 'caballa', 41: 'peix1', 47: 'peix1', 49: 'peix3', 50: 'peix1', 52: 'caballa', 54: 'peix1', 55: 'peix3', 56: 'peix1', 58: 'peix1'}
# peix_measures {'lubina0': 31.5, 'peix1': 19.4, 'caballa': 28.9, 'peix3': 21.6, 'lubina2': 33.5, 'ochoa_no_cinta': 30, 'ochoa_cinta': 33.5, 'fake_fish': -100, 'no_track_E2': 25}
# ------------------------------------------------------------------
#     filtered_length  track_id  gt_measure codi_escenari         day      hour  \
# 0          0.284927         1        28.9            E3  2024_11_18  13_52_03
# 1          0.296187         4        28.9            E3  2024_11_18  13_52_03
# 2          0.186052        11        19.4            E3  2024_11_18  13_52_03
# 3          0.194707        19        19.4            E3  2024_11_18  13_52_03
# 4          0.194985        20        19.4            E3  2024_11_18  13_52_03
# 5          0.299642        22        28.9            E3  2024_11_18  13_52_03
# 6          0.197036        26        19.4            E3  2024_11_18  13_52_03
# 7          0.313978        27        28.9            E3  2024_11_18  13_52_03
# 8          0.285720        28        28.9            E3  2024_11_18  13_52_03
# 9          0.192955        33        19.4            E3  2024_11_18  13_52_03
# 10         0.292334        39        28.9            E3  2024_11_18  13_52_03
# 11         0.185234        41        19.4            E3  2024_11_18  13_52_03
# 12         0.196993        47        19.4            E3  2024_11_18  13_52_03
# 13         0.225458        49        21.6            E3  2024_11_18  13_52_03
# 14         0.184522        50        19.4            E3  2024_11_18  13_52_03
# 15         0.295133        52        28.9            E3  2024_11_18  13_52_03
# 16         0.197759        54        19.4            E3  2024_11_18  13_52_03
# 17         0.246103        55        21.6            E3  2024_11_18  13_52_03
# 18         0.195493        56        19.4            E3  2024_11_18  13_52_03
# 19         0.206999        58        19.4            E3  2024_11_18  13_52_03
#
#     Abs_ERROR [cm]  relative_error [%] measure_ok_abs
# 0         0.407262            1.409213           good
# 1         0.718732            2.486963           good
# 2         0.794781            4.096807           good
# 3         0.070670            0.364279           good
# 4         0.098462            0.507534           good
# 5         1.064224            3.682435         medium
# 6         0.303601            1.564956           good
# 7         2.497765            8.642785            bad
# 8         0.327990            1.134914           good
# 9         0.104485            0.538582           good
# 10        0.333387            1.153590           good
# 11        0.876571            4.518408           good
# 12        0.299298            1.542774           good
# 13        0.945793            4.378673           good
# 14        0.947804            4.885589           good
# 15        0.613298            2.122138           good
# 16        0.375929            1.937780           good
# 17        3.010316           13.936648            bad
# 18        0.149300            0.769590           good
# 19        1.299875            6.700387         medium
# ------------------------------------------------------------------
# Index(['filtered_length', 'track_id', 'gt_measure', 'codi_escenari', 'day',
#        'hour', 'Abs_ERROR [cm]', 'relative_error [%]', 'measure_ok_abs',
#        'count', 'max_length', 'mean_length', 'elevation_deg_mean', 'std_dev'],
#       dtype='object')
#   codi_escenari         day      hour  track_id  count  filtered_length  \
# 0            E3  2024_11_18  13_52_03         1      1         0.284927
# 1            E3  2024_11_18  13_52_03         4     36         0.296187
# 2            E3  2024_11_18  13_52_03        11     13         0.186052
# 3            E3  2024_11_18  13_52_03        19     23         0.194707
# 4            E3  2024_11_18  13_52_03        20     11         0.194985
#
#    gt_measure  Abs_ERROR [cm]  relative_error [%] measure_ok_abs  max_length  \
# 0        28.9        0.407262            1.409213           good    0.284927
# 1        28.9        0.718732            2.486963           good    0.296187
# 2        19.4        0.794781            4.096807           good    0.186052
# 3        19.4        0.070670            0.364279           good    0.194707
# 4        19.4        0.098462            0.507534           good    0.194985
#
#    mean_length   std_dev  elevation_deg_mean
# 0     0.284927       NaN            8.408561
# 1     0.281548  0.009835            8.953825
# 2     0.180152  0.005984           24.580068
# 3     0.183036  0.009534           28.338096
# 4     0.188530  0.003747           19.037491
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#        filtered_length  gt_measure  Abs_ERROR [cm]  relative_error [%]  \
# count        20.000000   20.000000       20.000000           20.000000
# mean          0.233611   22.945000        0.761977            3.318702
# std           0.048847    4.531118        0.772967            3.344275
# min           0.184522   19.400000        0.070670            0.364279
# 25%           0.194915   19.400000        0.302526            1.148921
# 50%           0.202379   19.400000        0.510280            2.029959
# 75%           0.287374   28.900000        0.946296            4.413607
# max           0.313978   28.900000        3.010316           13.936648
#
#        max_length  mean_length    std_dev  elevation_deg_mean
# count   20.000000    20.000000  19.000000           20.000000
# mean     0.239651     0.223042   0.008294           15.794468
# std      0.057223     0.047673   0.005630           12.054566
# min      0.184522     0.176454   0.001709           -3.467909
# 25%      0.194915     0.183854   0.004747            8.128085
# 50%      0.202379     0.191328   0.006476           16.495755
# 75%      0.293034     0.282087   0.009684           23.014034
# max      0.366902     0.293955   0.025339           42.801707
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Tracks ids present in this video:
# {1, 2, 34, 37, 6, 10, 27, 30, 31}
# {1: 'lubina2', 2: 'ochoa_cinta', 34: 'fake_fish', 37: 'lubina2', 6: 'ochoa_no_cinta', 10: 'ochoa_no_cinta', 27: 'ochoa_no_cinta', 30: 'ochoa_no_cinta', 31: 'ochoa_cinta'}
#   codi_escenari         day      hour frame_id  class_name  Object_id  \
# 0            E3  2025_05_08  11_57_58   frame7           9        127
# 1            E3  2025_05_08  11_57_58   frame7           9        255
# 2            E3  2025_05_08  11_57_58  frame14           9        127
# 3            E3  2025_05_08  11_57_58  frame14           9        255
# 4            E3  2025_05_08  11_57_58  frame15           9        127
#
#    track_id  is_3D_complete  in_image_borders  \
# 0         1               1             False
# 1         2               1             False
# 2         1               1             False
# 3         2               1             False
# 4         1               1             False
#
#                           fish_direction  elevation_deg  azimuth_deg  \
# 0  [-0.32007196  0.31780999  0.89249692]      31.452433   -47.110947
# 1     [0.77274568 0.38724661 0.50289579]       0.075094    25.443910
# 2  [-0.47600052  0.4161768   0.77473891]      29.463233   -45.742346
# 3     [0.70725775 0.4107572  0.57538248]       0.909667    24.860697
# 4  [-0.73092998  0.68182111 -0.02934866]      27.673585   -43.553596
#
#    raw_length  filtered_length  fish_dist_from_camera  gt_measure  \
# 0    1.213105         0.318835               1.696389        33.5
# 1    0.501436         0.316543               0.853063        33.5
# 2    0.786381         0.321604               1.756200        33.5
# 3    2.251732         0.319894               0.852804        33.5
# 4    0.593185         0.320733               1.758143        33.5
#
#    Abs_ERROR [cm]  Rel_ERROR[%]
# 0        1.616486      4.825331
# 1        1.845703      5.509561
# 2        1.339583      3.998755
# 3        1.510624      4.509325
# 4        1.426748      4.258948
# -----------------------------------
#
#
#   codi_escenari         day      hour frame_id  class_name  Object_id  \
# 0            E3  2025_05_08  11_57_58   frame7           9        127
# 1            E3  2025_05_08  11_57_58   frame7           9        255
# 2            E3  2025_05_08  11_57_58  frame14           9        127
# 3            E3  2025_05_08  11_57_58  frame14           9        255
# 4            E3  2025_05_08  11_57_58  frame15           9        127
#
#    track_id  is_3D_complete  in_image_borders  \
# 0         1               1             False
# 1         2               1             False
# 2         1               1             False
# 3         2               1             False
# 4         1               1             False
#
#                           fish_direction  elevation_deg  azimuth_deg  \
# 0  [-0.32007196  0.31780999  0.89249692]      31.452433   -47.110947
# 1     [0.77274568 0.38724661 0.50289579]       0.075094    25.443910
# 2  [-0.47600052  0.4161768   0.77473891]      29.463233   -45.742346
# 3     [0.70725775 0.4107572  0.57538248]       0.909667    24.860697
# 4  [-0.73092998  0.68182111 -0.02934866]      27.673585   -43.553596
#
#    raw_length  filtered_length  fish_dist_from_camera  gt_measure  \
# 0    1.213105         0.318835               1.696389        33.5
# 1    0.501436         0.316543               0.853063        33.5
# 2    0.786381         0.321604               1.756200        33.5
# 3    2.251732         0.319894               0.852804        33.5
# 4    0.593185         0.320733               1.758143        33.5
#
#    Abs_ERROR [cm]  Rel_ERROR[%] measure_ok_abs measure_ok_rel
# 0        1.616486      4.825331         medium         medium
# 1        1.845703      5.509561         medium            bad
# 2        1.339583      3.998755         medium         medium
# 3        1.510624      4.509325         medium         medium
# 4        1.426748      4.258948         medium         medium
#
#        class_name   Object_id    track_id  is_3D_complete  elevation_deg  \
# count       490.0  490.000000  490.000000           490.0     490.000000
# mean          9.0  172.255102   13.985714             1.0       4.826345
# std           0.0   70.381797   13.712569             0.0      16.583586
# min           9.0   63.000000    1.000000             1.0     -34.728537
# 25%           9.0   85.000000    2.000000             1.0      -3.364878
# 50%           9.0  170.000000   10.000000             1.0       3.159640
# 75%           9.0  255.000000   30.000000             1.0      12.496511
# max           9.0  255.000000   37.000000             1.0      75.394156
#
#        azimuth_deg  raw_length  filtered_length  fish_dist_from_camera  \
# count   490.000000  490.000000       490.000000             490.000000
# mean     17.660475    0.466127         0.287364               1.561417
# std      94.215910    0.468616         0.039093               0.464477
# min    -178.909713    0.084256         0.073921               0.852804
# 25%     -31.814328    0.282482         0.272337               1.203806
# 50%      22.331840    0.306687         0.296836               1.420809
# 75%      51.637237    0.322744         0.314274               2.050325
# max     178.463323    2.685642         0.440771               2.482528
#
#        gt_measure  Abs_ERROR [cm]  Rel_ERROR[%]
# count  490.000000      490.000000    490.000000
# mean    30.952041        4.815909      9.860164
# std     13.412111       12.409320     16.709483
# min   -100.000000        0.017002   -127.977129
# 25%     30.000000        1.598358      4.733074
# 50%     33.500000        2.562778      7.758399
# 75%     33.500000        4.828491     14.649944
# max     33.500000      127.977129     71.914645
#
# measure_ok_abs:
# measure_ok_abs
# bad       318
# medium    118
# good       54
# Name: count, dtype: int64
# % measure_ok_abs
# bad       64.90
# medium    24.08
# good      11.02
# Name: proportion, dtype: float64
#
# --------------------------------------------------------------------------------
# measure_ok_rel:
# measure_ok_rel
# bad       357
# medium    120
# good       13
# Name: count, dtype: int64
# % measure_ok_rel
# bad       72.86
# medium    24.49
# good       2.65
# Name: proportion, dtype: float64
#
# --------------------------------------------------------------------------------
# /tmp/ipykernel_2399263/2128013161.py:156: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(filtrar_outliers)
# /tmp/ipykernel_2399263/1205157300.py:122: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_all_results = pd.concat([df_all_results, df_resultado], ignore_index=True)
# *****************************************
# Maximo descartado 0.3776098577663251
# *****************************************
# *****************************************
# Maximo descartado 0.4407713214462901
# *****************************************
# {1: 'lubina2', 2: 'ochoa_cinta', 34: 'fake_fish', 37: 'lubina2', 6: 'ochoa_no_cinta', 10: 'ochoa_no_cinta', 27: 'ochoa_no_cinta', 30: 'ochoa_no_cinta', 31: 'ochoa_cinta'}
# peix_measures {'lubina0': 31.5, 'peix1': 19.4, 'caballa': 28.9, 'peix3': 21.6, 'lubina2': 33.5, 'ochoa_no_cinta': 30, 'ochoa_cinta': 33.5, 'fake_fish': -100, 'no_track_E2': 25}
# ------------------------------------------------------------------
#    filtered_length  track_id  gt_measure codi_escenari         day      hour  \
# 0         0.346189         1        33.5            E3  2025_05_08  11_57_58
# 1         0.326272         2        33.5            E3  2025_05_08  11_57_58
# 2         0.212623         6        30.0            E3  2025_05_08  11_57_58
# 3         0.304307        10        30.0            E3  2025_05_08  11_57_58
# 4         0.276993        27        30.0            E3  2025_05_08  11_57_58
# 5         0.311920        30        30.0            E3  2025_05_08  11_57_58
# 6         0.326525        31        33.5            E3  2025_05_08  11_57_58
# 7         0.279771        34      -100.0            E3  2025_05_08  11_57_58
# 8         0.349109        37        33.5            E3  2025_05_08  11_57_58
#
#    Abs_ERROR [cm]  relative_error [%] measure_ok_abs
# 0        1.118862            3.339887         medium
# 1        0.872780            2.605314           good
# 2        8.737677           29.125589            bad
# 3        0.430735            1.435785           good
# 4        2.300663            7.668878            bad
# 5        1.192032            3.973439         medium
# 6        0.847489            2.529816           good
# 7      127.977129         -127.977129            bad
# 8        1.410937            4.211752         medium
# ------------------------------------------------------------------
# Index(['filtered_length', 'track_id', 'gt_measure', 'codi_escenari', 'day',
#        'hour', 'Abs_ERROR [cm]', 'relative_error [%]', 'measure_ok_abs',
#        'count', 'max_length', 'mean_length', 'elevation_deg_mean', 'std_dev'],
#       dtype='object')
#   codi_escenari         day      hour  track_id  count  filtered_length  \
# 0            E3  2025_05_08  11_57_58         1    115         0.346189
# 1            E3  2025_05_08  11_57_58         2    110         0.326272
# 2            E3  2025_05_08  11_57_58         6      4         0.212623
# 3            E3  2025_05_08  11_57_58        10     77         0.304307
# 4            E3  2025_05_08  11_57_58        27     20         0.276993
#
#    gt_measure  Abs_ERROR [cm]  relative_error [%] measure_ok_abs  max_length  \
# 0        33.5        1.118862            3.339887         medium    0.377610
# 1        33.5        0.872780            2.605314           good    0.440771
# 2        30.0        8.737677           29.125589            bad    0.212623
# 3        30.0        0.430735            1.435785           good    0.304307
# 4        30.0        2.300663            7.668878            bad    0.276993
#
#    mean_length   std_dev  elevation_deg_mean
# 0     0.300030  0.037174            2.609643
# 1     0.301441  0.032317            0.865417
# 2     0.200806  0.014887           12.915070
# 3     0.251926  0.031048            5.307926
# 4     0.245419  0.043648            3.755053
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#        filtered_length  gt_measure  Abs_ERROR [cm]  relative_error [%]  \
# count        29.000000   29.000000       29.000000           29.000000
# mean          0.255377   21.134483        5.521650           -0.231470
# std           0.056824   23.945791       23.607587           25.196662
# min           0.184522 -100.000000        0.070670         -127.977129
# 25%           0.196993   19.400000        0.333387            1.409213
# 50%           0.276993   28.900000        0.847489            2.529816
# 75%           0.299642   30.000000        1.192032            4.378673
# max           0.349109   33.500000      127.977129           29.125589
#
#        max_length  mean_length    std_dev  elevation_deg_mean
# count   29.000000    29.000000  28.000000           29.000000
# mean     0.264574     0.237249   0.016640           12.564904
# std      0.069783     0.049439   0.017829           11.892266
# min      0.184522     0.176454   0.001709           -3.467909
# 25%      0.196993     0.188381   0.005760            3.755053
# 50%      0.279771     0.227567   0.009684            8.953825
# 75%      0.304307     0.284512   0.022301           20.694956
# max      0.440771     0.308019   0.086800           42.801707
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# /tmp/ipykernel_2399263/2128013161.py:156: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(filtrar_outliers)
# <style type="text/css">
# #T_498bc_row0_col0, #T_498bc_row0_col1, #T_498bc_row0_col2, #T_498bc_row0_col3, #T_498bc_row0_col4, #T_498bc_row0_col5, #T_498bc_row0_col6, #T_498bc_row0_col7, #T_498bc_row0_col8, #T_498bc_row0_col9, #T_498bc_row0_col10, #T_498bc_row0_col11, #T_498bc_row0_col12, #T_498bc_row0_col13, #T_498bc_row0_col14, #T_498bc_row0_col15, #T_498bc_row1_col0, #T_498bc_row1_col1, #T_498bc_row1_col2, #T_498bc_row1_col3, #T_498bc_row1_col4, #T_498bc_row1_col5, #T_498bc_row1_col6, #T_498bc_row1_col7, #T_498bc_row1_col8, #T_498bc_row1_col9, #T_498bc_row1_col10, #T_498bc_row1_col11, #T_498bc_row1_col12, #T_498bc_row1_col13, #T_498bc_row1_col14, #T_498bc_row1_col15, #T_498bc_row2_col0, #T_498bc_row2_col1, #T_498bc_row2_col2, #T_498bc_row2_col3, #T_498bc_row2_col4, #T_498bc_row2_col5, #T_498bc_row2_col6, #T_498bc_row2_col7, #T_498bc_row2_col8, #T_498bc_row2_col9, #T_498bc_row2_col10, #T_498bc_row2_col11, #T_498bc_row2_col12, #T_498bc_row2_col13, #T_498bc_row2_col14, #T_498bc_row2_col15, #T_498bc_row3_col0, #T_498bc_row3_col1, #T_498bc_row3_col2, #T_498bc_row3_col3, #T_498bc_row3_col4, #T_498bc_row3_col5, #T_498bc_row3_col6, #T_498bc_row3_col7, #T_498bc_row3_col8, #T_498bc_row3_col9, #T_498bc_row3_col10, #T_498bc_row3_col11, #T_498bc_row3_col12, #T_498bc_row3_col13, #T_498bc_row3_col14, #T_498bc_row3_col15, #T_498bc_row4_col0, #T_498bc_row4_col1, #T_498bc_row4_col2, #T_498bc_row4_col3, #T_498bc_row4_col4, #T_498bc_row4_col5, #T_498bc_row4_col6, #T_498bc_row4_col7, #T_498bc_row4_col8, #T_498bc_row4_col9, #T_498bc_row4_col10, #T_498bc_row4_col11, #T_498bc_row4_col12, #T_498bc_row4_col13, #T_498bc_row4_col14, #T_498bc_row4_col15, #T_498bc_row6_col0, #T_498bc_row6_col1, #T_498bc_row6_col2, #T_498bc_row6_col3, #T_498bc_row6_col4, #T_498bc_row6_col5, #T_498bc_row6_col6, #T_498bc_row6_col7, #T_498bc_row6_col8, #T_498bc_row6_col9, #T_498bc_row6_col10, #T_498bc_row6_col11, #T_498bc_row6_col12, #T_498bc_row6_col13, #T_498bc_row6_col14, #T_498bc_row6_col15, #T_498bc_row8_col0, #T_498bc_row8_col1, #T_498bc_row8_col2, #T_498bc_row8_col3, #T_498bc_row8_col4, #T_498bc_row8_col5, #T_498bc_row8_col6, #T_498bc_row8_col7, #T_498bc_row8_col8, #T_498bc_row8_col9, #T_498bc_row8_col10, #T_498bc_row8_col11, #T_498bc_row8_col12, #T_498bc_row8_col13, #T_498bc_row8_col14, #T_498bc_row8_col15, #T_498bc_row9_col0, #T_498bc_row9_col1, #T_498bc_row9_col2, #T_498bc_row9_col3, #T_498bc_row9_col4, #T_498bc_row9_col5, #T_498bc_row9_col6, #T_498bc_row9_col7, #T_498bc_row9_col8, #T_498bc_row9_col9, #T_498bc_row9_col10, #T_498bc_row9_col11, #T_498bc_row9_col12, #T_498bc_row9_col13, #T_498bc_row9_col14, #T_498bc_row9_col15, #T_498bc_row10_col0, #T_498bc_row10_col1, #T_498bc_row10_col2, #T_498bc_row10_col3, #T_498bc_row10_col4, #T_498bc_row10_col5, #T_498bc_row10_col6, #T_498bc_row10_col7, #T_498bc_row10_col8, #T_498bc_row10_col9, #T_498bc_row10_col10, #T_498bc_row10_col11, #T_498bc_row10_col12, #T_498bc_row10_col13, #T_498bc_row10_col14, #T_498bc_row10_col15, #T_498bc_row11_col0, #T_498bc_row11_col1, #T_498bc_row11_col2, #T_498bc_row11_col3, #T_498bc_row11_col4, #T_498bc_row11_col5, #T_498bc_row11_col6, #T_498bc_row11_col7, #T_498bc_row11_col8, #T_498bc_row11_col9, #T_498bc_row11_col10, #T_498bc_row11_col11, #T_498bc_row11_col12, #T_498bc_row11_col13, #T_498bc_row11_col14, #T_498bc_row11_col15, #T_498bc_row12_col0, #T_498bc_row12_col1, #T_498bc_row12_col2, #T_498bc_row12_col3, #T_498bc_row12_col4, #T_498bc_row12_col5, #T_498bc_row12_col6, #T_498bc_row12_col7, #T_498bc_row12_col8, #T_498bc_row12_col9, #T_498bc_row12_col10, #T_498bc_row12_col11, #T_498bc_row12_col12, #T_498bc_row12_col13, #T_498bc_row12_col14, #T_498bc_row12_col15, #T_498bc_row13_col0, #T_498bc_row13_col1, #T_498bc_row13_col2, #T_498bc_row13_col3, #T_498bc_row13_col4, #T_498bc_row13_col5, #T_498bc_row13_col6, #T_498bc_row13_col7, #T_498bc_row13_col8, #T_498bc_row13_col9, #T_498bc_row13_col10, #T_498bc_row13_col11, #T_498bc_row13_col12, #T_498bc_row13_col13, #T_498bc_row13_col14, #T_498bc_row13_col15, #T_498bc_row14_col0, #T_ ...
#   background-color: #d9f2d9;
# }
# #T_498bc_row5_col0, #T_498bc_row5_col1, #T_498bc_row5_col2, #T_498bc_row5_col3, #T_498bc_row5_col4, #T_498bc_row5_col5, #T_498bc_row5_col6, #T_498bc_row5_col7, #T_498bc_row5_col8, #T_498bc_row5_col9, #T_498bc_row5_col10, #T_498bc_row5_col11, #T_498bc_row5_col12, #T_498bc_row5_col13, #T_498bc_row5_col14, #T_498bc_row5_col15, #T_498bc_row19_col0, #T_498bc_row19_col1, #T_498bc_row19_col2, #T_498bc_row19_col3, #T_498bc_row19_col4, #T_498bc_row19_col5, #T_498bc_row19_col6, #T_498bc_row19_col7, #T_498bc_row19_col8, #T_498bc_row19_col9, #T_498bc_row19_col10, #T_498bc_row19_col11, #T_498bc_row19_col12, #T_498bc_row19_col13, #T_498bc_row19_col14, #T_498bc_row19_col15, #T_498bc_row20_col0, #T_498bc_row20_col1, #T_498bc_row20_col2, #T_498bc_row20_col3, #T_498bc_row20_col4, #T_498bc_row20_col5, #T_498bc_row20_col6, #T_498bc_row20_col7, #T_498bc_row20_col8, #T_498bc_row20_col9, #T_498bc_row20_col10, #T_498bc_row20_col11, #T_498bc_row20_col12, #T_498bc_row20_col13, #T_498bc_row20_col14, #T_498bc_row20_col15, #T_498bc_row25_col0, #T_498bc_row25_col1, #T_498bc_row25_col2, #T_498bc_row25_col3, #T_498bc_row25_col4, #T_498bc_row25_col5, #T_498bc_row25_col6, #T_498bc_row25_col7, #T_498bc_row25_col8, #T_498bc_row25_col9, #T_498bc_row25_col10, #T_498bc_row25_col11, #T_498bc_row25_col12, #T_498bc_row25_col13, #T_498bc_row25_col14, #T_498bc_row25_col15, #T_498bc_row28_col0, #T_498bc_row28_col1, #T_498bc_row28_col2, #T_498bc_row28_col3, #T_498bc_row28_col4, #T_498bc_row28_col5, #T_498bc_row28_col6, #T_498bc_row28_col7, #T_498bc_row28_col8, #T_498bc_row28_col9, #T_498bc_row

# %%
df_resultado_colored
# Out:
# <style type="text/css">
# #T_ff087_row0_col0, #T_ff087_row0_col1, #T_ff087_row0_col2, #T_ff087_row0_col3, #T_ff087_row0_col4, #T_ff087_row0_col5, #T_ff087_row0_col6, #T_ff087_row0_col7, #T_ff087_row0_col8, #T_ff087_row0_col9, #T_ff087_row0_col10, #T_ff087_row0_col11, #T_ff087_row0_col12, #T_ff087_row0_col13, #T_ff087_row0_col14, #T_ff087_row5_col0, #T_ff087_row5_col1, #T_ff087_row5_col2, #T_ff087_row5_col3, #T_ff087_row5_col4, #T_ff087_row5_col5, #T_ff087_row5_col6, #T_ff087_row5_col7, #T_ff087_row5_col8, #T_ff087_row5_col9, #T_ff087_row5_col10, #T_ff087_row5_col11, #T_ff087_row5_col12, #T_ff087_row5_col13, #T_ff087_row5_col14, #T_ff087_row8_col0, #T_ff087_row8_col1, #T_ff087_row8_col2, #T_ff087_row8_col3, #T_ff087_row8_col4, #T_ff087_row8_col5, #T_ff087_row8_col6, #T_ff087_row8_col7, #T_ff087_row8_col8, #T_ff087_row8_col9, #T_ff087_row8_col10, #T_ff087_row8_col11, #T_ff087_row8_col12, #T_ff087_row8_col13, #T_ff087_row8_col14 {
#   background-color: #fff3cd;
# }
# #T_ff087_row1_col0, #T_ff087_row1_col1, #T_ff087_row1_col2, #T_ff087_row1_col3, #T_ff087_row1_col4, #T_ff087_row1_col5, #T_ff087_row1_col6, #T_ff087_row1_col7, #T_ff087_row1_col8, #T_ff087_row1_col9, #T_ff087_row1_col10, #T_ff087_row1_col11, #T_ff087_row1_col12, #T_ff087_row1_col13, #T_ff087_row1_col14, #T_ff087_row3_col0, #T_ff087_row3_col1, #T_ff087_row3_col2, #T_ff087_row3_col3, #T_ff087_row3_col4, #T_ff087_row3_col5, #T_ff087_row3_col6, #T_ff087_row3_col7, #T_ff087_row3_col8, #T_ff087_row3_col9, #T_ff087_row3_col10, #T_ff087_row3_col11, #T_ff087_row3_col12, #T_ff087_row3_col13, #T_ff087_row3_col14, #T_ff087_row6_col0, #T_ff087_row6_col1, #T_ff087_row6_col2, #T_ff087_row6_col3, #T_ff087_row6_col4, #T_ff087_row6_col5, #T_ff087_row6_col6, #T_ff087_row6_col7, #T_ff087_row6_col8, #T_ff087_row6_col9, #T_ff087_row6_col10, #T_ff087_row6_col11, #T_ff087_row6_col12, #T_ff087_row6_col13, #T_ff087_row6_col14 {
#   background-color: #d9f2d9;
# }
# #T_ff087_row2_col0, #T_ff087_row2_col1, #T_ff087_row2_col2, #T_ff087_row2_col3, #T_ff087_row2_col4, #T_ff087_row2_col5, #T_ff087_row2_col6, #T_ff087_row2_col7, #T_ff087_row2_col8, #T_ff087_row2_col9, #T_ff087_row2_col10, #T_ff087_row2_col11, #T_ff087_row2_col12, #T_ff087_row2_col13, #T_ff087_row2_col14, #T_ff087_row4_col0, #T_ff087_row4_col1, #T_ff087_row4_col2, #T_ff087_row4_col3, #T_ff087_row4_col4, #T_ff087_row4_col5, #T_ff087_row4_col6, #T_ff087_row4_col7, #T_ff087_row4_col8, #T_ff087_row4_col9, #T_ff087_row4_col10, #T_ff087_row4_col11, #T_ff087_row4_col12, #T_ff087_row4_col13, #T_ff087_row4_col14, #T_ff087_row7_col0, #T_ff087_row7_col1, #T_ff087_row7_col2, #T_ff087_row7_col3, #T_ff087_row7_col4, #T_ff087_row7_col5, #T_ff087_row7_col6, #T_ff087_row7_col7, #T_ff087_row7_col8, #T_ff087_row7_col9, #T_ff087_row7_col10, #T_ff087_row7_col11, #T_ff087_row7_col12, #T_ff087_row7_col13, #T_ff087_row7_col14 {
#   background-color: #f8d7da;
# }
# </style>
# <table id="T_ff087">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff087_level0_col0" class="col_heading level0 col0" >codi_escenari</th>
#       <th id="T_ff087_level0_col1" class="col_heading level0 col1" >day</th>
#       <th id="T_ff087_level0_col2" class="col_heading level0 col2" >hour</th>
#       <th id="T_ff087_level0_col3" class="col_heading level0 col3" >track_id</th>
#       <th id="T_ff087_level0_col4" class="col_heading level0 col4" >count</th>
#       <th id="T_ff087_level0_col5" class="col_heading level0 col5" >filtered_length</th>
#       <th id="T_ff087_level0_col6" class="col_heading level0 col6" >gt_measure</th>
#       <th id="T_ff087_level0_col7" class="col_heading level0 col7" >Abs_ERROR [cm]</th>
#       <th id="T_ff087_level0_col8" class="col_heading level0 col8" >relative_error [%]</th>
#       <th id="T_ff087_level0_col9" class="col_heading level0 col9" >measure_ok_abs</th>
#       <th id="T_ff087_level0_col10" class="col_heading level0 col10" >max_length</th>
#       <th id="T_ff087_level0_col11" class="col_heading level0 col11" >mean_length</th>
#       <th id="T_ff087_level0_col12" class="col_heading level0 col12" >std_dev</th>
#       <th id="T_ff087_level0_col13" class="col_heading level0 col13" >elevation_deg_mean</th>
#       <th id="T_ff087_level0_col14" class="col_heading level0 col14" >Comentaris</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff087_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff087_row0_col0" class="data row0 col0" >E3</td>
#       <td id="T_ff087_row0_col1" class="data row0 col1" >2025_05_08</td>
#       <td id="T_ff087_row0_col2" class="data row0 col2" >11_57_58</td>
#       <td id="T_ff087_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_ff087_row0_col4" class="data row0 col4" >115</td>
#       <td id="T_ff087_row0_col5" class="data row0 col5" >0.346189</td>
#       <td id="T_ff087_row0_col6" class="data row0 col6" >33.500000</td>
#       <td id="T_ff087_row0_col7" class="data row0 col7" >1.118862</td>
#       <td id="T_ff087_row0_col8" class="data row0 col8" >3.339887</td>
#       <td id="T_ff087_row0_col9" class="data row0 col9" >medium</td>
#       <td id="T_ff087_row0_col10" class="data row0 col10" >0.377610</td>
#       <td id="T_ff087_row0_col11" class="data row0 col11" >0.300030</td>
#       <td id="T_ff087_row0_col12" class="data row0 col12" >0.037174</td>
#       <td id="T_ff087_row0_col13" class="data row0 col13" >2.609643</td>
#       <td id="T_ff087_row0_col14" class="data row0 col14" ></td>
#     </tr>
#     <tr>
#       <th id="T_ff087_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ff087_row1_col0" class="data row1 col0" >E3</td>
#       <td id="T_ff087_row1_col1" class="data row1 col1" >2025_05_08</td>
#       <td id="T_ff087_row1_col2" class="data row1 col2" >11_57_58</td>
#       <td id="T_ff087_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_ff087_row1_col4" class="data row1 col4" >110</td>
#       <td id="T_ff087_row1_col5" class="data row1 col5" >0.326272</td>
#       <td id="T_ff087_row1_col6" class="data row1 col6" >33.500000</td>
#       <td id="T_ff087_row1_col7" class="data row1 col7" >0.872780</td>
#       <td id="T_ff087_row1_col8" class="data row1 col8" >2.605314</td>
#       <td id="T_ff087_row1_col9" class="data row1 col9" >good</td>
#       <td id="T_ff087_row1_col10" class="data row1 col10" >0.440771</td>
#       <td id="T_ff087_row1_col11" class="data row1 col11" >0.301441</td>
#       <td id="T_ff087_row1_col12" class="data row1 col12" >0.032317</td>
#       <td id="T_ff087_row1_col13" class="data row1 col13" >0.865417</td>
#       <td id="T_ff087_row1_col14" class="data row1 col14" ></td>
#     </tr>
#     <tr>
#       <th id="T_ff087_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ff087_row2_col0" class="data row2 col0" >E3</td>
#       <td id="T_ff087_row2_col1" class="data row2 col1" >2025_05_08</td>
#       <td id="T_ff087_row2_col2" class="data row2 col2" >11_57_58</td>
#       <td id="T_ff087_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_ff087_row2_col4" class="data row2 col4" >4</td>
#       <td id="T_ff087_row2_col5" class="data row2 col5" >0.212623</td>
#       <td id="T_ff087_row2_col6" class="data row2 col6" >30.000000</td>
#       <td id="T_ff087_row2_col7" class="data row2 col7" >8.737677</td>
#       <td id="T_ff087_row2_col8" class="data row2 col8" >29.125589</td>
#       <td id="T_ff087_row2_col9" class="data row2 col9" >bad</td>
#       <td id="T_ff087_row2_col10" class="data row2 col10" >0.212623</td>
#       <td id="T_ff087_row2_col11" class="data row2 col11" >0.200806</td>
#       <td id="T_ff087_row2_col12" class="data row2 col12" >0.014887</td>
#       <td id="T_ff087_row2_col13" class="data row2 col13" >12.915070</td>
#       <td id="T_ff087_row2_col14" class="data row2 col14" ></td>
#     </tr>
#     <tr>
#       <th id="T_ff087_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ff087_row3_col0" class="data row3 col0" >E3</td>
#       <td id="T_ff087_row3_col1" class="data row3 col1" >2025_05_08</td>
#       <td id="T_ff087_row3_col2" class="data row3 col2" >11_57_58</td>
#       <td i

# %%
# Afegir comentari si toca 
df_resultado.loc[df_resultado["track_id"] == 34, "Comentaris"] = ("No és un peix real...")
# df_resultado["Comentaris"] = ("Aquest dataset no és el millor perquè es mesclen ids...")

# %%
# Guardar con append o crear nuevo
df_resultado.to_csv(experiment_code+".csv")
df_resultado_colored.to_excel(experiment_code+'.xlsx', engine='openpyxl', index=False)

# Append df del escenario y guardar:
df_all_results = pd.concat([df_escenari_results, df_resultado], ignore_index=True)

csv_path = codi_escenari + ".csv"
# Comprobar si el archivo ya existe
file_exists = os.path.exists(csv_path)
# Guardar con append o crear nuevo
df_all_results.to_csv(
    csv_path,
    mode='a' if file_exists else 'w',
    header=not file_exists,  # Solo escribir encabezado si el archivo no existe
    index=False
)

# Apply styling and save
df_all_results_colored = df_all_results.style.apply(lambda row: highlight_rows(row, quality_column='measure_ok_abs'), axis=1)
df_all_results_colored.to_excel(experiment_code+'.xlsx', engine='openpyxl', index=False)

df_all_results_colored.to_excel(codi_escenari+'.xlsx', engine='openpyxl', index=False)
# Out:
# /tmp/ipykernel_2399263/2681256285.py:6: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_all_results = pd.concat([df_escenari_results, df_resultado], ignore_index=True)

# %%
df_to_excel = pd.read_csv("E2.csv")
df_to_excel

df_to_excel = df_to_excel.style.apply(lambda row: highlight_rows(row, quality_column='measure_ok_abs'), axis=1)
df_to_excel.to_excel('E2.xlsx', engine='openpyxl', index=False)

# %%
# df_to_excel

# %%
df_all_results_colored.to_excel(codi_escenari+'.xlsx', engine='openpyxl', index=False)

# %%
# df_all_results_colored

# %%
visualizar_outliers(df, 37, porcentaje_umbral=0.05)
# Out:
# num de medidas =  25
# /tmp/ipykernel_2399263/2128013161.py:131: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df_escenari_results

# %%
# INICIALITZACIONS -----------------------------------------------------------
Escenari="Escenari_3/"
base_path="2025_05_08/11_57_58"

column_order = [
    "codi_escenari",
    "day",
    "hour",        
    "track_id",
    "count",
    "filtered_length",
    "gt_measure",
    "Abs_ERROR [cm]",
    "relative_error [%]",
    "measure_ok_abs",
    "max_length",
    "mean_length",
    "std_dev",
    "elevation_deg_mean",
    "comentaris"
]

df_all_results = pd.DataFrame(columns=column_order)


day = base_path.split("/")[0]
hour = base_path.split("/")[-1]
codi_escenari="E"+Escenari.split("_")[-1][0]

temp_code = ("-").join(base_path.split("/"))
experiment_code = codi_escenari+"_"+temp_code


out_escenari_agg_csv=codi_escenari+"_results_resume.csv"
out_csv_name =experiment_code+"_results_agg.csv"

df = pd.read_csv(Escenari+base_path+"/pointclouds/results/all_complete_ok_fish.csv").iloc[:,1:]
df_resume = pd.read_csv(Escenari+base_path+"/pointclouds/results/resume.csv")

df['codi_escenari'] = codi_escenari
df['day'] = day
df['hour'] = hour

# Paso 3: Reordenar columnas (poner las nuevas al principio)
cols = ['codi_escenari', 'day', 'hour'] + [col for col in df.columns if col not in ['codi_escenari', 'day', 'hour']]
df = df[cols]


peix_measures={"lubina0":31.5,"peix1":19.4,"caballa":28.9,"peix3":21.6,"lubina2":33.5,"ochoa_no_cinta":30,"ochoa_cinta":33.5,"fake_fish":-100,"no_track_E2":25}

bagfile_gts = { 
                "2024_11_18/13_52_03":{1:"caballa", 4:"caballa", 11:"peix1", 19:"peix1", 20:"peix1", 22:"caballa", 26:"peix1",\
                                       27:"caballa", 28:"caballa", 33:"peix1", 39:"caballa", 41:"peix1", \
                                       47:"peix1", 49:"peix3", 50:"peix1", 52:"caballa", 54:"peix1", 55:"peix3", 56:"peix1", 58:"peix1"},

                "2025_05_08/11_57_58":{1:"lubina2", 2:"ochoa_cinta", 34:"fake_fish", 37:"lubina2", 6:"ochoa_no_cinta", 10:"ochoa_no_cinta", 27:"ochoa_no_cinta",\
                                       30:"ochoa_no_cinta", 31:"ochoa_cinta"},
                # 11_48_14 -> Aquest es un poc trambòlico xq el tracker es confon quan es creuen peixos.
                "2025_05_08/11_48_14":{32:"ochoa_cinta", 1:"lubina2", 2:"ochoa_no_cinta", 3:"ochoa_cinta", 6:"ochoa_cinta", 8:"ochoa_cinta", 16:"ochoa_cinta", \
                                            19:"lubina2", 21:"ochoa_cinta", 22:"ochoa_no_cinta", 23:"lubina2", 28:"lubina2", 29:"ochoa_cinta", 30:"ochoa_cinta"},
                # Escenari_2
               "2025_05_08/11_30_34": {1:"ochoa_no_cinta", 4:"lubina2", 9:"ochoa_no_cinta", 18:"lubina2", 23:"fake_fish"},
               "2025_05_08/11_36_35":{1:"ochoa_no_cinta", 2:"lubina2", 5:"ochoa_no_cinta", 6:"lubina2", 12:"ochoa_no_cinta", 16:"ochoa_no_cinta", 18:"ochoa_no_cinta", 20:"ochoa_no_cinta", 24:"lubina2"},
               "2025_05_08/11_44_47":{1:"lubina2", 4:"ochoa_no_cinta", 14:"ochoa_no_cinta"},
               "2024_11_28/13_19_06":{1:"caballa", 2:"peix3", 8:"peix3", 9:"caballa", 10:"peix3", 11:"caballa", 15:"peix3", 19:"fake_fish"},
               "2024_11_28/13_47_08":{1:"caballa", 3:"peix3", 6:"peix3", 10:"caballa", 11:"peix3", -1:"no_track_E2"},
               #Escenari 1:
               "2025_05_08/11_17_18": {1: "lubina2", 6: "fake_fish", 9: "fake_fish"},
               "2025_05_08/11_41_03":{1:"lubina2"},
               "2024_11_12/11_00_27":{-1:"lubina0", 1:"lubina0", 2:"lubina0", 3:"lubina0", 6:"lubina0", 8:"lubina0", 11:"lubina0"},
               "2024_11_28/13_07_38":{1:"caballa" , -1:"caballa" , 6:"caballa"},
               "2024_11_28/13_09_20":{-1: "caballa" , 4: "caballa" , 5: "caballa"}}


# bagfile_gts = {"2025_05_08/11_30_34": {1:30, 4:33.5, 9:30, 18:33.5, 23:-100},
#                "2025_05_08/11_36_35":{1, 2, 5, 6, 12, 16, 18, 20, 24},
#                #Escenari 1:
#                "2025_05_08/11_17_18": {1: 33.5, 6: -100, 9: -100},
#                "2025_05_08/11_41_03":{1:33.5},
#                "2024_11_12/11_00_27":{-1:31.5, 1:31.5, 2:31.5, 3:31.5, 6:31.5, 8:31.5, 11:31.5},
#                "2024_11_28/13_07_38":{1:28.9 , -1:28.9 , 6:28.9},
#                "2024_11_28/13_09_20":{-1: 28.9 , 4: 28.9 , 5: 28.9}}
              
#----------------------------------------------------------------------------------

print("Tracks ids present in this video:")
print(set(df["track_id"]))

# Ja he generat el gt
if base_path in bagfile_gts.keys():

    gt_measure = bagfile_gts[base_path]
    print(gt_measure)
        
    
    df["gt_measure"] = df["track_id"].map(gt_measure).map(peix_measures)
    df_resume["gt_measure"] = df_resume["track_id"].map(gt_measure).map(peix_measures)
    # df_resume["gt_measure"] = df["track_id"].map(gt_measure[peix_measures])
    df.sort_values(by=['frame_id'])

    df["Abs_ERROR [cm]"]=abs(df["filtered_length"]-(df["gt_measure"]/100))*100
    df['Rel_ERROR[%]'] = df['Abs_ERROR [cm]'] / (df['gt_measure']/100)

    print(df.head())
    print("----------------------------------- \n \n")

    df = clasificar_medidas(df, agg=False)
    # print(df.head())
    
    df = generate_analysis_plots(df)

    # Descomentar para guardar todas las medidas sin agregar clasificadas:
    # styled_df = df.style.apply(lambda row: highlight_rows(row, quality_column="measure_ok_abs"), axis=1)
    # styled_df.to_excel(out_csv_name+'.xlsx', engine='openpyxl', index=False)

    df_resultado=descartar_outliers_por_track(df, porcentaje_umbral=0.1)
    print(df_resultado.head())
    

    df_resultado["Comentaris"] = ("")
    # df_resultado.loc[df_resultado["track_id"] != 1, "Comentaris"] = ("")

    df_resultado_colored = df_resultado.style.apply(lambda row: highlight_rows(row, quality_column='measure_ok_abs'), axis=1)
# Out:
# Tracks ids present in this video:
# {1, 2, 34, 37, 6, 10, 27, 30, 31}
# {1: 'lubina2', 2: 'ochoa_cinta', 34: 'fake_fish', 37: 'lubina2', 6: 'ochoa_no_cinta', 10: 'ochoa_no_cinta', 27: 'ochoa_no_cinta', 30: 'ochoa_no_cinta', 31: 'ochoa_cinta'}
#   codi_escenari         day      hour frame_id  class_name  Object_id  \
# 0            E3  2025_05_08  11_57_58   frame7           9        127
# 1            E3  2025_05_08  11_57_58   frame7           9        255
# 2            E3  2025_05_08  11_57_58  frame14           9        127
# 3            E3  2025_05_08  11_57_58  frame14           9        255
# 4            E3  2025_05_08  11_57_58  frame15           9        127
#
#    track_id  is_3D_complete  in_image_borders  \
# 0         1               1             False
# 1         2               1             False
# 2         1               1             False
# 3         2               1             False
# 4         1               1             False
#
#                           fish_direction  elevation_deg  azimuth_deg  \
# 0  [-0.32007196  0.31780999  0.89249692]      31.452433   -47.110947
# 1     [0.77274568 0.38724661 0.50289579]       0.075094    25.443910
# 2  [-0.47600052  0.4161768   0.77473891]      29.463233   -45.742346
# 3     [0.70725775 0.4107572  0.57538248]       0.909667    24.860697
# 4  [-0.73092998  0.68182111 -0.02934866]      27.673585   -43.553596
#
#    raw_length  filtered_length  fish_dist_from_camera  gt_measure  \
# 0    1.213105         0.318835               1.696389        33.5
# 1    0.501436         0.316543               0.853063        33.5
# 2    0.786381         0.321604               1.756200        33.5
# 3    2.251732         0.319894               0.852804        33.5
# 4    0.593185         0.320733               1.758143        33.5
#
#    Abs_ERROR [cm]  Rel_ERROR[%]
# 0        1.616486      4.825331
# 1        1.845703      5.509561
# 2        1.339583      3.998755
# 3        1.510624      4.509325
# 4        1.426748      4.258948
# -----------------------------------
#
#
#   codi_escenari         day      hour frame_id  class_name  Object_id  \
# 0            E3  2025_05_08  11_57_58   frame7           9        127
# 1            E3  2025_05_08  11_57_58   frame7           9        255
# 2            E3  2025_05_08  11_57_58  frame14           9        127
# 3            E3  2025_05_08  11_57_58  frame14           9        255
# 4            E3  2025_05_08  11_57_58  frame15           9        127
#
#    track_id  is_3D_complete  in_image_borders  \
# 0         1               1             False
# 1         2               1             False
# 2         1               1             False
# 3         2               1             False
# 4         1               1             False
#
#                           fish_direction  elevation_deg  azimuth_deg  \
# 0  [-0.32007196  0.31780999  0.89249692]      31.452433   -47.110947
# 1     [0.77274568 0.38724661 0.50289579]       0.075094    25.443910
# 2  [-0.47600052  0.4161768   0.77473891]      29.463233   -45.742346
# 3     [0.70725775 0.4107572  0.57538248]       0.909667    24.860697
# 4  [-0.73092998  0.68182111 -0.02934866]      27.673585   -43.553596
#
#    raw_length  filtered_length  fish_dist_from_camera  gt_measure  \
# 0    1.213105         0.318835               1.696389        33.5
# 1    0.501436         0.316543               0.853063        33.5
# 2    0.786381         0.321604               1.756200        33.5
# 3    2.251732         0.319894               0.852804        33.5
# 4    0.593185         0.320733               1.758143        33.5
#
#    Abs_ERROR [cm]  Rel_ERROR[%] measure_ok_abs measure_ok_rel
# 0        1.616486      4.825331         medium         medium
# 1        1.845703      5.509561         medium            bad
# 2        1.339583      3.998755         medium         medium
# 3        1.510624      4.509325         medium         medium
# 4        1.426748      4.258948         medium         medium
#
#        class_name   Object_id    track_id  is_3D_complete  elevation_deg  \
# count       490.0  490.000000  490.000000           490.0     490.000000
# mean          9.0  172.255102   13.985714             1.0       4.826345
# std           0.0   70.381797   13.712569             0.0      16.583586
# min           9.0   63.000000    1.000000             1.0     -34.728537
# 25%           9.0   85.000000    2.000000             1.0      -3.364878
# 50%           9.0  170.000000   10.000000             1.0       3.159640
# 75%           9.0  255.000000   30.000000             1.0      12.496511
# max           9.0  255.000000   37.000000             1.0      75.394156
#
#        azimuth_deg  raw_length  filtered_length  fish_dist_from_camera  \
# count   490.000000  490.000000       490.000000             490.000000
# mean     17.660475    0.466127         0.287364               1.561417
# std      94.215910    0.468616         0.039093               0.464477
# min    -178.909713    0.084256         0.073921               0.852804
# 25%     -31.814328    0.282482         0.272337               1.203806
# 50%      22.331840    0.306687         0.296836               1.420809
# 75%      51.637237    0.322744         0.314274               2.050325
# max     178.463323    2.685642         0.440771               2.482528
#
#        gt_measure  Abs_ERROR [cm]  Rel_ERROR[%]
# count  490.000000      490.000000    490.000000
# mean    30.952041        4.815909      9.860164
# std     13.412111       12.409320     16.709483
# min   -100.000000        0.017002   -127.977129
# 25%     30.000000        1.598358      4.733074
# 50%     33.500000        2.562778      7.758399
# 75%     33.500000        4.828491     14.649944
# max     33.500000      127.977129     71.914645
#
# measure_ok_abs:
# measure_ok_abs
# bad       318
# medium    118
# good       54
# Name: count, dtype: int64
# % measure_ok_abs
# bad       64.90
# medium    24.08
# good      11.02
# Name: proportion, dtype: float64
#
# --------------------------------------------------------------------------------
# measure_ok_rel:
# measure_ok_rel
# bad       357
# medium    120
# good       13
# Name: count, dtype: int64
# % measure_ok_rel
# bad       72.86
# medium    24.49
# good       2.65
# Name: proportion, dtype: float64
#
# --------------------------------------------------------------------------------
# *****************************************
# Maximo descartado 0.3776098577663251
# *****************************************
# *****************************************
# Maximo descartado 0.4407713214462901
# *****************************************
# {1: 'lubina2', 2: 'ochoa_cinta', 34: 'fake_fish', 37: 'lubina2', 6: 'ochoa_no_cinta', 10: 'ochoa_no_cinta', 27: 'ochoa_no_cinta', 30: 'ochoa_no_cinta', 31: 'ochoa_cinta'}
# peix_measures {'lubina0': 31.5, 'peix1': 19.4, 'caballa': 28.9, 'peix3': 21.6, 'lubina2': 33.5, 'ochoa_no_cinta': 30, 'ochoa_cinta': 33.5, 'fake_fish': -100, 'no_track_E2': 25}
# ------------------------------------------------------------------
#    filtered_length  track_id  gt_measure codi_escenari         day      hour  \
# 0         0.346189         1        33.5            E3  2025_05_08  11_57_58
# 1         0.326272         2        33.5            E3  2025_05_08  11_57_58
# 2         0.212623         6        30.0            E3  2025_05_08  11_57_58
# 3         0.304307        10        30.0            E3  2025_05_08  11_57_58
# 4         0.276993        27        30.0            E3  2025_05_08  11_57_58
# 5         0.311920        30        30.0            E3  2025_05_08  11_57_58
# 6         0.326525        31        33.5            E3  2025_05_08  11_57_58
# 7         0.279771        34      -100.0            E3  2025_05_08  11_57_58
# 8         0.349109        37        33.5            E3  2025_05_08  11_57_58
#
#    Abs_ERROR [cm]  relative_error [%] measure_ok_abs
# 0        1.118862            3.339887         medium
# 1        0.872780            2.605314           good
# 2        8.737677           29.125589            bad
# 3        0.430735            1.435785           good
# 4        2.300663            7.668878            bad
# 5        1.192032            3.973439         medium
# 6        0.847489            2.529816           good
# 7      127.977129         -127.977129            bad
# 8        1.410937            4.211752         medium
# ------------------------------------------------------------------
# Index(['filtered_length', 'track_id', 'gt_measure', 'codi_escenari', 'day',
#        'hour', 'Abs_ERROR [cm]', 'relative_error [%]', 'measure_ok_abs',
#        'count', 'max_length', 'mean_length', 'elevation_deg_mean', 'std_dev'],
#       dtype='object')
#   codi_escenari         day      hour  track_id  count  filtered_length  \
# 0            E3  2025_05_08  11_57_58         1    115         0.346189
# 1            E3  2025_05_08  11_57_58         2    110         0.326272
# 2            E3  2025_05_08  11_57_58         6      4         0.212623
# 3            E3  2025_05_08  11_57_58        10     77         0.304307
# 4            E3  2025_05_08  11_57_58        27     20         0.276993
#
#    gt_measure  Abs_ERROR [cm]  relative_error [%] measure_ok_abs  max_length  \
# 0        33.5        1.118862            3.339887         medium    0.377610
# 1        33.5        0.872780            2.605314           good    0.440771
# 2        30.0        8.737677           29.125589            bad    0.212623
# 3        30.0        0.430735            1.435785           good    0.304307
# 4        30.0        2.300663            7.668878            bad    0.276993
#
#    mean_length   std_dev  elevation_deg_mean
# 0     0.300030  0.037174            2.609643
# 1     0.301441  0.032317            0.865417
# 2     0.200806  0.014887           12.915070
# 3     0.251926  0.031048            5.307926
# 4     0.245419  0.043648            3.755053
# /tmp/ipykernel_2399263/2128013161.py:156: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(filtrar_outliers)

# %%
df_resultado_colored
# Out:
# <style type="text/css">
# #T_ff087_row0_col0, #T_ff087_row0_col1, #T_ff087_row0_col2, #T_ff087_row0_col3, #T_ff087_row0_col4, #T_ff087_row0_col5, #T_ff087_row0_col6, #T_ff087_row0_col7, #T_ff087_row0_col8, #T_ff087_row0_col9, #T_ff087_row0_col10, #T_ff087_row0_col11, #T_ff087_row0_col12, #T_ff087_row0_col13, #T_ff087_row0_col14, #T_ff087_row5_col0, #T_ff087_row5_col1, #T_ff087_row5_col2, #T_ff087_row5_col3, #T_ff087_row5_col4, #T_ff087_row5_col5, #T_ff087_row5_col6, #T_ff087_row5_col7, #T_ff087_row5_col8, #T_ff087_row5_col9, #T_ff087_row5_col10, #T_ff087_row5_col11, #T_ff087_row5_col12, #T_ff087_row5_col13, #T_ff087_row5_col14, #T_ff087_row8_col0, #T_ff087_row8_col1, #T_ff087_row8_col2, #T_ff087_row8_col3, #T_ff087_row8_col4, #T_ff087_row8_col5, #T_ff087_row8_col6, #T_ff087_row8_col7, #T_ff087_row8_col8, #T_ff087_row8_col9, #T_ff087_row8_col10, #T_ff087_row8_col11, #T_ff087_row8_col12, #T_ff087_row8_col13, #T_ff087_row8_col14 {
#   background-color: #fff3cd;
# }
# #T_ff087_row1_col0, #T_ff087_row1_col1, #T_ff087_row1_col2, #T_ff087_row1_col3, #T_ff087_row1_col4, #T_ff087_row1_col5, #T_ff087_row1_col6, #T_ff087_row1_col7, #T_ff087_row1_col8, #T_ff087_row1_col9, #T_ff087_row1_col10, #T_ff087_row1_col11, #T_ff087_row1_col12, #T_ff087_row1_col13, #T_ff087_row1_col14, #T_ff087_row3_col0, #T_ff087_row3_col1, #T_ff087_row3_col2, #T_ff087_row3_col3, #T_ff087_row3_col4, #T_ff087_row3_col5, #T_ff087_row3_col6, #T_ff087_row3_col7, #T_ff087_row3_col8, #T_ff087_row3_col9, #T_ff087_row3_col10, #T_ff087_row3_col11, #T_ff087_row3_col12, #T_ff087_row3_col13, #T_ff087_row3_col14, #T_ff087_row6_col0, #T_ff087_row6_col1, #T_ff087_row6_col2, #T_ff087_row6_col3, #T_ff087_row6_col4, #T_ff087_row6_col5, #T_ff087_row6_col6, #T_ff087_row6_col7, #T_ff087_row6_col8, #T_ff087_row6_col9, #T_ff087_row6_col10, #T_ff087_row6_col11, #T_ff087_row6_col12, #T_ff087_row6_col13, #T_ff087_row6_col14 {
#   background-color: #d9f2d9;
# }
# #T_ff087_row2_col0, #T_ff087_row2_col1, #T_ff087_row2_col2, #T_ff087_row2_col3, #T_ff087_row2_col4, #T_ff087_row2_col5, #T_ff087_row2_col6, #T_ff087_row2_col7, #T_ff087_row2_col8, #T_ff087_row2_col9, #T_ff087_row2_col10, #T_ff087_row2_col11, #T_ff087_row2_col12, #T_ff087_row2_col13, #T_ff087_row2_col14, #T_ff087_row4_col0, #T_ff087_row4_col1, #T_ff087_row4_col2, #T_ff087_row4_col3, #T_ff087_row4_col4, #T_ff087_row4_col5, #T_ff087_row4_col6, #T_ff087_row4_col7, #T_ff087_row4_col8, #T_ff087_row4_col9, #T_ff087_row4_col10, #T_ff087_row4_col11, #T_ff087_row4_col12, #T_ff087_row4_col13, #T_ff087_row4_col14, #T_ff087_row7_col0, #T_ff087_row7_col1, #T_ff087_row7_col2, #T_ff087_row7_col3, #T_ff087_row7_col4, #T_ff087_row7_col5, #T_ff087_row7_col6, #T_ff087_row7_col7, #T_ff087_row7_col8, #T_ff087_row7_col9, #T_ff087_row7_col10, #T_ff087_row7_col11, #T_ff087_row7_col12, #T_ff087_row7_col13, #T_ff087_row7_col14 {
#   background-color: #f8d7da;
# }
# </style>
# <table id="T_ff087">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff087_level0_col0" class="col_heading level0 col0" >codi_escenari</th>
#       <th id="T_ff087_level0_col1" class="col_heading level0 col1" >day</th>
#       <th id="T_ff087_level0_col2" class="col_heading level0 col2" >hour</th>
#       <th id="T_ff087_level0_col3" class="col_heading level0 col3" >track_id</th>
#       <th id="T_ff087_level0_col4" class="col_heading level0 col4" >count</th>
#       <th id="T_ff087_level0_col5" class="col_heading level0 col5" >filtered_length</th>
#       <th id="T_ff087_level0_col6" class="col_heading level0 col6" >gt_measure</th>
#       <th id="T_ff087_level0_col7" class="col_heading level0 col7" >Abs_ERROR [cm]</th>
#       <th id="T_ff087_level0_col8" class="col_heading level0 col8" >relative_error [%]</th>
#       <th id="T_ff087_level0_col9" class="col_heading level0 col9" >measure_ok_abs</th>
#       <th id="T_ff087_level0_col10" class="col_heading level0 col10" >max_length</th>
#       <th id="T_ff087_level0_col11" class="col_heading level0 col11" >mean_length</th>
#       <th id="T_ff087_level0_col12" class="col_heading level0 col12" >std_dev</th>
#       <th id="T_ff087_level0_col13" class="col_heading level0 col13" >elevation_deg_mean</th>
#       <th id="T_ff087_level0_col14" class="col_heading level0 col14" >Comentaris</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff087_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff087_row0_col0" class="data row0 col0" >E3</td>
#       <td id="T_ff087_row0_col1" class="data row0 col1" >2025_05_08</td>
#       <td id="T_ff087_row0_col2" class="data row0 col2" >11_57_58</td>
#       <td id="T_ff087_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_ff087_row0_col4" class="data row0 col4" >115</td>
#       <td id="T_ff087_row0_col5" class="data row0 col5" >0.346189</td>
#       <td id="T_ff087_row0_col6" class="data row0 col6" >33.500000</td>
#       <td id="T_ff087_row0_col7" class="data row0 col7" >1.118862</td>
#       <td id="T_ff087_row0_col8" class="data row0 col8" >3.339887</td>
#       <td id="T_ff087_row0_col9" class="data row0 col9" >medium</td>
#       <td id="T_ff087_row0_col10" class="data row0 col10" >0.377610</td>
#       <td id="T_ff087_row0_col11" class="data row0 col11" >0.300030</td>
#       <td id="T_ff087_row0_col12" class="data row0 col12" >0.037174</td>
#       <td id="T_ff087_row0_col13" class="data row0 col13" >2.609643</td>
#       <td id="T_ff087_row0_col14" class="data row0 col14" ></td>
#     </tr>
#     <tr>
#       <th id="T_ff087_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ff087_row1_col0" class="data row1 col0" >E3</td>
#       <td id="T_ff087_row1_col1" class="data row1 col1" >2025_05_08</td>
#       <td id="T_ff087_row1_col2" class="data row1 col2" >11_57_58</td>
#       <td id="T_ff087_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_ff087_row1_col4" class="data row1 col4" >110</td>
#       <td id="T_ff087_row1_col5" class="data row1 col5" >0.326272</td>
#       <td id="T_ff087_row1_col6" class="data row1 col6" >33.500000</td>
#       <td id="T_ff087_row1_col7" class="data row1 col7" >0.872780</td>
#       <td id="T_ff087_row1_col8" class="data row1 col8" >2.605314</td>
#       <td id="T_ff087_row1_col9" class="data row1 col9" >good</td>
#       <td id="T_ff087_row1_col10" class="data row1 col10" >0.440771</td>
#       <td id="T_ff087_row1_col11" class="data row1 col11" >0.301441</td>
#       <td id="T_ff087_row1_col12" class="data row1 col12" >0.032317</td>
#       <td id="T_ff087_row1_col13" class="data row1 col13" >0.865417</td>
#       <td id="T_ff087_row1_col14" class="data row1 col14" ></td>
#     </tr>
#     <tr>
#       <th id="T_ff087_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ff087_row2_col0" class="data row2 col0" >E3</td>
#       <td id="T_ff087_row2_col1" class="data row2 col1" >2025_05_08</td>
#       <td id="T_ff087_row2_col2" class="data row2 col2" >11_57_58</td>
#       <td id="T_ff087_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_ff087_row2_col4" class="data row2 col4" >4</td>
#       <td id="T_ff087_row2_col5" class="data row2 col5" >0.212623</td>
#       <td id="T_ff087_row2_col6" class="data row2 col6" >30.000000</td>
#       <td id="T_ff087_row2_col7" class="data row2 col7" >8.737677</td>
#       <td id="T_ff087_row2_col8" class="data row2 col8" >29.125589</td>
#       <td id="T_ff087_row2_col9" class="data row2 col9" >bad</td>
#       <td id="T_ff087_row2_col10" class="data row2 col10" >0.212623</td>
#       <td id="T_ff087_row2_col11" class="data row2 col11" >0.200806</td>
#       <td id="T_ff087_row2_col12" class="data row2 col12" >0.014887</td>
#       <td id="T_ff087_row2_col13" class="data row2 col13" >12.915070</td>
#       <td id="T_ff087_row2_col14" class="data row2 col14" ></td>
#     </tr>
#     <tr>
#       <th id="T_ff087_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ff087_row3_col0" class="data row3 col0" >E3</td>
#       <td id="T_ff087_row3_col1" class="data row3 col1" >2025_05_08</td>
#       <td id="T_ff087_row3_col2" class="data row3 col2" >11_57_58</td>
#       <td i

# %%
# df_debug = df[(df['track_id'] == 27) & (df['filtered_length'] > 0.30)]
df_debug = df[(df['track_id'] == 27)]



# df_debug=df_debug.sort_values(by=['Abs_ERROR [cm]'],ascending=False)
df_debug=df_debug.sort_values(by=['frame_id'],ascending=False)
df_debug
# Out:
#     codi_escenari         day      hour  frame_id  class_name  Object_id  \
# 298            E3  2025_05_08  11_57_58  frame280           9        255
# 294            E3  2025_05_08  11_57_58  frame275           9        255
# 291            E3  2025_05_08  11_57_58  frame274           9        255
# 288            E3  2025_05_08  11_57_58  frame272           9        255
# 285            E3  2025_05_08  11_57_58  frame270           9        255
# 282            E3  2025_05_08  11_57_58  frame268           9        255
# 279            E3  2025_05_08  11_57_58  frame261           9        255
# 276            E3  2025_05_08  11_57_58  frame258           9        255
# 273            E3  2025_05_08  11_57_58  frame257           9        255
# 270            E3  2025_05_08  11_57_58  frame255           9        255
# 267            E3  2025_05_08  11_57_58  frame254           9        255
# 264            E3  2025_05_08  11_57_58  frame251           9        255
# 261            E3  2025_05_08  11_57_58  frame250           9        255
# 258            E3  2025_05_08  11_57_58  frame247           9        255
# 253            E3  2025_05_08  11_57_58  frame246           9        191
# 252            E3  2025_05_08  11_57_58  frame245           9        255
# 249            E3  2025_05_08  11_57_58  frame243           9        255
# 246            E3  2025_05_08  11_57_58  frame235           9        255
# 243            E3  2025_05_08  11_57_58  frame233           9        255
# 240            E3  2025_05_08  11_57_58  frame232           9        255
#
#      track_id  is_3D_complete  in_image_borders  \
# 298        27               1             False
# 294        27               1             False
# 291        27               1             False
# 288        27               1             False
# 285        27               1             False
# 282        27               1             False
# 279        27               1             False
# 276        27               1             False
# 273        27               1             False
# 270        27               1             False
# 267        27               1             False
# 264        27               1             False
# 261        27               1             False
# 258        27               1             False
# 253        27               1             False
# 252        27               1             False
# 249        27               1             False
# 246        27               1             False
# 243        27               1             False
# 240        27               1             False
#
#                             fish_direction  ...  filtered_length  \
# 298  [-0.43751257 -0.89527664  0.08403855]  ...         0.084256
# 294  [-0.94366821 -0.32789686 -0.04442919]  ...         0.270884
# 291  [-0.93863625 -0.34117868 -0.05058745]  ...         0.272923
# 288  [-0.94293785 -0.32521909 -0.0714195 ]  ...         0.276993
# 285  [-0.94906569 -0.30630931 -0.07381677]  ...         0.275718
# 282  [-0.95090767 -0.30442354 -0.05568581]  ...         0.274085
# 279  [-0.96879902 -0.22746397 -0.09843068]  ...         0.272480
# 276  [-0.97928793 -0.19381667 -0.05856839]  ...         0.262742
# 273  [-0.97900312 -0.19234901 -0.06748894]  ...         0.261212
# 270  [-0.96854152 -0.23301585 -0.08735518]  ...         0.260568
# 267  [-0.96742729 -0.24623096 -0.05877718]  ...         0.248863
# 264  [-0.93318396 -0.34349826 -0.10571965]  ...         0.267885
# 261  [-0.93347414 -0.35447004 -0.05456216]  ...         0.263112
# 258  [-0.92679214 -0.37083411 -0.0594844 ]  ...         0.254573
# 253  [-0.93373706 -0.35471653 -0.04807583]  ...         0.246320
# 252     [0.94118328 0.32716512 0.08448083]  ...         0.243017
# 249     [0.96267623 0.25726701 0.08407237]  ...         0.222880
# 246     [0.74796076 0.09850683 0.65639249]  ...         0.223171
# 243     [0.75894981 0.09850092 0.64365577]  ...         0.230558
# 240     [0.8338998  0.07911592 0.54621589]  ...         0.196144
#
#      fish_dist_from_camera  gt_measure  Abs_ERROR [cm]  Rel_ERROR[%]  \
# 298               1.458879        30.0       21.574394     71.914645
# 294               1.449183        30.0        2.911630      9.705432
# 291               1.448202        30.0        2.707676      9.025587
# 288               1.447195        30.0        2.300663      7.668878
# 285               1.445884        30.0        2.428169      8.093898
# 282               1.446242        30.0        2.591545      8.638482
# 279               1.447448        30.0        2.751950      9.173168
# 276               1.443435        30.0        3.725799     12.419331
# 273               1.444994        30.0        3.878787     12.929292
# 270               1.448595        30.0        3.943175     13.143918
# 267               1.448912        30.0        5.113680     17.045599
# 264               1.451290        30.0        3.211467     10.704889
# 261               1.452935        30.0        3.688801     12.296005
# 258               1.460135        30.0        4.542719     15.142396
# 253               1.462331        30.0        5.368005     17.893350
# 252               1.460478        30.0        5.698280     18.994266
# 249               1.463700        30.0        7.712028     25.706760
# 246               1.432320        30.0        7.682943     25.609812
# 243               1.429811        30.0        6.944173     23.147244
# 240               1.429919        30.0       10.385587     34.618623
#
#      measure_ok_abs  measure_ok_rel  elevation_abs elevation_rad elevation_sin
# 298             bad             bad       4.820740      0.084138      0.084039
# 294             bad             bad       2.546443     -0.044444      0.044429
# 291             bad             bad       2.899685     -0.050609      0.050587
# 288             bad             bad       4.095523     -0.071480      0.071420
# 285             bad             bad       4.233240     -0.073884      0.073817
# 282             bad             bad       3.192213     -0.055715      0.055686
# 279             bad             bad       5.648809     -0.098590      0.098431
# 276             bad             bad       3.357643     -0.058602      0.058568
# 273             bad             bad       3.869773     -0.067540      0.067489
# 270             bad             bad       5.011470     -0.087467      0.087355
# 267             bad             bad       3.369627     -0.058811      0.058777
# 264             bad             bad       6.068630     -0.105918      0.105720
# 261             bad             bad       3.127735     -0.054589      0.054562
# 258             bad             bad       3.410218     -0.059520      0.059484
# 253             bad             bad       2.755604     -0.048094      0.048076
# 252             bad             bad       4.846171      0.084582      0.084481
# 249             bad             bad       4.822685      0.084172      0.084072
# 246             bad             bad      41.025320      0.716027      0.656392
# 243             bad             bad      40.064964      0.699266      0.643656
# 240             bad             bad      33.107793      0.577840      0.546216
#
# [20 rows x 23 columns]

# %%
frame_id = 24
object_id=255

problematic_frames=[os.path.join(Escenari+base_path,file) for file in os.listdir(Escenari+base_path) if "frame"+str(frame_id)+"_" in file and (".jpg" in file or ".png" in file)]
debug_path=os.path.join(Escenari+base_path,"debug")
debug_files=[os.path.join(debug_path,file) for file in os.listdir(debug_path) if "frame"+str(frame_id)+"_" in file and str(object_id) in file and (".jpg" in file or ".png" in file)]
problematic_frames.extend(debug_files)
inferred_path=os.path.join(Escenari+base_path,"inferred")
inferred_files=[os.path.join(inferred_path,file) for file in os.listdir(inferred_path) if "frame"+str(frame_id)+"_" in file and str(object_id) in file and (".jpg" in file or ".png" in file)]
problematic_frames.extend(inferred_files)
problematic_frames
# Out:
# ['Escenari_3/2025_05_08/11_57_58/frame24_masked.png',
#  'Escenari_3/2025_05_08/11_57_58/frame24_right_image.jpg',
#  'Escenari_3/2025_05_08/11_57_58/frame24_left_image.jpg',
#  'Escenari_3/2025_05_08/11_57_58/frame24_object_ids.png',
#  'Escenari_3/2025_05_08/11_57_58/frame24_disparity.png',
#  'Escenari_3/2025_05_08/11_57_58/debug/frame24_object_255_mask.png',
#  'Escenari_3/2025_05_08/11_57_58/debug/frame24_object255_contours_MASK.png',
#  'Escenari_3/2025_05_08/11_57_58/debug/frame24_object255_ellipse_DISPARITY.png',
#  'Escenari_3/2025_05_08/11_57_58/debug/frame24_object_255_mask_and_disp.png',
#  'Escenari_3/2025_05_08/11_57_58/debug/frame24_object255_ellipse_MASK.png',
#  'Escenari_3/2025_05_08/11_57_58/debug/frame24_object_255_ellipses.png',
#  'Escenari_3/2025_05_08/11_57_58/debug/frame24_object_255_disp.png',
#  'Escenari_3/2025_05_08/11_57_58/debug/frame24_object255_contours_DISPARITY.png']

# %%
from IPython.display import Image

for imageName in problematic_frames:frame24frame24))
